# %%
import pandas as pd 
import numpy as np

# %%
data = "international.csv"

# %%
data_df = pd.read_csv(data)
data_new = data_df.drop(columns = ['Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16',
                                  'Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'])
data_new
# Out:
#       departure_airport_id               departure_airport departure_terminal  \
# 0                     35.0     Internacional Benito Juarez                  2
# 1                     53.0             Franz Josef Strauss                  2
# 2                     53.0             Franz Josef Strauss                  2
# 3                    213.0                      Manzanillo                  1
# 4                      6.0                        Schiphol                NaN
# ...                    ...                             ...                ...
# 2103                  94.0  Luis Munoz Marin International                  B
# 2104                  94.0  Luis Munoz Marin International                  B
# 2105                  94.0  Luis Munoz Marin International                  B
# 2106                 150.0            Nassau International                  A
# 2107                 150.0            Nassau International                  A
#
# ...

# %%
data_group = data_new.groupby("arrival_airport")
data_group.count()
# Out:
#                                           departure_airport_id  \
# arrival_airport
# Hartsfield-jackson Atlanta International                   618
# Los Angeles International                                 1038
#
#                                           departure_airport  \
# arrival_airport
# Hartsfield-jackson Atlanta International                618
# Los Angeles International                              1038
#
#                                           departure_terminal  departure_gate  \
# arrival_airport
# Hartsfield-jackson Atlanta International                 267             541
# Los Angeles International                                737             833
#
#                                           departure_delay  arrival_airport_id  \
# arrival_airport
# Hartsfield-jackson Atlanta International              617                 618
# Los Angeles International                            1016                1038
#
# ...

# %%
countries = data_df["Country"].unique()
country_df = pd.DataFrame(countries)
country_df
# Out:
#                        0
# 0                 Mexico
# 1                Germany
# 2                   Cuba
# 3            Netherlands
# 4            Phillipines
# 5                  Japan
# 6            El Salvador
# 7                  China
# 8                    NaN
# 9                 Turkey
# 10                Taiwan
# 11                  Peru
# 12             Hong Kong
# 13            Costa Rica
# 14  United Arab Emirates
# 15           South Korea
# 16             Singapore
# 17                 Chile
# 18           New Zealand
# 19             Australia
# 20             Guatemala
# 21            Luxembourg
# 22                 Qatar
# 23                Panama
# 24                Canada
# 25                  Guam
# 26                France
# 27               Ecuador
# 28                Belize
# 29                  Fiji
# 30                 Spain
# 31                Russia
# 32               Belgium
# 33               Bahamas
# 34        Virgin Islands
# 35           Puerto Rico
# ...

# %%
country_df.to_csv("unique_countries.csv")

# %%
data_new.to_csv("international_clean.csv")

# %%
data_sum = data_new.groupby("Country")
data_sum_count = data_sum.count()
data_count = ({"Country Count": data_sum_count})
data_count = data_count["Country Count"]
data_count_drop = data_count.drop(columns = ['Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16',
                                  'Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'])
data_count_drop.to_csv("country_count.csv")
