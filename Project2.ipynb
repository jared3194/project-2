# %%
import requests
import json
import pandas as pd
from config import api_key
from pprint import pprint

# %%
########################4.24.2021###################################100
params = {
  'access_key': api_key,
   'arr_iata': 'ATL'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0424.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-25T10:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-25T10:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 37,
#                          'estimated': '2021-04-25T09:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '231',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-25T09:20:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': None,
#                       'iata': 'KE35',
#                       'icao': 'KAL35',
#                       'number': '35'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-25T10:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-25T10:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 37,
#                          'estimated': '2021-04-25T09:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '231',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-25T09:20:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'ke',
#                                      'airline_icao': 'kal',
#                                      'airline_name': 'korean air',
#                                      'flight_iata': 'ke35',
#                                      'flight_icao': 'kal35',
#                                      'flight_number': '35'},
#                       'iata': 'DL7851',
#                       'icao': 'DAL7851',
#                       'number': '7851'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 5,
#                          'estimated': '2021-04-24T14:10:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '14',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T14:10:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1113',
#                                      'flight_icao': 'dal1113',
#                                      'flight_number': '1113'},
#                       'iata': 'KL5090',
#                       'icao': 'KLM5090',
#                       'number': '5090'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T13:03:00+00:00',
#                          'actual_runway': '2021-04-24T13:03:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': '2021-04-24T13:03:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'WS6786',
#                       'icao': 'WJA6786',
#                       'number': '6786'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T13:03:00+00:00',
#                          'actual_runway': '2021-04-24T13:03:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': '2021-04-24T13:03:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'VS5130',
#                       'icao': 'VIR5130',
#                       'number': '5130'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T13:03:00+00:00',
#                          'actual_runway': '2021-04-24T13:03:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': '2021-04-24T13:03:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'KL6327',
#                       'icao': 'KLM6327',
#                       'number': '6327'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T13:03:00+00:00',
#                          'actual_runway': '2021-04-24T13:03:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': '2021-04-24T13:03:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'AM4908',
#                       'icao': 'AMX4908',
#                       'number': '4908'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T13:03:00+00:00',
#                          'actual_runway': '2021-04-24T13:03:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': '2021-04-24T13:03:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'AF3708',
#                       'icao': 'AFR3708',
#                       'number': '3708'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T15:29:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:29:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T12:44:00+00:00',
#                          'actual_runway': '2021-04-24T12:44:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:30:00+00:00',
#                          'estimated_runway': '2021-04-24T12:44:00+00:00',
#                          'gate': '41',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:30:00+00:00',
#                          'terminal': 'C',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'ua',
#                                      'airline_icao': 'ual',
#                                      'airline_name': 'united airlines',
#                                      'flight_iata': 'ua6017',
#                                      'flight_icao': 'ual6017',
#                                      'flight_number': '6017'},
#                       'iata': 'NZ6320',
#                       'icao': 'ANZ6320',
#                       'number': '6320'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-24T13:48:00+00:00',
#                        'actual_runway': '2021-04-24T13:48:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': 10,
#                        'estimated': '2021-04-24T13:45:00+00:00',
#                        'estimated_runway': '2021-04-24T13:48:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T11:24:00+00:00',
#                          'actual_runway': '2021-04-24T11:24:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 38,
#                          'estimated': '2021-04-24T10:46:00+00:00',
#                          'estimated_runway': '2021-04-24T11:24:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T10:46:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl752',
#                                      'flight_icao': 'dal752',
#                                      'flight_number': '752'},
#                       'iata': 'VS4374',
#                       'icao': 'VIR4374',
#                       'number': '4374'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-24T13:48:00+00:00',
#                        'actual_runway': '2021-04-24T13:48:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': 10,
#                        'estimated': '2021-04-24T13:45:00+00:00',
#                        'estimated_runway': '2021-04-24T13:48:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T11:24:00+00:00',
#                          'actual_runway': '2021-04-24T11:24:00+00:00',
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 38,
#                          'estimated': '2021-04-24T10:46:00+00:00',
#                          'estimated_runway': '2021-04-24T11:24:00+00:00',
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T10:46:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl752',
#                                      'flight_icao': 'dal752',
#                                      'flight_number': '752'},
#                       'iata': 'AM5116',
#                       'icao': 'AMX5116',
#                       'number': '5116'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T13:23:00+00:00',
#                        'actual_runway': '2021-04-24T13:23:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': 34,
#                        'estimated': '2021-04-24T12:50:00+00:00',
#                        'estimated_runway': '2021-04-24T13:23:00+00:00',
#                        'gate': 'D30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:50:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T10:27:00+00:00',
#                          'actual_runway': '2021-04-24T10:27:00+00:00',
#                          'airport': 'Salina',
#                          'delay': 57,
#                          'estimated': '2021-04-24T09:30:00+00:00',
#                          'estimated_runway': '2021-04-24T10:27:00+00:00',
#                          'gate': None,
#                          'iata': 'SLN',
#                          'icao': 'KSLN',
#                          'scheduled': '2021-04-24T09:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5554',
#                       'icao': 'DAL5554',
#                       'number': '5554'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 11,
#                          'estimated': '2021-04-24T15:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D6',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T15:55:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1049',
#                       'icao': 'DAL1049',
#                       'number': '1049'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 11,
#                          'estimated': '2021-04-24T15:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D6',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T15:55:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1049',
#                                      'flight_icao': 'dal1049',
#                                      'flight_number': '1049'},
#                       'iata': 'WS6672',
#                       'icao': 'WJA6672',
#                       'number': '6672'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:41:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'C55',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Harrisburg International',
#                          'delay': 2,
#                          'estimated': '2021-04-24T17:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-24T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4847',
#                       'icao': 'DAL4847',
#                       'number': '4847'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:48:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hopkins International',
#                          'delay': 65,
#                          'estimated': '2021-04-24T16:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:48:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hopkins International',
#                          'delay': 65,
#                          'estimated': '2021-04-24T16:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T19:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'C21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'La Guardia',
#                          'delay': 23,
#                          'estimated': '2021-04-24T16:25:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '55',
#                          'iata': 'LGA',
#                          'icao': 'KLGA',
#                          'scheduled': '2021-04-24T16:25:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN2625',
#                       'icao': 'SWA2625',
#                       'number': '2625'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T08:51:00+00:00',
#                        'actual_runway': '2021-04-24T08:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': 4,
#                        'estimated': '2021-04-24T08:48:00+00:00',
#                        'estimated_runway': '2021-04-24T08:51:00+00:00',
#                        'gate': 'B17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T07:08:00+00:00',
#                          'actual_runway': '2021-04-24T07:08:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 8,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': '2021-04-24T07:08:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2218',
#                       'icao': 'DAL2218',
#                       'number': '2218'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-24T08:51:00+00:00',
#                        'actual_runway': '2021-04-24T08:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': 4,
#                        'estimated': '2021-04-24T08:48:00+00:00',
#                        'estimated_runway': '2021-04-24T08:51:00+00:00',
#                        'gate': 'B17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T07:08:00+00:00',
#                          'actual_runway': '2021-04-24T07:08:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 8,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': '2021-04-24T07:08:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2218',
#                                      'flight_icao': 'dal2218',
#                                      'flight_number': '2218'},
#                       'iata': 'AM5210',
#                       'icao': 'AMX5210',
#                       'number': '5210'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:09:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:09:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 7,
#                          'estimated': '2021-04-24T17:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-24T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'KL6899',
#                       'icao': 'KLM6899',
#                       'number': '6899'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-24T11:03:00+00:00',
#                        'actual_runway': '2021-04-24T11:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T11:23:00+00:00',
#                        'estimated_runway': '2021-04-24T11:03:00+00:00',
#                        'gate': 'B26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T11:23:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T08:34:00+00:00',
#                          'actual_runway': '2021-04-24T08:34:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 4,
#                          'estimated': '2021-04-24T08:30:00+00:00',
#                          'estimated_runway': '2021-04-24T08:34:00+00:00',
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-24T08:30:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl843',
#                                      'flight_icao': 'dal843',
#                                      'flight_number': '843'},
#                       'iata': 'AM3558',
#                       'icao': 'AMX3558',
#                       'number': '3558'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-24T11:03:00+00:00',
#                        'actual_runway': '2021-04-24T11:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T11:23:00+00:00',
#                        'estimated_runway': '2021-04-24T11:03:00+00:00',
#                        'gate': 'B26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T11:23:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T08:34:00+00:00',
#                          'actual_runway': '2021-04-24T08:34:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 4,
#                          'estimated': '2021-04-24T08:30:00+00:00',
#                          'estimated_runway': '2021-04-24T08:34:00+00:00',
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-24T08:30:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl843',
#                                      'flight_icao': 'dal843',
#                                      'flight_number': '843'},
#                       'iata': 'KE6986',
#                       'icao': 'KAL6986',
#                       'number': '6986'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:32:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Bush Field',
#                          'delay': 3,
#                          'estimated': '2021-04-24T18:26:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-24T18:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5286',
#                                      'flight_icao': 'dal5286',
#                                      'flight_number': '5286'},
#                       'iata': 'AF2293',
#                       'icao': 'AFR2293',
#                       'number': '2293'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:32:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Bush Field',
#                          'delay': 3,
#                          'estimated': '2021-04-24T18:26:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-24T18:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5286',
#                                      'flight_icao': 'dal5286',
#                                      'flight_number': '5286'},
#                       'iata': 'KL6812',
#                       'icao': 'KLM6812',
#                       'number': '6812'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:32:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
# ...
#                          'iata': 'IAD',
#                          'icao': 'KIAD',
#                          'scheduled': '2021-04-24T16:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2221',
#                       'icao': 'DAL2221',
#                       'number': '2221'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'NW Florida Beaches Int',
#                          'delay': 2,
#                          'estimated': '2021-04-24T15:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'ECP',
#                          'icao': 'KECP',
#                          'scheduled': '2021-04-24T15:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1709',
#                                      'flight_icao': 'dal1709',
#                                      'flight_number': '1709'},
#                       'iata': 'AF2260',
#                       'icao': 'AFR2260',
#                       'number': '2260'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'NW Florida Beaches Int',
#                          'delay': 2,
#                          'estimated': '2021-04-24T15:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'ECP',
#                          'icao': 'KECP',
#                          'scheduled': '2021-04-24T15:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1709',
#                                      'flight_icao': 'dal1709',
#                                      'flight_number': '1709'},
#                       'iata': 'WS6690',
#                       'icao': 'WJA6690',
#                       'number': '6690'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'NW Florida Beaches Int',
#                          'delay': 2,
#                          'estimated': '2021-04-24T15:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'ECP',
#                          'icao': 'KECP',
#                          'scheduled': '2021-04-24T15:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1709',
#                                      'flight_icao': 'dal1709',
#                                      'flight_number': '1709'},
#                       'iata': 'KL8133',
#                       'icao': 'KLM8133',
#                       'number': '8133'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'NW Florida Beaches Int',
#                          'delay': 2,
#                          'estimated': '2021-04-24T15:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'ECP',
#                          'icao': 'KECP',
#                          'scheduled': '2021-04-24T15:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1709',
#                                      'flight_icao': 'dal1709',
#                                      'flight_number': '1709'},
#                       'iata': 'VS2588',
#                       'icao': 'VIR2588',
#                       'number': '2588'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'NW Florida Beaches Int',
#                          'delay': 2,
#                          'estimated': '2021-04-24T15:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'ECP',
#                          'icao': 'KECP',
#                          'scheduled': '2021-04-24T15:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1709',
#                       'icao': 'DAL1709',
#                       'number': '1709'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'ACD88E',
#                         'registration': 'N927DZ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T12:51:00+00:00',
#                        'actual_runway': '2021-04-24T12:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T13:00:00+00:00',
#                        'estimated_runway': '2021-04-24T12:51:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T11:45:00+00:00',
#                          'actual_runway': '2021-04-24T11:45:00+00:00',
#                          'airport': 'Cincinnati/Northern Kentucky',
#                          'delay': 14,
#                          'estimated': '2021-04-24T11:31:00+00:00',
#                          'estimated_runway': '2021-04-24T11:45:00+00:00',
#                          'gate': 'B15',
#                          'iata': 'CVG',
#                          'icao': 'KCVG',
#                          'scheduled': '2021-04-24T11:31:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2097',
#                       'icao': 'DAL2097',
#                       'number': '2097'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-24T12:51:00+00:00',
#                        'actual_runway': '2021-04-24T12:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T13:00:00+00:00',
#                        'estimated_runway': '2021-04-24T12:51:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T11:45:00+00:00',
#                          'actual_runway': '2021-04-24T11:45:00+00:00',
#                          'airport': 'Cincinnati/Northern Kentucky',
#                          'delay': 14,
#                          'estimated': '2021-04-24T11:31:00+00:00',
#                          'estimated_runway': '2021-04-24T11:45:00+00:00',
#                          'gate': 'B15',
#                          'iata': 'CVG',
#                          'icao': 'KCVG',
#                          'scheduled': '2021-04-24T11:31:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2097',
#                                      'flight_icao': 'dal2097',
#                                      'flight_number': '2097'},
#                       'iata': 'WS6644',
#                       'icao': 'WJA6644',
#                       'number': '6644'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-24T12:51:00+00:00',
#                        'actual_runway': '2021-04-24T12:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T13:00:00+00:00',
#                        'estimated_runway': '2021-04-24T12:51:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T11:45:00+00:00',
#                          'actual_runway': '2021-04-24T11:45:00+00:00',
#                          'airport': 'Cincinnati/Northern Kentucky',
#                          'delay': 14,
#                          'estimated': '2021-04-24T11:31:00+00:00',
#                          'estimated_runway': '2021-04-24T11:45:00+00:00',
#                          'gate': 'B15',
#                          'iata': 'CVG',
#                          'icao': 'KCVG',
#                          'scheduled': '2021-04-24T11:31:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2097',
#                                      'flight_icao': 'dal2097',
#                                      'flight_number': '2097'},
#                       'iata': 'VS5062',
#                       'icao': 'VIR5062',
#                       'number': '5062'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 255045}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #estimated.append(row['arrival']['estimated'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"icao": icao,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data_df.head()
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 95           AS          ASA  Hartsfield-jackson Atlanta International
# 96           VS          VIR  Hartsfield-jackson Atlanta International
# 97           KL          KLM  Hartsfield-jackson Atlanta International
# 98           DL          DAL  Hartsfield-jackson Atlanta International
# 99           AZ          AZA  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0         35            I     None               Seoul (Incheon)            2
# 1       7851            I     None               Seoul (Incheon)            2
# 2       5090            I     None               Seoul (Incheon)            2
# 3       6786            S      B21  George Bush Intercontinental            A
# 4       5130            S      A12  George Bush Intercontinental            A
# ..       ...          ...      ...                           ...          ...
# 95      2588            S      B14        NW Florida Beaches Int         None
# 96      1709            S      B14        NW Florida Beaches Int         None
# 97      2097            S      B14        NW Florida Beaches Int         None
# 98      6644            S      B32  Cincinnati/Northern Kentucky            3
# 99      5062            S      B32  Cincinnati/Northern Kentucky            3
#
#    dep_gate
# 0       231
# 1       231
# 2       231
# 3        14
# 4        15
# ..      ...
# 95        4
# 96        4
# 97        4
# 98      B15
# 99      B15
#
# [100 rows x 9 columns]

# %%
########################4.23.2021###################################200
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-23',    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T07:18:00+00:00',
#                        'actual_runway': '2021-04-23T07:18:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-23T07:28:00+00:00',
#                        'estimated_runway': '2021-04-23T07:18:00+00:00',
#                        'gate': 'B22',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T07:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:16:00+00:00',
#                          'actual_runway': '2021-04-23T06:16:00+00:00',
#                          'airport': 'Cincinnati/Northern Kentucky',
#                          'delay': 16,
#                          'estimated': '2021-04-23T06:00:00+00:00',
#                          'estimated_runway': '2021-04-23T06:16:00+00:00',
#                          'gate': 'B15',
#                          'iata': 'CVG',
#                          'icao': 'KCVG',
#                          'scheduled': '2021-04-23T06:00:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1626',
#                                      'flight_icao': 'dal1626',
#                                      'flight_number': '1626'},
#                       'iata': 'AM3055',
#                       'icao': 'AMX3055',
#                       'number': '3055'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T07:18:00+00:00',
#                        'actual_runway': '2021-04-23T07:18:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-23T07:28:00+00:00',
#                        'estimated_runway': '2021-04-23T07:18:00+00:00',
#                        'gate': 'B22',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T07:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:16:00+00:00',
#                          'actual_runway': '2021-04-23T06:16:00+00:00',
#                          'airport': 'Cincinnati/Northern Kentucky',
#                          'delay': 16,
#                          'estimated': '2021-04-23T06:00:00+00:00',
#                          'estimated_runway': '2021-04-23T06:16:00+00:00',
#                          'gate': 'B15',
#                          'iata': 'CVG',
#                          'icao': 'KCVG',
#                          'scheduled': '2021-04-23T06:00:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1626',
#                       'icao': 'DAL1626',
#                       'number': '1626'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:43:00+00:00',
#                        'actual_runway': '2021-04-23T08:43:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:43:00+00:00',
#                        'gate': 'A15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:19:00+00:00',
#                          'actual_runway': '2021-04-23T07:19:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-23T07:12:00+00:00',
#                          'estimated_runway': '2021-04-23T07:19:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-23T07:12:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1469',
#                                      'flight_icao': 'dal1469',
#                                      'flight_number': '1469'},
#                       'iata': 'KE7106',
#                       'icao': 'KAL7106',
#                       'number': '7106'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'ABD69D',
#                         'registration': 'N862DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:43:00+00:00',
#                        'actual_runway': '2021-04-23T08:43:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:43:00+00:00',
#                        'gate': 'A15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:19:00+00:00',
#                          'actual_runway': '2021-04-23T07:19:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-23T07:12:00+00:00',
#                          'estimated_runway': '2021-04-23T07:19:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-23T07:12:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1469',
#                       'icao': 'DAL1469',
#                       'number': '1469'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-23T09:27:00+00:00',
#                        'actual_runway': '2021-04-23T09:27:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:50:00+00:00',
#                        'estimated_runway': '2021-04-23T09:27:00+00:00',
#                        'gate': 'C15',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:50:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:10:00+00:00',
#                          'actual_runway': '2021-04-23T07:10:00+00:00',
#                          'airport': 'Midway',
#                          'delay': 10,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:10:00+00:00',
#                          'gate': 'B26',
#                          'iata': 'MDW',
#                          'icao': 'KMDW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN1264',
#                       'icao': 'SWA1264',
#                       'number': '1264'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-23T08:48:00+00:00',
#                        'actual_runway': '2021-04-23T08:48:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:05:00+00:00',
#                        'estimated_runway': '2021-04-23T08:48:00+00:00',
#                        'gate': 'C20',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:10:00+00:00',
#                          'actual_runway': '2021-04-23T07:10:00+00:00',
#                          'airport': 'Nashville International',
#                          'delay': 11,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:10:00+00:00',
#                          'gate': 'C7',
#                          'iata': 'BNA',
#                          'icao': 'KBNA',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN699',
#                       'icao': 'SWA699',
#                       'number': '699'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-23T09:25:00+00:00',
#                        'actual_runway': '2021-04-23T09:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:55:00+00:00',
#                        'estimated_runway': '2021-04-23T09:25:00+00:00',
#                        'gate': 'C17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:50:00+00:00',
#                          'actual_runway': '2021-04-23T06:50:00+00:00',
#                          'airport': 'Eppley Airfield',
#                          'delay': 11,
#                          'estimated': '2021-04-23T06:40:00+00:00',
#                          'estimated_runway': '2021-04-23T06:50:00+00:00',
#                          'gate': 'B16',
#                          'iata': 'OMA',
#                          'icao': 'KOMA',
#                          'scheduled': '2021-04-23T06:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN285',
#                       'icao': 'SWA285',
#                       'number': '285'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T09:47:00+00:00',
#                        'actual_runway': '2021-04-23T09:47:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:16:00+00:00',
#                        'estimated_runway': '2021-04-23T09:47:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:09:00+00:00',
#                          'actual_runway': '2021-04-23T07:09:00+00:00',
#                          'airport': 'Eppley Airfield',
#                          'delay': 10,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:09:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'OMA',
#                          'icao': 'KOMA',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5792',
#                                      'flight_icao': 'dal5792',
#                                      'flight_number': '5792'},
#                       'iata': 'AM4772',
#                       'icao': 'AMX4772',
#                       'number': '4772'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T09:47:00+00:00',
#                        'actual_runway': '2021-04-23T09:47:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:16:00+00:00',
#                        'estimated_runway': '2021-04-23T09:47:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:09:00+00:00',
#                          'actual_runway': '2021-04-23T07:09:00+00:00',
#                          'airport': 'Eppley Airfield',
#                          'delay': 10,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:09:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'OMA',
#                          'icao': 'KOMA',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5792',
#                                      'flight_icao': 'dal5792',
#                                      'flight_number': '5792'},
#                       'iata': 'KE3631',
#                       'icao': 'KAL3631',
#                       'number': '3631'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T09:47:00+00:00',
#                        'actual_runway': '2021-04-23T09:47:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:16:00+00:00',
#                        'estimated_runway': '2021-04-23T09:47:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:09:00+00:00',
#                          'actual_runway': '2021-04-23T07:09:00+00:00',
#                          'airport': 'Eppley Airfield',
#                          'delay': 10,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:09:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'OMA',
#                          'icao': 'KOMA',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5792',
#                                      'flight_icao': 'dal5792',
#                                      'flight_number': '5792'},
#                       'iata': 'VS3188',
#                       'icao': 'VIR3188',
#                       'number': '3188'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T09:47:00+00:00',
#                        'actual_runway': '2021-04-23T09:47:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:16:00+00:00',
#                        'estimated_runway': '2021-04-23T09:47:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:09:00+00:00',
#                          'actual_runway': '2021-04-23T07:09:00+00:00',
#                          'airport': 'Eppley Airfield',
#                          'delay': 10,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:09:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'OMA',
#                          'icao': 'KOMA',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5792',
#                       'icao': 'DAL5792',
#                       'number': '5792'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:23:00+00:00',
#                        'actual_runway': '2021-04-23T08:23:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:50:00+00:00',
#                        'estimated_runway': '2021-04-23T08:23:00+00:00',
#                        'gate': 'T04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:50:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:36:00+00:00',
#                          'actual_runway': '2021-04-23T06:36:00+00:00',
#                          'airport': 'Memphis International',
#                          'delay': 1,
#                          'estimated': '2021-04-23T06:35:00+00:00',
#                          'estimated_runway': '2021-04-23T06:36:00+00:00',
#                          'gate': 'A17',
#                          'iata': 'MEM',
#                          'icao': 'KMEM',
#                          'scheduled': '2021-04-23T06:35:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1648',
#                       'icao': 'DAL1648',
#                       'number': '1648'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T08:27:00+00:00',
#                        'actual_runway': '2021-04-23T08:27:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:57:00+00:00',
#                        'estimated_runway': '2021-04-23T08:27:00+00:00',
#                        'gate': 'A33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:06:00+00:00',
#                          'actual_runway': '2021-04-23T06:06:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:00:00+00:00',
#                          'estimated_runway': '2021-04-23T06:06:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2021',
#                                      'flight_icao': 'dal2021',
#                                      'flight_number': '2021'},
#                       'iata': 'AM4610',
#                       'icao': 'AMX4610',
#                       'number': '4610'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:27:00+00:00',
#                        'actual_runway': '2021-04-23T08:27:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:57:00+00:00',
#                        'estimated_runway': '2021-04-23T08:27:00+00:00',
#                        'gate': 'A33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:06:00+00:00',
#                          'actual_runway': '2021-04-23T06:06:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:00:00+00:00',
#                          'estimated_runway': '2021-04-23T06:06:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2021',
#                                      'flight_icao': 'dal2021',
#                                      'flight_number': '2021'},
#                       'iata': 'KE3777',
#                       'icao': 'KAL3777',
#                       'number': '3777'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B738',
#                         'icao': 'B738',
#                         'icao24': 'A437CE',
#                         'registration': 'N371DA'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:27:00+00:00',
#                        'actual_runway': '2021-04-23T08:27:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:57:00+00:00',
#                        'estimated_runway': '2021-04-23T08:27:00+00:00',
#                        'gate': 'A33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:06:00+00:00',
#                          'actual_runway': '2021-04-23T06:06:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:00:00+00:00',
#                          'estimated_runway': '2021-04-23T06:06:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2021',
#                       'icao': 'DAL2021',
#                       'number': '2021'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T08:42:00+00:00',
#                        'actual_runway': '2021-04-23T08:42:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:48:00+00:00',
#                        'estimated_runway': '2021-04-23T08:42:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:40:00+00:00',
#                          'actual_runway': '2021-04-23T07:40:00+00:00',
#                          'airport': 'Piedmont Triad International',
#                          'delay': 20,
#                          'estimated': '2021-04-23T07:20:00+00:00',
#                          'estimated_runway': '2021-04-23T07:40:00+00:00',
#                          'gate': '31',
#                          'iata': 'GSO',
#                          'icao': 'KGSO',
#                          'scheduled': '2021-04-23T07:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5721',
#                                      'flight_icao': 'dal5721',
#                                      'flight_number': '5721'},
#                       'iata': 'AM3448',
#                       'icao': 'AMX3448',
#                       'number': '3448'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:42:00+00:00',
#                        'actual_runway': '2021-04-23T08:42:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:48:00+00:00',
#                        'estimated_runway': '2021-04-23T08:42:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:40:00+00:00',
#                          'actual_runway': '2021-04-23T07:40:00+00:00',
#                          'airport': 'Piedmont Triad International',
#                          'delay': 20,
#                          'estimated': '2021-04-23T07:20:00+00:00',
#                          'estimated_runway': '2021-04-23T07:40:00+00:00',
#                          'gate': '31',
#                          'iata': 'GSO',
#                          'icao': 'KGSO',
#                          'scheduled': '2021-04-23T07:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5721',
#                                      'flight_icao': 'dal5721',
#                                      'flight_number': '5721'},
#                       'iata': 'KE3677',
#                       'icao': 'KAL3677',
#                       'number': '3677'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:42:00+00:00',
#                        'actual_runway': '2021-04-23T08:42:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:48:00+00:00',
#                        'estimated_runway': '2021-04-23T08:42:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:40:00+00:00',
#                          'actual_runway': '2021-04-23T07:40:00+00:00',
#                          'airport': 'Piedmont Triad International',
#                          'delay': 20,
#                          'estimated': '2021-04-23T07:20:00+00:00',
#                          'estimated_runway': '2021-04-23T07:40:00+00:00',
#                          'gate': '31',
#                          'iata': 'GSO',
#                          'icao': 'KGSO',
#                          'scheduled': '2021-04-23T07:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5721',
#                       'icao': 'DAL5721',
#                       'number': '5721'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:20:00+00:00',
#                        'actual_runway': '2021-04-23T08:20:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:53:00+00:00',
#                        'estimated_runway': '2021-04-23T08:20:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:53:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:39:00+00:00',
#                          'actual_runway': '2021-04-23T06:39:00+00:00',
#                          'airport': 'Golden Triangle Reg.',
#                          'delay': 4,
#                          'estimated': '2021-04-23T06:36:00+00:00',
#                          'estimated_runway': '2021-04-23T06:39:00+00:00',
#                          'gate': None,
#                          'iata': 'GTR',
#                          'icao': 'KGTR',
#                          'scheduled': '2021-04-23T06:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5316',
#                                      'flight_icao': 'dal5316',
#                                      'flight_number': '5316'},
#                       'iata': 'KE3722',
#                       'icao': 'KAL3722',
#                       'number': '3722'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T08:20:00+00:00',
#                        'actual_runway': '2021-04-23T08:20:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:53:00+00:00',
#                        'estimated_runway': '2021-04-23T08:20:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:53:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:39:00+00:00',
#                          'actual_runway': '2021-04-23T06:39:00+00:00',
#                          'airport': 'Golden Triangle Reg.',
#                          'delay': 4,
#                          'estimated': '2021-04-23T06:36:00+00:00',
#                          'estimated_runway': '2021-04-23T06:39:00+00:00',
#                          'gate': None,
#                          'iata': 'GTR',
#                          'icao': 'KGTR',
#                          'scheduled': '2021-04-23T06:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5316',
#                                      'flight_icao': 'dal5316',
#                                      'flight_number': '5316'},
#                       'iata': 'VS4698',
#                       'icao': 'VIR4698',
#                       'number': '4698'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-23T08:20:00+00:00',
#                        'actual_runway': '2021-04-23T08:20:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:53:00+00:00',
#                        'estimated_runway': '2021-04-23T08:20:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:53:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:39:00+00:00',
#                          'actual_runway': '2021-04-23T06:39:00+00:00',
#                          'airport': 'Golden Triangle Reg.',
#                          'delay': 4,
#                          'estimated': '2021-04-23T06:36:00+00:00',
#                          'estimated_runway': '2021-04-23T06:39:00+00:00',
#                          'gate': None,
#                          'iata': 'GTR',
#                          'icao': 'KGTR',
#                          'scheduled': '2021-04-23T06:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5316',
#                                      'flight_icao': 'dal5316',
#                                      'flight_number': '5316'},
#                       'iata': 'KL6891',
#                       'icao': 'KLM6891',
#                       'number': '6891'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:20:00+00:00',
#                        'actual_runway': '2021-04-23T08:20:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:53:00+00:00',
#                        'estimated_runway': '2021-04-23T08:20:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T08:53:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T06:39:00+00:00',
#                          'actual_runway': '2021-04-23T06:39:00+00:00',
#                          'airport': 'Golden Triangle Reg.',
#                          'delay': 4,
#                          'estimated': '2021-04-23T06:36:00+00:00',
#                          'estimated_runway': '2021-04-23T06:39:00+00:00',
#                          'gate': None,
#                          'iata': 'GTR',
#                          'icao': 'KGTR',
#                          'scheduled': '2021-04-23T06:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5316',
#                       'icao': 'DAL5316',
#                       'number': '5316'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B738',
#                         'icao': 'B738',
#                         'icao24': 'ABE42C',
#                         'registration': 'N8653A'},
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-23T09:30:00+00:00',
#                        'actual_runway': '2021-04-23T09:30:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T10:00:00+00:00',
#                        'estimated_runway': '2021-04-23T09:30:00+00:00',
#                        'gate': 'C22',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:05:00+00:00',
#                          'actual_runway': '2021-04-23T07:05:00+00:00',
#                          'airport': 'Kansas City International Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:05:00+00:00',
#                          'gate': '45',
#                          'iata': 'MCI',
#                          'icao': 'KMCI',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN746',
#                       'icao': 'SWA746',
#                       'number': '746'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T09:12:00+00:00',
#                        'actual_runway': '2021-04-23T09:12:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:40:00+00:00',
#                        'estimated_runway': '2021-04-23T09:12:00+00:00',
#                        'gate': 'A4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T08:06:00+00:00',
#                          'actual_runway': '2021-04-23T08:06:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 7,
#                          'estimated': '2021-04-23T08:00:00+00:00',
#                          'estimated_runway': '2021-04-23T08:06:00+00:00',
#                          'gate': '75',
#                          'iata': 'MCO',
#                          'icao': 'KMCO',
#                          'scheduled': '2021-04-23T08:00:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2245',
#                                      'flight_icao': 'dal2245',
#                                      'flight_number': '2245'},
#                       'iata': 'KE6948',
#                       'icao': 'KAL6948',
#                       'number': '6948'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B752',
#                         'icao': 'B752',
#                         'icao24': 'A8DED6',
#                         'registration': 'N6705Y'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T09:12:00+00:00',
#                        'actual_runway': '2021-04-23T09:12:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:40:00+00:00',
#                        'estimated_runway': '2021-04-23T09:12:00+00:00',
#                        'gate': 'A4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T08:06:00+00:00',
#                          'actual_runway': '2021-04-23T08:06:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 7,
#                          'estimated': '2021-04-23T08:00:00+00:00',
# ...
#                        'actual_runway': '2021-04-23T11:36:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': 1,
#                        'estimated': '2021-04-23T11:39:00+00:00',
#                        'estimated_runway': '2021-04-23T11:36:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T11:39:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T08:00:00+00:00',
#                          'actual_runway': '2021-04-23T08:00:00+00:00',
#                          'airport': 'Luis Munoz Marin International',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:45:00+00:00',
#                          'estimated_runway': '2021-04-23T08:00:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'SJU',
#                          'icao': 'TJSJ',
#                          'scheduled': '2021-04-23T07:45:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/Puerto_Rico'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1858',
#                                      'flight_icao': 'dal1858',
#                                      'flight_number': '1858'},
#                       'iata': 'WS7325',
#                       'icao': 'WJA7325',
#                       'number': '7325'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B752',
#                         'icao': 'B752',
#                         'icao24': 'A8E29C',
#                         'registration': 'N6716C'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T11:36:00+00:00',
#                        'actual_runway': '2021-04-23T11:36:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': 1,
#                        'estimated': '2021-04-23T11:39:00+00:00',
#                        'estimated_runway': '2021-04-23T11:36:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T11:39:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T08:00:00+00:00',
#                          'actual_runway': '2021-04-23T08:00:00+00:00',
#                          'airport': 'Luis Munoz Marin International',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:45:00+00:00',
#                          'estimated_runway': '2021-04-23T08:00:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'SJU',
#                          'icao': 'TJSJ',
#                          'scheduled': '2021-04-23T07:45:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/Puerto_Rico'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1858',
#                       'icao': 'DAL1858',
#                       'number': '1858'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T09:46:00+00:00',
#                        'actual_runway': '2021-04-23T09:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:11:00+00:00',
#                        'estimated_runway': '2021-04-23T09:46:00+00:00',
#                        'gate': 'D6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:15:00+00:00',
#                          'actual_runway': '2021-04-23T07:15:00+00:00',
#                          'airport': 'Eastern Iowa Airport',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:15:00+00:00',
#                          'gate': '2',
#                          'iata': 'CID',
#                          'icao': 'KCID',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5052',
#                                      'flight_icao': 'dal5052',
#                                      'flight_number': '5052'},
#                       'iata': 'AM3254',
#                       'icao': 'AMX3254',
#                       'number': '3254'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T09:46:00+00:00',
#                        'actual_runway': '2021-04-23T09:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:11:00+00:00',
#                        'estimated_runway': '2021-04-23T09:46:00+00:00',
#                        'gate': 'D6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:15:00+00:00',
#                          'actual_runway': '2021-04-23T07:15:00+00:00',
#                          'airport': 'Eastern Iowa Airport',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:15:00+00:00',
#                          'gate': '2',
#                          'iata': 'CID',
#                          'icao': 'KCID',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5052',
#                                      'flight_icao': 'dal5052',
#                                      'flight_number': '5052'},
#                       'iata': 'KE3594',
#                       'icao': 'KAL3594',
#                       'number': '3594'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-23T09:46:00+00:00',
#                        'actual_runway': '2021-04-23T09:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:11:00+00:00',
#                        'estimated_runway': '2021-04-23T09:46:00+00:00',
#                        'gate': 'D6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:15:00+00:00',
#                          'actual_runway': '2021-04-23T07:15:00+00:00',
#                          'airport': 'Eastern Iowa Airport',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:15:00+00:00',
#                          'gate': '2',
#                          'iata': 'CID',
#                          'icao': 'KCID',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5052',
#                                      'flight_icao': 'dal5052',
#                                      'flight_number': '5052'},
#                       'iata': 'KL6263',
#                       'icao': 'KLM6263',
#                       'number': '6263'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T09:46:00+00:00',
#                        'actual_runway': '2021-04-23T09:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:11:00+00:00',
#                        'estimated_runway': '2021-04-23T09:46:00+00:00',
#                        'gate': 'D6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:15:00+00:00',
#                          'actual_runway': '2021-04-23T07:15:00+00:00',
#                          'airport': 'Eastern Iowa Airport',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:15:00+00:00',
#                          'gate': '2',
#                          'iata': 'CID',
#                          'icao': 'KCID',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5052',
#                                      'flight_icao': 'dal5052',
#                                      'flight_number': '5052'},
#                       'iata': 'VS2993',
#                       'icao': 'VIR2993',
#                       'number': '2993'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T09:46:00+00:00',
#                        'actual_runway': '2021-04-23T09:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-23T10:11:00+00:00',
#                        'estimated_runway': '2021-04-23T09:46:00+00:00',
#                        'gate': 'D6',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T10:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T07:15:00+00:00',
#                          'actual_runway': '2021-04-23T07:15:00+00:00',
#                          'airport': 'Eastern Iowa Airport',
#                          'delay': 15,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:15:00+00:00',
#                          'gate': '2',
#                          'iata': 'CID',
#                          'icao': 'KCID',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5052',
#                       'icao': 'DAL5052',
#                       'number': '5052'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T09:43:00+00:00',
#                        'actual_runway': '2021-04-23T09:43:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:55:00+00:00',
#                        'estimated_runway': '2021-04-23T09:43:00+00:00',
#                        'gate': 'A25',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-23T09:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-23T08:08:00+00:00',
#                          'actual_runway': '2021-04-23T08:08:00+00:00',
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 8,
#                          'estimated': '2021-04-23T08:00:00+00:00',
#                          'estimated_runway': '2021-04-23T08:08:00+00:00',
#                          'gate': 'D8',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-23T08:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2206',
#                                      'flight_icao': 'dal2206',
#                                      'flight_number': '2206'},
#                       'iata': 'AM4255',
#                       'icao': 'AMX4255',
#                       'number': '4255'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3212}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data2_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data2_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([flights_data_df, flights_data2_df])
joined_df_merge.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
########################4.22.2021###################################300
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-22'
    
}

api_0422 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0422.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'NK', 'icao': 'NKS', 'name': 'Spirit Airlines'},
#            'arrival': {'actual': '2021-04-22T18:31:00+00:00',
#                        'actual_runway': '2021-04-22T18:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:52:00+00:00',
#                        'estimated_runway': '2021-04-22T18:31:00+00:00',
#                        'gate': 'D3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:52:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:56:00+00:00',
#                          'actual_runway': '2021-04-22T15:56:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 16,
#                          'estimated': '2021-04-22T15:40:00+00:00',
#                          'estimated_runway': '2021-04-22T15:56:00+00:00',
#                          'gate': '11',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-22T15:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'NK465',
#                       'icao': 'NKS465',
#                       'number': '465'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD876E',
#                         'registration': 'N971AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL977',
#                       'icao': 'DAL977',
#                       'number': '977'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'VS2924',
#                       'icao': 'VIR2924',
#                       'number': '2924'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AZ3245',
#                       'icao': 'AZA3245',
#                       'number': '3245'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'KL5257',
#                       'icao': 'KLM5257',
#                       'number': '5257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AF2905',
#                       'icao': 'AFR2905',
#                       'number': '2905'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A17C12',
#                         'registration': 'N195PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5043',
#                       'icao': 'DAL5043',
#                       'number': '5043'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Outagamie County',
#                          'delay': 3,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'VS2310',
#                       'icao': 'VIR2310',
#                       'number': '2310'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'KL6393',
#                       'icao': 'KLM6393',
#                       'number': '6393'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'AF2331',
#                       'icao': 'AFR2331',
#                       'number': '2331'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-22T17:25:00+00:00',
#                        'actual_runway': '2021-04-22T17:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '10',
#                        'delay': None,
#                        'estimated': '2021-04-22T17:50:00+00:00',
#                        'estimated_runway': '2021-04-22T17:25:00+00:00',
#                        'gate': 'T11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T17:50:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:35:00+00:00',
#                          'actual_runway': '2021-04-22T16:35:00+00:00',
#                          'airport': 'Charlotte Douglas',
#                          'delay': 12,
#                          'estimated': '2021-04-22T16:24:00+00:00',
#                          'estimated_runway': '2021-04-22T16:35:00+00:00',
#                          'gate': 'E14',
#                          'iata': 'CLT',
#                          'icao': 'KCLT',
#                          'scheduled': '2021-04-22T16:24:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA5360',
#                       'icao': 'AAL5360',
#                       'number': '5360'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'ADA16F',
#                         'registration': 'N978AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 5,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 6,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'AF2912',
#                       'icao': 'AFR2912',
#                       'number': '2912'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'KL5503',
#                       'icao': 'KLM5503',
#                       'number': '5503'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'VS2506',
#                       'icao': 'VIR2506',
#                       'number': '2506'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5131',
#                       'icao': 'DAL5131',
#                       'number': '5131'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A320',
#                         'icao': 'A320',
#                         'icao24': 'A3E5FA',
#                         'registration': 'N350NA'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:58:00+00:00',
#                        'actual_runway': '2021-04-22T19:58:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-22T20:26:00+00:00',
#                        'estimated_runway': '2021-04-22T19:58:00+00:00',
#                        'gate': 'T5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T20:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:18:00+00:00',
#                          'actual_runway': '2021-04-22T13:18:00+00:00',
#                          'airport': 'Spokane International',
#                          'delay': 8,
#                          'estimated': '2021-04-22T13:11:00+00:00',
#                          'estimated_runway': '2021-04-22T13:18:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'GEG',
#                          'icao': 'KGEG',
#                          'scheduled': '2021-04-22T13:11:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL499',
#                       'icao': 'DAL499',
#                       'number': '499'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5053',
#                       'icao': 'DAL5053',
#                       'number': '5053'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Eglin AFB',
#                          'delay': 3,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'VS2709',
#                       'icao': 'VIR2709',
#                       'number': '2709'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'WS7266',
#                       'icao': 'WJA7266',
#                       'number': '7266'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'KL6306',
#                       'icao': 'KLM6306',
#                       'number': '6306'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'AF2897',
#                       'icao': 'AFR2897',
#                       'number': '2897'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-22T18:09:00+00:00',
#                        'actual_runway': '2021-04-22T18:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:15:00+00:00',
#                        'estimated_runway': '2021-04-22T18:09:00+00:00',
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:20:00+00:00',
#                          'actual_runway': '2021-04-22T17:20:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 21,
#                          'estimated': '2021-04-22T17:00:00+00:00',
#                          'estimated_runway': '2021-04-22T17:20:00+00:00',
#                          'gate': 'C2',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T17:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN917',
#                       'icao': 'SWA917',
#                       'number': '917'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T17:51:00+00:00',
#                        'actual_runway': '2021-04-22T17:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:09:00+00:00',
#                        'estimated_runway': '2021-04-22T17:51:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:09:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:02:00+00:00',
#                          'actual_runway': '2021-04-22T17:02:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 8,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T17:02:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
# ...
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4829',
#                       'icao': 'DAL4829',
#                       'number': '4829'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'VS5418',
#                       'icao': 'VIR5418',
#                       'number': '5418'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'KL5011',
#                       'icao': 'KLM5011',
#                       'number': '5011'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AM3537',
#                       'icao': 'AMX3537',
#                       'number': '3537'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AF2341',
#                       'icao': 'AFR2341',
#                       'number': '2341'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5409',
#                       'icao': 'DAL5409',
#                       'number': '5409'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'KL5797',
#                       'icao': 'KLM5797',
#                       'number': '5797'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'AM3601',
#                       'icao': 'AMX3601',
#                       'number': '3601'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3165}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data3_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data3_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data3_df])
joined_df_merge.head(300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 295           KL          KLM  Hartsfield-jackson Atlanta International
# 296           AM          AMX  Hartsfield-jackson Atlanta International
# 297           WS          WJA  Hartsfield-jackson Atlanta International
# 298           AS          ASA  Hartsfield-jackson Atlanta International
# 299           VS          VIR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 295       NaN            S      B14        NW Florida Beaches Int
# 296       NaN            S      B14        NW Florida Beaches Int
# 297       NaN            S      B14        NW Florida Beaches Int
# 298       NaN            S      B32  Cincinnati/Northern Kentucky
# 299       NaN            S      B32  Cincinnati/Northern Kentucky
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 295         None        4
# 296         None        4
# 297         None        4
# 298            3      B15
# 299            3      B15
#
# [300 rows x 9 columns]

# %%
########################4.21.2021###################################400
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-21'
    
}

api_0421 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0421.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A3A9B6',
#                         'registration': 'N335PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:44:00+00:00',
#                          'actual_runway': '2021-04-21T12:44:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 13,
#                          'estimated': '2021-04-21T12:31:00+00:00',
#                          'estimated_runway': '2021-04-21T12:44:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-21T12:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4930',
#                       'icao': 'DAL4930',
#                       'number': '4930'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:44:00+00:00',
#                          'actual_runway': '2021-04-21T12:44:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 13,
#                          'estimated': '2021-04-21T12:31:00+00:00',
#                          'estimated_runway': '2021-04-21T12:44:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-21T12:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4930',
#                                      'flight_icao': 'dal4930',
#                                      'flight_number': '4930'},
#                       'iata': 'WS6531',
#                       'icao': 'WJA6531',
#                       'number': '6531'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:44:00+00:00',
#                          'actual_runway': '2021-04-21T12:44:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 13,
#                          'estimated': '2021-04-21T12:31:00+00:00',
#                          'estimated_runway': '2021-04-21T12:44:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-21T12:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4930',
#                                      'flight_icao': 'dal4930',
#                                      'flight_number': '4930'},
#                       'iata': 'VS2546',
#                       'icao': 'VIR2546',
#                       'number': '2546'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:44:00+00:00',
#                          'actual_runway': '2021-04-21T12:44:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 13,
#                          'estimated': '2021-04-21T12:31:00+00:00',
#                          'estimated_runway': '2021-04-21T12:44:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-21T12:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4930',
#                                      'flight_icao': 'dal4930',
#                                      'flight_number': '4930'},
#                       'iata': 'KL6399',
#                       'icao': 'KLM6399',
#                       'number': '6399'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:44:00+00:00',
#                          'actual_runway': '2021-04-21T12:44:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 13,
#                          'estimated': '2021-04-21T12:31:00+00:00',
#                          'estimated_runway': '2021-04-21T12:44:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-21T12:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4930',
#                                      'flight_icao': 'dal4930',
#                                      'flight_number': '4930'},
#                       'iata': 'AM3246',
#                       'icao': 'AMX3246',
#                       'number': '3246'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T13:53:00+00:00',
#                        'actual_runway': '2021-04-21T13:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T13:57:00+00:00',
#                        'estimated_runway': '2021-04-21T13:53:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:25:00+00:00',
#                          'actual_runway': '2021-04-21T13:25:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 30,
#                          'estimated': '2021-04-21T12:55:00+00:00',
#                          'estimated_runway': '2021-04-21T13:25:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-21T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5409',
#                       'icao': 'DAL5409',
#                       'number': '5409'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-21T13:53:00+00:00',
#                        'actual_runway': '2021-04-21T13:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T13:57:00+00:00',
#                        'estimated_runway': '2021-04-21T13:53:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:25:00+00:00',
#                          'actual_runway': '2021-04-21T13:25:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 30,
#                          'estimated': '2021-04-21T12:55:00+00:00',
#                          'estimated_runway': '2021-04-21T13:25:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-21T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'VS4370',
#                       'icao': 'VIR4370',
#                       'number': '4370'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-21T13:53:00+00:00',
#                        'actual_runway': '2021-04-21T13:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T13:57:00+00:00',
#                        'estimated_runway': '2021-04-21T13:53:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:25:00+00:00',
#                          'actual_runway': '2021-04-21T13:25:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 30,
#                          'estimated': '2021-04-21T12:55:00+00:00',
#                          'estimated_runway': '2021-04-21T13:25:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-21T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'KL5797',
#                       'icao': 'KLM5797',
#                       'number': '5797'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T13:53:00+00:00',
#                        'actual_runway': '2021-04-21T13:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T13:57:00+00:00',
#                        'estimated_runway': '2021-04-21T13:53:00+00:00',
#                        'gate': 'D14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:25:00+00:00',
#                          'actual_runway': '2021-04-21T13:25:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 30,
#                          'estimated': '2021-04-21T12:55:00+00:00',
#                          'estimated_runway': '2021-04-21T13:25:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-21T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'AM3601',
#                       'icao': 'AMX3601',
#                       'number': '3601'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A321',
#                         'icao': 'A321',
#                         'icao24': 'A3A8BA',
#                         'registration': 'N335DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T16:16:00+00:00',
#                        'actual_runway': '2021-04-21T16:16:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-21T16:58:00+00:00',
#                        'estimated_runway': '2021-04-21T16:16:00+00:00',
#                        'gate': 'B22',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T16:58:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T09:47:00+00:00',
#                          'actual_runway': '2021-04-21T09:47:00+00:00',
#                          'airport': 'Los Angeles International',
#                          'delay': 7,
#                          'estimated': '2021-04-21T09:40:00+00:00',
#                          'estimated_runway': '2021-04-21T09:47:00+00:00',
#                          'gate': '28',
#                          'iata': 'LAX',
#                          'icao': 'KLAX',
#                          'scheduled': '2021-04-21T09:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL358',
#                       'icao': 'DAL358',
#                       'number': '358'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-21T14:22:00+00:00',
#                        'actual_runway': '2021-04-21T14:22:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:45:00+00:00',
#                        'estimated_runway': '2021-04-21T14:22:00+00:00',
#                        'gate': 'D8',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:54:00+00:00',
#                          'actual_runway': '2021-04-21T12:54:00+00:00',
#                          'airport': 'Municipal/Baer Field',
#                          'delay': 6,
#                          'estimated': '2021-04-21T12:48:00+00:00',
#                          'estimated_runway': '2021-04-21T12:54:00+00:00',
#                          'gate': '5',
#                          'iata': 'FWA',
#                          'icao': 'KFWA',
#                          'scheduled': '2021-04-21T12:48:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Indiana/Indianapolis'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5128',
#                                      'flight_icao': 'dal5128',
#                                      'flight_number': '5128'},
#                       'iata': 'WS6710',
#                       'icao': 'WJA6710',
#                       'number': '6710'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-21T14:22:00+00:00',
#                        'actual_runway': '2021-04-21T14:22:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:45:00+00:00',
#                        'estimated_runway': '2021-04-21T14:22:00+00:00',
#                        'gate': 'D8',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:54:00+00:00',
#                          'actual_runway': '2021-04-21T12:54:00+00:00',
#                          'airport': 'Municipal/Baer Field',
#                          'delay': 6,
#                          'estimated': '2021-04-21T12:48:00+00:00',
#                          'estimated_runway': '2021-04-21T12:54:00+00:00',
#                          'gate': '5',
#                          'iata': 'FWA',
#                          'icao': 'KFWA',
#                          'scheduled': '2021-04-21T12:48:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Indiana/Indianapolis'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5128',
#                                      'flight_icao': 'dal5128',
#                                      'flight_number': '5128'},
#                       'iata': 'KL6359',
#                       'icao': 'KLM6359',
#                       'number': '6359'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T14:22:00+00:00',
#                        'actual_runway': '2021-04-21T14:22:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:45:00+00:00',
#                        'estimated_runway': '2021-04-21T14:22:00+00:00',
#                        'gate': 'D8',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:54:00+00:00',
#                          'actual_runway': '2021-04-21T12:54:00+00:00',
#                          'airport': 'Municipal/Baer Field',
#                          'delay': 6,
#                          'estimated': '2021-04-21T12:48:00+00:00',
#                          'estimated_runway': '2021-04-21T12:54:00+00:00',
#                          'gate': '5',
#                          'iata': 'FWA',
#                          'icao': 'KFWA',
#                          'scheduled': '2021-04-21T12:48:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Indiana/Indianapolis'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5128',
#                                      'flight_icao': 'dal5128',
#                                      'flight_number': '5128'},
#                       'iata': 'AM3514',
#                       'icao': 'AMX3514',
#                       'number': '3514'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T13:55:00+00:00',
#                        'actual_runway': '2021-04-21T13:55:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:20:00+00:00',
#                        'estimated_runway': '2021-04-21T13:55:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:18:00+00:00',
#                          'actual_runway': '2021-04-21T13:18:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-21T13:09:00+00:00',
#                          'estimated_runway': '2021-04-21T13:18:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-21T13:09:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4786',
#                       'icao': 'DAL4786',
#                       'number': '4786'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-21T13:55:00+00:00',
#                        'actual_runway': '2021-04-21T13:55:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:20:00+00:00',
#                        'estimated_runway': '2021-04-21T13:55:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:18:00+00:00',
#                          'actual_runway': '2021-04-21T13:18:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-21T13:09:00+00:00',
#                          'estimated_runway': '2021-04-21T13:18:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-21T13:09:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4786',
#                                      'flight_icao': 'dal4786',
#                                      'flight_number': '4786'},
#                       'iata': 'WS6675',
#                       'icao': 'WJA6675',
#                       'number': '6675'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-21T13:55:00+00:00',
#                        'actual_runway': '2021-04-21T13:55:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:20:00+00:00',
#                        'estimated_runway': '2021-04-21T13:55:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:18:00+00:00',
#                          'actual_runway': '2021-04-21T13:18:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-21T13:09:00+00:00',
#                          'estimated_runway': '2021-04-21T13:18:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-21T13:09:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4786',
#                                      'flight_icao': 'dal4786',
#                                      'flight_number': '4786'},
#                       'iata': 'VS2779',
#                       'icao': 'VIR2779',
#                       'number': '2779'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T13:55:00+00:00',
#                        'actual_runway': '2021-04-21T13:55:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:20:00+00:00',
#                        'estimated_runway': '2021-04-21T13:55:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:18:00+00:00',
#                          'actual_runway': '2021-04-21T13:18:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-21T13:09:00+00:00',
#                          'estimated_runway': '2021-04-21T13:18:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-21T13:09:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4786',
#                                      'flight_icao': 'dal4786',
#                                      'flight_number': '4786'},
#                       'iata': 'AM3378',
#                       'icao': 'AMX3378',
#                       'number': '3378'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2030',
#                       'icao': 'DAL2030',
#                       'number': '2030'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2030',
#                                      'flight_icao': 'dal2030',
#                                      'flight_number': '2030'},
#                       'iata': 'WS6552',
#                       'icao': 'WJA6552',
#                       'number': '6552'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2030',
#                                      'flight_icao': 'dal2030',
#                                      'flight_number': '2030'},
#                       'iata': 'VS4352',
#                       'icao': 'VIR4352',
#                       'number': '4352'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2030',
#                                      'flight_icao': 'dal2030',
#                                      'flight_number': '2030'},
#                       'iata': 'KL5557',
#                       'icao': 'KLM5557',
#                       'number': '5557'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2030',
#                                      'flight_icao': 'dal2030',
#                                      'flight_number': '2030'},
#                       'iata': 'AM3469',
#                       'icao': 'AMX3469',
#                       'number': '3469'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-21T13:56:00+00:00',
#                        'actual_runway': '2021-04-21T13:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:19:00+00:00',
#                        'estimated_runway': '2021-04-21T13:56:00+00:00',
#                        'gate': 'B06',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:19:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T12:46:00+00:00',
#                          'actual_runway': '2021-04-21T12:46:00+00:00',
#                          'airport': 'Port Columbus International',
#                          'delay': 5,
#                          'estimated': '2021-04-21T12:41:00+00:00',
#                          'estimated_runway': '2021-04-21T12:46:00+00:00',
#                          'gate': 'C55',
#                          'iata': 'CMH',
#                          'icao': 'KCMH',
#                          'scheduled': '2021-04-21T12:41:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2030',
#                                      'flight_icao': 'dal2030',
#                                      'flight_number': '2030'},
#                       'iata': 'AF2593',
#                       'icao': 'AFR2593',
#                       'number': '2593'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T14:27:00+00:00',
#                        'actual_runway': '2021-04-21T14:27:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:45:00+00:00',
#                        'estimated_runway': '2021-04-21T14:27:00+00:00',
#                        'gate': 'B24',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T13:04:00+00:00',
#                          'actual_runway': '2021-04-21T13:04:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 4,
#                          'estimated': '2021-04-21T13:00:00+00:00',
#                          'estimated_runway': '2021-04-21T13:04:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-21T13:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1505',
#                       'icao': 'DAL1505',
#                       'number': '1505'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
# ...
#                       'icao': 'NKS1210',
#                       'number': '1210'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-21T12:00:00+00:00',
#                        'actual_runway': '2021-04-21T12:00:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-21T12:20:00+00:00',
#                        'estimated_runway': '2021-04-21T12:00:00+00:00',
#                        'gate': 'C3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T10:57:00+00:00',
#                          'actual_runway': '2021-04-21T10:57:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 12,
#                          'estimated': '2021-04-21T10:45:00+00:00',
#                          'estimated_runway': '2021-04-21T10:57:00+00:00',
#                          'gate': '109',
#                          'iata': 'MCO',
#                          'icao': 'KMCO',
#                          'scheduled': '2021-04-21T10:45:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN5730',
#                       'icao': 'SWA5730',
#                       'number': '5730'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T12:33:00+00:00',
#                        'actual_runway': '2021-04-21T12:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-21T12:59:00+00:00',
#                        'estimated_runway': '2021-04-21T12:33:00+00:00',
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T11:14:00+00:00',
#                          'actual_runway': '2021-04-21T11:14:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 8,
#                          'estimated': '2021-04-21T11:07:00+00:00',
#                          'estimated_runway': '2021-04-21T11:14:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-21T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1508',
#                                      'flight_icao': 'dal1508',
#                                      'flight_number': '1508'},
#                       'iata': 'AM3596',
#                       'icao': 'AMX3596',
#                       'number': '3596'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-21T12:33:00+00:00',
#                        'actual_runway': '2021-04-21T12:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-21T12:59:00+00:00',
#                        'estimated_runway': '2021-04-21T12:33:00+00:00',
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T11:14:00+00:00',
#                          'actual_runway': '2021-04-21T11:14:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 8,
#                          'estimated': '2021-04-21T11:07:00+00:00',
#                          'estimated_runway': '2021-04-21T11:14:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-21T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1508',
#                                      'flight_icao': 'dal1508',
#                                      'flight_number': '1508'},
#                       'iata': 'KL6959',
#                       'icao': 'KLM6959',
#                       'number': '6959'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-21T12:33:00+00:00',
#                        'actual_runway': '2021-04-21T12:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-21T12:59:00+00:00',
#                        'estimated_runway': '2021-04-21T12:33:00+00:00',
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T11:14:00+00:00',
#                          'actual_runway': '2021-04-21T11:14:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 8,
#                          'estimated': '2021-04-21T11:07:00+00:00',
#                          'estimated_runway': '2021-04-21T11:14:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-21T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1508',
#                                      'flight_icao': 'dal1508',
#                                      'flight_number': '1508'},
#                       'iata': 'VS2399',
#                       'icao': 'VIR2399',
#                       'number': '2399'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-21T12:59:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T11:14:00+00:00',
#                          'actual_runway': '2021-04-21T11:14:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 8,
#                          'estimated': '2021-04-21T11:07:00+00:00',
#                          'estimated_runway': '2021-04-21T11:14:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-21T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1508',
#                                      'flight_icao': 'dal1508',
#                                      'flight_number': '1508'},
#                       'iata': 'VS2681',
#                       'icao': 'VIR2681',
#                       'number': '2681'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'AC7AA9',
#                         'registration': 'N903DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T12:33:00+00:00',
#                        'actual_runway': '2021-04-21T12:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-21T12:59:00+00:00',
#                        'estimated_runway': '2021-04-21T12:33:00+00:00',
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T11:14:00+00:00',
#                          'actual_runway': '2021-04-21T11:14:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 8,
#                          'estimated': '2021-04-21T11:07:00+00:00',
#                          'estimated_runway': '2021-04-21T11:14:00+00:00',
#                          'gate': 'B14',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-21T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1508',
#                       'icao': 'DAL1508',
#                       'number': '1508'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-21T11:34:00+00:00',
#                        'actual_runway': '2021-04-21T11:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-21T11:52:00+00:00',
#                        'estimated_runway': '2021-04-21T11:34:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T11:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T10:00:00+00:00',
#                          'actual_runway': '2021-04-21T10:00:00+00:00',
#                          'airport': 'Birmingham',
#                          'delay': 10,
#                          'estimated': '2021-04-21T09:50:00+00:00',
#                          'estimated_runway': '2021-04-21T10:00:00+00:00',
#                          'gate': 'A4',
#                          'iata': 'BHM',
#                          'icao': 'KBHM',
#                          'scheduled': '2021-04-21T09:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2128',
#                                      'flight_icao': 'dal2128',
#                                      'flight_number': '2128'},
#                       'iata': 'AM3357',
#                       'icao': 'AMX3357',
#                       'number': '3357'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T11:34:00+00:00',
#                        'actual_runway': '2021-04-21T11:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-21T11:52:00+00:00',
#                        'estimated_runway': '2021-04-21T11:34:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T11:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-21T10:00:00+00:00',
#                          'actual_runway': '2021-04-21T10:00:00+00:00',
#                          'airport': 'Birmingham',
#                          'delay': 10,
#                          'estimated': '2021-04-21T09:50:00+00:00',
#                          'estimated_runway': '2021-04-21T10:00:00+00:00',
#                          'gate': 'A4',
#                          'iata': 'BHM',
#                          'icao': 'KBHM',
#                          'scheduled': '2021-04-21T09:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2128',
#                       'icao': 'DAL2128',
#                       'number': '2128'},
#            'flight_date': '2021-04-21',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 2827}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data4_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data4_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data4_df])
joined_df_merge.head(400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 395          ATL         KATL                                       NaN
# 396          ATL         KATL                                       NaN
# 397          ATL         KATL                                       NaN
# 398          ATL         KATL                                       NaN
# 399          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 395       NaN          NaN      NaN                           NaN
# 396       NaN          NaN      NaN                           NaN
# 397       NaN          NaN      NaN                           NaN
# 398       NaN          NaN      NaN                           NaN
# 399       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 395          NaN      NaN
# 396          NaN      NaN
# 397          NaN      NaN
# 398          NaN      NaN
# 399          NaN      NaN
#
# [400 rows x 9 columns]

# %%
########################4.20.2021###################################500
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-20'
    
}

api_0420 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0420.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2357',
#                       'icao': 'DAL2357',
#                       'number': '2357'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'AZ3361',
#                       'icao': 'AZA3361',
#                       'number': '3361'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'WS6934',
#                       'icao': 'WJA6934',
#                       'number': '6934'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'VS2257',
#                       'icao': 'VIR2257',
#                       'number': '2257'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'KL5511',
#                       'icao': 'KLM5511',
#                       'number': '5511'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'AF3491',
#                       'icao': 'AFR3491',
#                       'number': '3491'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1480',
#                                      'flight_icao': 'dal1480',
#                                      'flight_number': '1480'},
#                       'iata': 'AM3589',
#                       'icao': 'AMX3589',
#                       'number': '3589'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1480',
#                                      'flight_icao': 'dal1480',
#                                      'flight_number': '1480'},
#                       'iata': 'KE3723',
#                       'icao': 'KAL3723',
#                       'number': '3723'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'AB2B23',
#                         'registration': 'N819DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1480',
#                       'icao': 'DAL1480',
#                       'number': '1480'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1172',
#                                      'flight_icao': 'dal1172',
#                                      'flight_number': '1172'},
#                       'iata': 'AM4319',
#                       'icao': 'AMX4319',
#                       'number': '4319'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1172',
#                                      'flight_icao': 'dal1172',
#                                      'flight_number': '1172'},
#                       'iata': 'KE3667',
#                       'icao': 'KAL3667',
#                       'number': '3667'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1172',
#                       'icao': 'DAL1172',
#                       'number': '1172'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:31:00+00:00',
#                        'actual_runway': '2021-04-20T07:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:31:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:19:00+00:00',
#                          'actual_runway': '2021-04-20T06:19:00+00:00',
#                          'airport': 'Albert J Ellis',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:19:00+00:00',
#                          'gate': '02',
#                          'iata': 'OAJ',
#                          'icao': 'KOAJ',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4830',
#                                      'flight_icao': 'dal4830',
#                                      'flight_number': '4830'},
#                       'iata': 'KE6980',
#                       'icao': 'KAL6980',
#                       'number': '6980'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:31:00+00:00',
#                        'actual_runway': '2021-04-20T07:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:31:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:19:00+00:00',
#                          'actual_runway': '2021-04-20T06:19:00+00:00',
#                          'airport': 'Albert J Ellis',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:19:00+00:00',
#                          'gate': '02',
#                          'iata': 'OAJ',
#                          'icao': 'KOAJ',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4830',
#                       'icao': 'DAL4830',
#                       'number': '4830'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:29:00+00:00',
#                        'actual_runway': '2021-04-20T07:29:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:29:00+00:00',
#                        'gate': 'B7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Sarasota/Bradenton International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'SRQ',
#                          'icao': 'KSRQ',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2272',
#                                      'flight_icao': 'dal2272',
#                                      'flight_number': '2272'},
#                       'iata': 'AM3490',
#                       'icao': 'AMX3490',
#                       'number': '3490'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A321',
#                         'icao': 'A321',
#                         'icao24': 'A3FB6F',
#                         'registration': 'N356DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:29:00+00:00',
#                        'actual_runway': '2021-04-20T07:29:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:29:00+00:00',
#                        'gate': 'B7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Sarasota/Bradenton International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'SRQ',
#                          'icao': 'KSRQ',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2272',
#                       'icao': 'DAL2272',
#                       'number': '2272'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'AM3809',
#                       'icao': 'AMX3809',
#                       'number': '3809'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'KE3566',
#                       'icao': 'KAL3566',
#                       'number': '3566'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'KL6600',
#                       'icao': 'KLM6600',
#                       'number': '6600'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'VS2261',
#                       'icao': 'VIR2261',
#                       'number': '2261'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2647',
#                       'icao': 'DAL2647',
#                       'number': '2647'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:06:00+00:00',
#                        'actual_runway': '2021-04-20T08:06:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:28:00+00:00',
#                        'estimated_runway': '2021-04-20T08:06:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:10:00+00:00',
#                          'actual_runway': '2021-04-20T06:10:00+00:00',
#                          'airport': 'John F Kennedy International',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:10:00+00:00',
#                          'gate': 'B38',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': '4',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL424',
#                       'icao': 'DAL424',
#                       'number': '424'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:21:00+00:00',
#                        'actual_runway': '2021-04-20T08:21:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:42:00+00:00',
#                        'estimated_runway': '2021-04-20T08:21:00+00:00',
#                        'gate': 'B11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:42:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Bradley International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': '12',
#                          'iata': 'BDL',
#                          'icao': 'KBDL',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1198',
#                                      'flight_icao': 'dal1198',
#                                      'flight_number': '1198'},
#                       'iata': 'AM5585',
#                       'icao': 'AMX5585',
#                       'number': '5585'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD4395',
#                         'registration': 'N954AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:21:00+00:00',
#                        'actual_runway': '2021-04-20T08:21:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:42:00+00:00',
#                        'estimated_runway': '2021-04-20T08:21:00+00:00',
#                        'gate': 'B11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:42:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Bradley International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': '12',
#                          'iata': 'BDL',
#                          'icao': 'KBDL',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1198',
#                       'icao': 'DAL1198',
#                       'number': '1198'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:38:00+00:00',
#                        'actual_runway': '2021-04-20T07:38:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:10:00+00:00',
# ...
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1458',
#                                      'flight_icao': 'dal1458',
#                                      'flight_number': '1458'},
#                       'iata': 'AM3351',
#                       'icao': 'AMX3351',
#                       'number': '3351'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:45:00+00:00',
#                        'actual_runway': '2021-04-20T07:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:05:00+00:00',
#                        'estimated_runway': '2021-04-20T07:45:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1458',
#                                      'flight_icao': 'dal1458',
#                                      'flight_number': '1458'},
#                       'iata': 'KE3718',
#                       'icao': 'KAL3718',
#                       'number': '3718'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD6B14',
#                         'registration': 'N964AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:45:00+00:00',
#                        'actual_runway': '2021-04-20T07:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:05:00+00:00',
#                        'estimated_runway': '2021-04-20T07:45:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1458',
#                       'icao': 'DAL1458',
#                       'number': '1458'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1647',
#                                      'flight_icao': 'dal1647',
#                                      'flight_number': '1647'},
#                       'iata': 'AM5132',
#                       'icao': 'AMX5132',
#                       'number': '5132'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1647',
#                                      'flight_icao': 'dal1647',
#                                      'flight_number': '1647'},
#                       'iata': 'KE3797',
#                       'icao': 'KAL3797',
#                       'number': '3797'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A321',
#                         'icao': 'A321',
#                         'icao24': 'A3BDA6',
#                         'registration': 'N340DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1647',
#                       'icao': 'DAL1647',
#                       'number': '1647'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:15:00+00:00',
#                        'actual_runway': '2021-04-20T08:15:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:34:00+00:00',
#                        'estimated_runway': '2021-04-20T08:15:00+00:00',
#                        'gate': 'A27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:13:00+00:00',
#                          'actual_runway': '2021-04-20T07:13:00+00:00',
#                          'airport': 'Raleigh-durham International Airport',
#                          'delay': 13,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:13:00+00:00',
#                          'gate': 'C1',
#                          'iata': 'RDU',
#                          'icao': 'KRDU',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1585',
#                                      'flight_icao': 'dal1585',
#                                      'flight_number': '1585'},
#                       'iata': 'AM3814',
#                       'icao': 'AMX3814',
#                       'number': '3814'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:15:00+00:00',
#                        'actual_runway': '2021-04-20T08:15:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:34:00+00:00',
#                        'estimated_runway': '2021-04-20T08:15:00+00:00',
#                        'gate': 'A27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:13:00+00:00',
#                          'actual_runway': '2021-04-20T07:13:00+00:00',
#                          'airport': 'Raleigh-durham International Airport',
#                          'delay': 13,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:13:00+00:00',
#                          'gate': 'C1',
#                          'iata': 'RDU',
#                          'icao': 'KRDU',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1585',
#                                      'flight_icao': 'dal1585',
#                                      'flight_number': '1585'},
#                       'iata': 'KE3732',
#                       'icao': 'KAL3732',
#                       'number': '3732'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 2864}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data5_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data5_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data5_df])
joined_df_merge.head(500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 495          ATL         KATL                                       NaN
# 496          ATL         KATL                                       NaN
# 497          ATL         KATL                                       NaN
# 498          ATL         KATL                                       NaN
# 499          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 495       NaN          NaN      NaN                           NaN
# 496       NaN          NaN      NaN                           NaN
# 497       NaN          NaN      NaN                           NaN
# 498       NaN          NaN      NaN                           NaN
# 499       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 495          NaN      NaN
# 496          NaN      NaN
# 497          NaN      NaN
# 498          NaN      NaN
# 499          NaN      NaN
#
# [500 rows x 9 columns]

# %%
########################4.19.2021###################################600
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-19'
    
}

api_0419 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0419.json()

#pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:34:00+00:00',
#                        'actual_runway': '2021-04-19T12:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:56:00+00:00',
#                        'estimated_runway': '2021-04-19T12:34:00+00:00',
#                        'gate': 'T08',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:56:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:17:00+00:00',
#                          'actual_runway': '2021-04-19T11:17:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T11:07:00+00:00',
#                          'estimated_runway': '2021-04-19T11:17:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1448',
#                                      'flight_icao': 'dal1448',
#                                      'flight_number': '1448'},
#                       'iata': 'VS2674',
#                       'icao': 'VIR2674',
#                       'number': '2674'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:52:00+00:00',
#                        'actual_runway': '2021-04-19T20:52:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T21:15:00+00:00',
#                        'estimated_runway': '2021-04-19T20:52:00+00:00',
#                        'gate': 'E26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T21:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T19:35:00+00:00',
#                          'actual_runway': '2021-04-19T19:35:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 5,
#                          'estimated': '2021-04-19T19:30:00+00:00',
#                          'estimated_runway': '2021-04-19T19:35:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T19:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1492',
#                                      'flight_icao': 'dal1492',
#                                      'flight_number': '1492'},
#                       'iata': 'KL5161',
#                       'icao': 'KLM5161',
#                       'number': '5161'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:34:00+00:00',
#                        'actual_runway': '2021-04-19T12:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:56:00+00:00',
#                        'estimated_runway': '2021-04-19T12:34:00+00:00',
#                        'gate': 'T08',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:56:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:17:00+00:00',
#                          'actual_runway': '2021-04-19T11:17:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T11:07:00+00:00',
#                          'estimated_runway': '2021-04-19T11:17:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1448',
#                       'icao': 'DAL1448',
#                       'number': '1448'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A333',
#                         'icao': 'A333',
#                         'icao24': '484FFF',
#                         'registration': 'PH-AKE'},
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:03:00+00:00',
#                        'actual_runway': '2021-04-19T20:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': 'F1',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:30:00+00:00',
#                        'estimated_runway': '2021-04-19T20:03:00+00:00',
#                        'gate': 'E14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:30:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:59:00+00:00',
#                          'actual_runway': '2021-04-19T16:59:00+00:00',
#                          'airport': 'Schiphol',
#                          'delay': None,
#                          'estimated': '2021-04-19T17:00:00+00:00',
#                          'estimated_runway': '2021-04-19T16:59:00+00:00',
#                          'gate': 'D43',
#                          'iata': 'AMS',
#                          'icao': 'EHAM',
#                          'scheduled': '2021-04-19T17:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Europe/Amsterdam'},
#            'flight': {'codeshared': None,
#                       'iata': 'KL621',
#                       'icao': 'KLM621',
#                       'number': '621'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A319',
#                         'icao': 'A319',
#                         'icao24': 'A3D4C6',
#                         'registration': 'N346NB'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T18:05:00+00:00',
#                        'actual_runway': '2021-04-19T18:05:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': 39,
#                        'estimated': '2021-04-19T17:26:00+00:00',
#                        'estimated_runway': '2021-04-19T18:05:00+00:00',
#                        'gate': 'T04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T17:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:22:00+00:00',
#                          'actual_runway': '2021-04-19T16:22:00+00:00',
#                          'airport': 'International',
#                          'delay': 56,
#                          'estimated': '2021-04-19T15:26:00+00:00',
#                          'estimated_runway': '2021-04-19T16:22:00+00:00',
#                          'gate': 'ARR',
#                          'iata': 'EYW',
#                          'icao': 'KEYW',
#                          'scheduled': '2021-04-19T15:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2371',
#                       'icao': 'DAL2371',
#                       'number': '2371'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T18:05:00+00:00',
#                        'actual_runway': '2021-04-19T18:05:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': 39,
#                        'estimated': '2021-04-19T17:26:00+00:00',
#                        'estimated_runway': '2021-04-19T18:05:00+00:00',
#                        'gate': 'T04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T17:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:22:00+00:00',
#                          'actual_runway': '2021-04-19T16:22:00+00:00',
#                          'airport': 'International',
#                          'delay': 56,
#                          'estimated': '2021-04-19T15:26:00+00:00',
#                          'estimated_runway': '2021-04-19T16:22:00+00:00',
#                          'gate': 'ARR',
#                          'iata': 'EYW',
#                          'icao': 'KEYW',
#                          'scheduled': '2021-04-19T15:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2371',
#                                      'flight_icao': 'dal2371',
#                                      'flight_number': '2371'},
#                       'iata': 'KL5807',
#                       'icao': 'KLM5807',
#                       'number': '5807'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4791',
#                                      'flight_icao': 'dal4791',
#                                      'flight_number': '4791'},
#                       'iata': 'KL6911',
#                       'icao': 'KLM6911',
#                       'number': '6911'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4791',
#                                      'flight_icao': 'dal4791',
#                                      'flight_number': '4791'},
#                       'iata': 'VS2811',
#                       'icao': 'VIR2811',
#                       'number': '2811'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4791',
#                       'icao': 'DAL4791',
#                       'number': '4791'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'AF2095',
#                       'icao': 'AFR2095',
#                       'number': '2095'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'KL6367',
#                       'icao': 'KLM6367',
#                       'number': '6367'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Harrisburg International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'VS2226',
#                       'icao': 'VIR2226',
#                       'number': '2226'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4847',
#                       'icao': 'DAL4847',
#                       'number': '4847'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 32,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'AF3726',
#                       'icao': 'AFR3726',
#                       'number': '3726'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 4,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '13',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4759',
#                                      'flight_icao': 'dal4759',
#                                      'flight_number': '4759'},
#                       'iata': 'KL6811',
#                       'icao': 'KLM6811',
#                       'number': '6811'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 9,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'KL5223',
#                       'icao': 'KLM5223',
#                       'number': '5223'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 9,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'VS3209',
#                       'icao': 'VIR3209',
#                       'number': '3209'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 32,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2038',
#                       'icao': 'DAL2038',
#                       'number': '2038'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': 53,
#                        'estimated': '2021-04-19T13:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T13:15:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T13:33:00+00:00',
#                          'actual_runway': '2021-04-19T13:33:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 78,
#                          'estimated': '2021-04-19T12:15:00+00:00',
#                          'estimated_runway': '2021-04-19T13:33:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-19T12:15:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5559',
#                       'icao': 'DAL5559',
#                       'number': '5559'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'AF5873',
#                       'icao': 'AFR5873',
#                       'number': '5873'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'KL5669',
#                       'icao': 'KLM5669',
#                       'number': '5669'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'VS5122',
#                       'icao': 'VIR5122',
#                       'number': '5122'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:41:00+00:00',
#                        'actual_runway': '2021-04-19T19:41:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': '2021-04-19T19:41:00+00:00',
#                        'gate': 'B10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:09:00+00:00',
#                          'actual_runway': '2021-04-19T17:09:00+00:00',
#                          'airport': 'William P Hobby',
#                          'delay': 5,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': '2021-04-19T17:09:00+00:00',
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1720',
#                       'icao': 'DAL1720',
#                       'number': '1720'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B737',
#                         'icao': 'B737',
#                         'icao24': 'A2BB10',
#                         'registration': 'N275WN'},
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-19T20:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:22:00+00:00',
#                          'actual_runway': '2021-04-19T17:22:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 28,
#                          'estimated': '2021-04-19T16:55:00+00:00',
#                          'estimated_runway': '2021-04-19T17:22:00+00:00',
#                          'gate': '16',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-19T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN189',
#                       'icao': 'SWA189',
#                       'number': '189'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': {'altitude': 8938.26,
#                     'direction': 138.32,
#                     'is_ground': True,
#                     'latitude': 33.64,
#                     'longitude': -84.43,
#                     'speed_horizontal': 927.432,
#                     'speed_vertical': -47.988,
#                     'updated': '2021-04-20T01:33:58+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T18:33:00+00:00',
#                        'actual_runway': '2021-04-19T18:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:50:00+00:00',
#                        'estimated_runway': '2021-04-19T18:33:00+00:00',
#                        'gate': 'B34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:50:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:58:00+00:00',
#                          'actual_runway': '2021-04-19T17:58:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 18,
#                          'estimated': '2021-04-19T17:40:00+00:00',
#                          'estimated_runway': '2021-04-19T17:58:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-19T17:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
# ...
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5287',
#                                      'flight_icao': 'dal5287',
#                                      'flight_number': '5287'},
#                       'iata': 'VS2959',
#                       'icao': 'VIR2959',
#                       'number': '2959'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5287',
#                                      'flight_icao': 'dal5287',
#                                      'flight_number': '5287'},
#                       'iata': 'WS6721',
#                       'icao': 'WJA6721',
#                       'number': '6721'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:54:00+00:00',
#                        'actual_runway': '2021-04-19T20:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T21:28:00+00:00',
#                        'estimated_runway': '2021-04-19T20:54:00+00:00',
#                        'gate': 'D9A',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T21:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T19:01:00+00:00',
#                          'actual_runway': '2021-04-19T19:01:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 7,
#                          'estimated': '2021-04-19T18:55:00+00:00',
#                          'estimated_runway': '2021-04-19T19:01:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T18:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4971',
#                                      'flight_icao': 'dal4971',
#                                      'flight_number': '4971'},
#                       'iata': 'KL5317',
#                       'icao': 'KLM5317',
#                       'number': '5317'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5287',
#                       'icao': 'DAL5287',
#                       'number': '5287'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-19T12:11:00+00:00',
#                        'actual_runway': '2021-04-19T12:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:37:00+00:00',
#                        'estimated_runway': '2021-04-19T12:11:00+00:00',
#                        'gate': 'A18',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:37:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:24:00+00:00',
#                          'actual_runway': '2021-04-19T11:24:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 4,
#                          'estimated': '2021-04-19T11:20:00+00:00',
#                          'estimated_runway': '2021-04-19T11:24:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-19T11:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1682',
#                                      'flight_icao': 'dal1682',
#                                      'flight_number': '1682'},
#                       'iata': 'WS6775',
#                       'icao': 'WJA6775',
#                       'number': '6775'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:11:00+00:00',
#                        'actual_runway': '2021-04-19T12:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:37:00+00:00',
#                        'estimated_runway': '2021-04-19T12:11:00+00:00',
#                        'gate': 'A18',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:37:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:24:00+00:00',
#                          'actual_runway': '2021-04-19T11:24:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 4,
#                          'estimated': '2021-04-19T11:20:00+00:00',
#                          'estimated_runway': '2021-04-19T11:24:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-19T11:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1682',
#                       'icao': 'DAL1682',
#                       'number': '1682'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T12:40:00+00:00',
#                        'actual_runway': '2021-04-19T12:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:59:00+00:00',
#                        'estimated_runway': '2021-04-19T12:40:00+00:00',
#                        'gate': 'D39',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:51:00+00:00',
#                          'actual_runway': '2021-04-19T11:51:00+00:00',
#                          'airport': 'Valdosta Regional Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-19T11:40:00+00:00',
#                          'estimated_runway': '2021-04-19T11:51:00+00:00',
#                          'gate': None,
#                          'iata': 'VLD',
#                          'icao': 'KVLD',
#                          'scheduled': '2021-04-19T11:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4650',
#                                      'flight_icao': 'dal4650',
#                                      'flight_number': '4650'},
#                       'iata': 'KL7207',
#                       'icao': 'KLM7207',
#                       'number': '7207'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:40:00+00:00',
#                        'actual_runway': '2021-04-19T12:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:59:00+00:00',
#                        'estimated_runway': '2021-04-19T12:40:00+00:00',
#                        'gate': 'D39',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:51:00+00:00',
#                          'actual_runway': '2021-04-19T11:51:00+00:00',
#                          'airport': 'Valdosta Regional Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-19T11:40:00+00:00',
#                          'estimated_runway': '2021-04-19T11:51:00+00:00',
#                          'gate': None,
#                          'iata': 'VLD',
#                          'icao': 'KVLD',
#                          'scheduled': '2021-04-19T11:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4650',
#                                      'flight_icao': 'dal4650',
#                                      'flight_number': '4650'},
#                       'iata': 'VS2330',
#                       'icao': 'VIR2330',
#                       'number': '2330'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 2992}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data6_df])
joined_df_merge.head(600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 595           DL          DAL                                       NaN
# 596           DL          DAL                                       NaN
# 597           WS          WJA                                       NaN
# 598           VS          VIR                                       NaN
# 599           KL          KLM                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 595       NaN          NaN      NaN                           NaN
# 596       NaN          NaN      NaN                           NaN
# 597       NaN          NaN      NaN                           NaN
# 598       NaN          NaN      NaN                           NaN
# 599       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 595          NaN      NaN
# 596          NaN      NaN
# 597          NaN      NaN
# 598          NaN      NaN
# 599          NaN      NaN
#
# [600 rows x 9 columns]

# %%
########################4.18.2021###################################700
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-18'
    
}

api_0418 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0418.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data7_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data7_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data7_df])
joined_df_merge.head(700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 695           KL          KLM                                       NaN
# 696          ATL         KATL                                       NaN
# 697           AF          AFR                                       NaN
# 698          ATL         KATL                                       NaN
# 699           DL          DAL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 695       NaN          NaN      NaN                           NaN
# 696       NaN          NaN      NaN                           NaN
# 697       NaN          NaN      NaN                           NaN
# 698       NaN          NaN      NaN                           NaN
# 699       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 695          NaN      NaN
# 696          NaN      NaN
# 697          NaN      NaN
# 698          NaN      NaN
# 699          NaN      NaN
#
# [700 rows x 9 columns]

# %%
########################4.17.2021###################################800
params = {
    'access_key': api_key,
    'arr_iata': 'ATL',
    'flight_date': '2021-04-17'
    
}

api_0417 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0417.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data8_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data8_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data8_df])
joined_df_merge.head(800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 795           WS          WJA                                       NaN
# 796          ATL         KATL                                       NaN
# 797           KL          KLM                                       NaN
# 798          ATL         KATL                                       NaN
# 799           VS          VIR                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 795       NaN          NaN      NaN                           NaN
# 796       NaN          NaN      NaN                           NaN
# 797       NaN          NaN      NaN                           NaN
# 798       NaN          NaN      NaN                           NaN
# 799       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 795          NaN      NaN
# 796          NaN      NaN
# 797          NaN      NaN
# 798          NaN      NaN
# 799          NaN      NaN
#
# [800 rows x 9 columns]

# %%
########################4.16.2021###################################900
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-16'
    
}

api_0416 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0416.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data9_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data9_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data9_df])
joined_df_merge.head(900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 895           KL          KLM                                       NaN
# 896          ATL         KATL                                       NaN
# 897           AF          AFR                                       NaN
# 898          ATL         KATL                                       NaN
# 899           DL          DAL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 895       NaN          NaN      NaN                           NaN
# 896       NaN          NaN      NaN                           NaN
# 897       NaN          NaN      NaN                           NaN
# 898       NaN          NaN      NaN                           NaN
# 899       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 895          NaN      NaN
# 896          NaN      NaN
# 897          NaN      NaN
# 898          NaN      NaN
# 899          NaN      NaN
#
# [900 rows x 9 columns]

# %%
########################4.15.2021###################################1000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
'flight_date': '2021-04-15'
    
}

api_0415 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0415.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data10_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data10_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data10_df])
joined_df_merge.head(1000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 995           WS          WJA                                       NaN
# 996          ATL         KATL                                       NaN
# 997           KL          KLM                                       NaN
# 998          ATL         KATL                                       NaN
# 999           VS          VIR                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 995       NaN          NaN      NaN                           NaN
# 996       NaN          NaN      NaN                           NaN
# 997       NaN          NaN      NaN                           NaN
# 998       NaN          NaN      NaN                           NaN
# 999       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 995          NaN      NaN
# 996          NaN      NaN
# 997          NaN      NaN
# 998          NaN      NaN
# 999          NaN      NaN
#
# [1000 rows x 9 columns]

# %%
########################4.14.2021###################################1100
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-14'
    
}

api_0414 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0414.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data11_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data11_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data11_df])
joined_df_merge.head(1100)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1095           AM          AMX                                       NaN
# 1096           DL          DAL                                       NaN
# 1097           KE          KAL                                       NaN
# 1098           AM          AMX                                       NaN
# 1099           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1095       NaN          NaN      NaN                           NaN
# 1096       NaN          NaN      NaN                           NaN
# 1097       NaN          NaN      NaN                           NaN
# 1098       NaN          NaN      NaN                           NaN
# 1099       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1095          NaN      NaN
# 1096          NaN      NaN
# 1097          NaN      NaN
# 1098          NaN      NaN
# 1099          NaN      NaN
#
# [1100 rows x 9 columns]

# %%
########################4.13.2021###################################1200
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-13'
    
}

api_0413 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0413.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data12_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data12_df])
joined_df_merge.head(1200)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 84           AF          AFR  Hartsfield-jackson Atlanta International
# 85           WS          WJA  Hartsfield-jackson Atlanta International
# 86           KL          KLM  Hartsfield-jackson Atlanta International
# 87           VS          VIR  Hartsfield-jackson Atlanta International
# 88           DL          DAL  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                              dep_airport  \
# 0         35            I     None                          Seoul (Incheon)
# 1       7851            I     None                          Seoul (Incheon)
# 2       5090            I     None                          Seoul (Incheon)
# 3       6786            S      B21             George Bush Intercontinental
# 4       5130            S      A12             George Bush Intercontinental
# ..       ...          ...      ...                                      ...
# 84      3509            S      A12  Fort Lauderdale–Hollywood International
# 85      1676            S      A12  Fort Lauderdale–Hollywood International
# 86      3705            S       E4          Pensacola International Airport
# 87      3803            S       E4          Pensacola International Airport
# 88      5254            S       E4          Pensacola International Airport
#
#    dep_terminal dep_gate
# 0             2      231
# 1             2      231
# 2             2      231
# 3             A       14
# 4             A       15
# ..          ...      ...
# 84            2       D3
# 85            2       D3
# 86         None        4
# 87         None        4
# 88         None        4
#
# [1200 rows x 9 columns]

# %%
########################4.12.2021###################################1300
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-12'
    
}

api_0412 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0412.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data13_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data13_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data13_df])
joined_df_merge.head(1300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 184           DL          DAL  Hartsfield-jackson Atlanta International
# 185           AF          AFR  Hartsfield-jackson Atlanta International
# 186           WS          WJA  Hartsfield-jackson Atlanta International
# 187           KL          KLM  Hartsfield-jackson Atlanta International
# 188           VS          VIR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# 0          35            I     None                          Seoul (Incheon)
# 1        7851            I     None                          Seoul (Incheon)
# 2        5090            I     None                          Seoul (Incheon)
# 3        6786            S      B21             George Bush Intercontinental
# 4        5130            S      A12             George Bush Intercontinental
# ..        ...          ...      ...                                      ...
# 184      1408            S      A12  Fort Lauderdale–Hollywood International
# 185      3509            S      A12  Fort Lauderdale–Hollywood International
# 186      1676            S       E4          Pensacola International Airport
# 187      3705            S       E4          Pensacola International Airport
# 188      3803            S       E4          Pensacola International Airport
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 184            2       D3
# 185            2       D3
# 186         None        4
# 187         None        4
# 188         None        4
#
# [1300 rows x 9 columns]

# %%
########################4.11.2021###################################1400
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-11'
    
}

api_0411 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0411.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data14_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data14_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data14_df])
joined_df_merge.head(1400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 284           KE          KAL  Hartsfield-jackson Atlanta International
# 285           AM          AMX  Hartsfield-jackson Atlanta International
# 286           DL          DAL  Hartsfield-jackson Atlanta International
# 287           AF          AFR  Hartsfield-jackson Atlanta International
# 288           WS          WJA  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# 0          35            I     None                          Seoul (Incheon)
# 1        7851            I     None                          Seoul (Incheon)
# 2        5090            I     None                          Seoul (Incheon)
# 3        6786            S      B21             George Bush Intercontinental
# 4        5130            S      A12             George Bush Intercontinental
# ..        ...          ...      ...                                      ...
# 284      6339            S      A12  Fort Lauderdale–Hollywood International
# 285      2557            S      A12  Fort Lauderdale–Hollywood International
# 286      4684            S       E4          Pensacola International Airport
# 287      3368            S       E4          Pensacola International Airport
# 288      6936            S       E4          Pensacola International Airport
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 284            2       D3
# 285            2       D3
# 286         None        4
# 287         None        4
# 288         None        4
#
# [1400 rows x 9 columns]

# %%
########################4.10.2021###################################1500
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-10'
    
}

api_0410 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0410.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data15_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data15_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data15_df])
joined_df_merge.head(1500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 384          ATL         KATL  Hartsfield-jackson Atlanta International
# 385          ATL         KATL  Hartsfield-jackson Atlanta International
# 386          ATL         KATL  Hartsfield-jackson Atlanta International
# 387          ATL         KATL  Hartsfield-jackson Atlanta International
# 388          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# 0          35            I     None                          Seoul (Incheon)
# 1        7851            I     None                          Seoul (Incheon)
# 2        5090            I     None                          Seoul (Incheon)
# 3        6786            S      B21             George Bush Intercontinental
# 4        5130            S      A12             George Bush Intercontinental
# ..        ...          ...      ...                                      ...
# 384      3419            S      A12  Fort Lauderdale–Hollywood International
# 385      3598            S      A12  Fort Lauderdale–Hollywood International
# 386      6339            S       E4          Pensacola International Airport
# 387      2557            S       E4          Pensacola International Airport
# 388      4684            S       E4          Pensacola International Airport
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 384            2       D3
# 385            2       D3
# 386         None        4
# 387         None        4
# 388         None        4
#
# [1500 rows x 9 columns]

# %%
########################4.09.2021###################################1600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-09'
    
}

api_0409 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0409.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data16_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data16_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data16_df])
joined_df_merge.head(1600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 484          ATL         KATL  Hartsfield-jackson Atlanta International
# 485          ATL         KATL  Hartsfield-jackson Atlanta International
# 486          ATL         KATL  Hartsfield-jackson Atlanta International
# 487          ATL         KATL  Hartsfield-jackson Atlanta International
# 488          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 484      4956            S      D42                        Yeager
# 485      1547            S      D42                        Yeager
# 486      2156            S      D42                        Yeager
# 487      5565            S      F10                 Jacksonville,
# 488      4410            S      F10                 Jacksonville,
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 484         None       B1
# 485         None       B1
# 486         None       B1
# 487         None       A9
# 488         None       A9
#
# [1600 rows x 9 columns]

# %%
########################4.08.2021###################################1700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-08'
    
}

api_0408 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0408.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data17_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data17_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data17_df])
joined_df_merge.head(1700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 584           DL          DAL  Hartsfield-jackson Atlanta International
# 585           KE          KAL  Hartsfield-jackson Atlanta International
# 586           AM          AMX  Hartsfield-jackson Atlanta International
# 587           DL          DAL  Hartsfield-jackson Atlanta International
# 588           KE          KAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 584       NaN            S      D42                        Yeager
# 585       NaN            S      D42                        Yeager
# 586       NaN            S      D42                        Yeager
# 587       NaN            S      F10                 Jacksonville,
# 588       NaN            S      F10                 Jacksonville,
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 584         None       B1
# 585         None       B1
# 586         None       B1
# 587         None       A9
# 588         None       A9
#
# [1700 rows x 9 columns]

# %%
########################4.07.2021###################################1800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-07'
    
}

api_0407 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0407.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data18_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data18_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data18_df])
joined_df_merge.head(1800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 684          ATL         KATL  Hartsfield-jackson Atlanta International
# 685           AF          AFR  Hartsfield-jackson Atlanta International
# 686          ATL         KATL  Hartsfield-jackson Atlanta International
# 687           AM          AMX  Hartsfield-jackson Atlanta International
# 688          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# 0          35            I     None                 Seoul (Incheon)
# 1        7851            I     None                 Seoul (Incheon)
# 2        5090            I     None                 Seoul (Incheon)
# 3        6786            S      B21    George Bush Intercontinental
# 4        5130            S      A12    George Bush Intercontinental
# ..        ...          ...      ...                             ...
# 684       NaN            S      B27           Bradley International
# 685       NaN            S      B27           Bradley International
# 686       NaN            S      B27           Bradley International
# 687       NaN            S      E15  Richmond International Airport
# 688       NaN            S      E15  Richmond International Airport
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 684            A       12
# 685            A       12
# 686            A       12
# 687         None      B14
# 688         None      B14
#
# [1800 rows x 9 columns]

# %%
########################4.06.2021###################################1900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-06'
    
}

api_0406 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0406.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data19_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data19_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data19_df])
joined_df_merge.head(1900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 784          ATL         KATL                                       NaN
# 785           DL          DAL                                       NaN
# 786          ATL         KATL                                       NaN
# 787           KE          KAL                                       NaN
# 788          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 784       NaN          NaN      NaN                           NaN
# 785       NaN          NaN      NaN                           NaN
# 786       NaN          NaN      NaN                           NaN
# 787       NaN          NaN      NaN                           NaN
# 788       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 784          NaN      NaN
# 785          NaN      NaN
# 786          NaN      NaN
# 787          NaN      NaN
# 788          NaN      NaN
#
# [1900 rows x 9 columns]

# %%
########################4.05.2021###################################2000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-05'
    
}

api_0405 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0405.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data20_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data20_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data20_df])
joined_df_merge.head(2000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 884          ATL         KATL                                       NaN
# 885           AF          AFR                                       NaN
# 886          ATL         KATL                                       NaN
# 887           AM          AMX                                       NaN
# 888          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 884       NaN          NaN      NaN                           NaN
# 885       NaN          NaN      NaN                           NaN
# 886       NaN          NaN      NaN                           NaN
# 887       NaN          NaN      NaN                           NaN
# 888       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 884          NaN      NaN
# 885          NaN      NaN
# 886          NaN      NaN
# 887          NaN      NaN
# 888          NaN      NaN
#
# [2000 rows x 9 columns]

# %%
########################4.04.2021###################################2100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-04'
    
}

api_0404 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0404.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data21_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data21_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data21_df])
joined_df_merge.head(2100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 984          ATL         KATL                                       NaN
# 985           DL          DAL                                       NaN
# 986          ATL         KATL                                       NaN
# 987           KE          KAL                                       NaN
# 988          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 984       NaN          NaN      NaN                           NaN
# 985       NaN          NaN      NaN                           NaN
# 986       NaN          NaN      NaN                           NaN
# 987       NaN          NaN      NaN                           NaN
# 988       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 984          NaN      NaN
# 985          NaN      NaN
# 986          NaN      NaN
# 987          NaN      NaN
# 988          NaN      NaN
#
# [2100 rows x 9 columns]

# %%
########################4.03.2021###################################2200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-03'
    
}

api_0403 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0403.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data22_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data22_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data22_df])
joined_df_merge.head(2200)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1084           KL          KLM                                       NaN
# 1085           KE          KAL                                       NaN
# 1086           AZ          AZA                                       NaN
# 1087           AF          AFR                                       NaN
# 1088           BR          EVA                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1084       NaN          NaN      NaN                           NaN
# 1085       NaN          NaN      NaN                           NaN
# 1086       NaN          NaN      NaN                           NaN
# 1087       NaN          NaN      NaN                           NaN
# 1088       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1084          NaN      NaN
# 1085          NaN      NaN
# 1086          NaN      NaN
# 1087          NaN      NaN
# 1088          NaN      NaN
#
# [2200 rows x 9 columns]

# %%
########################4.02.2021###################################2300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-02'
    
}

api_0402 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0402.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data23_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data23_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data23_df])
joined_df_merge.head(2300)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1184           LA          LAN                                       NaN
# 1185           KL          KLM                                       NaN
# 1186           KE          KAL                                       NaN
# 1187           AZ          AZA                                       NaN
# 1188           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1184       NaN          NaN      NaN                           NaN
# 1185       NaN          NaN      NaN                           NaN
# 1186       NaN          NaN      NaN                           NaN
# 1187       NaN          NaN      NaN                           NaN
# 1188       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1184          NaN      NaN
# 1185          NaN      NaN
# 1186          NaN      NaN
# 1187          NaN      NaN
# 1188          NaN      NaN
#
# [2300 rows x 9 columns]

# %%
########################4.01.2021###################################2400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-01'
    
}

api_0401 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0401.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data24_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data24_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(2400)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1284           DL          DAL                                       NaN
# 1285           PK          PIA                                       NaN
# 1286           SQ          SIA                                       NaN
# 1287           TK          THY                                       NaN
# 1288           AM          AMX                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1284       NaN          NaN      NaN                           NaN
# 1285       NaN          NaN      NaN                           NaN
# 1286       NaN          NaN      NaN                           NaN
# 1287       NaN          NaN      NaN                           NaN
# 1288       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1284          NaN      NaN
# 1285          NaN      NaN
# 1286          NaN      NaN
# 1287          NaN      NaN
# 1288          NaN      NaN
#
# [2400 rows x 9 columns]

# %%
########################03.31.2021###################################2500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-31'
    
}

api_0331 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0331.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data25_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data25_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data25_df])
joined_df_merge.head(2500)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1384           DL          DAL                                       NaN
# 1385           AM          AMX                                       NaN
# 1386           KE          KAL                                       NaN
# 1387           DL          DAL                                       NaN
# 1388           PK          PIA                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1384       NaN          NaN      NaN                           NaN
# 1385       NaN          NaN      NaN                           NaN
# 1386       NaN          NaN      NaN                           NaN
# 1387       NaN          NaN      NaN                           NaN
# 1388       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1384          NaN      NaN
# 1385          NaN      NaN
# 1386          NaN      NaN
# 1387          NaN      NaN
# 1388          NaN      NaN
#
# [2500 rows x 9 columns]

# %%
########################03.30.2021###################################2600
params = {
   'access_key': api_key,  
   'arr_iata': 'ATL',
    'flight_date': '2021-03-30'
    
}

api_0330 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0330.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data26_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data26_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data26_df])
joined_df_merge.head(2600)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1484           AF          AFR                                       NaN
# 1485           DL          DAL                                       NaN
# 1486           AZ          AZA                                       NaN
# 1487           VS          VIR                                       NaN
# 1488           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1484       NaN          NaN      NaN                           NaN
# 1485       NaN          NaN      NaN                           NaN
# 1486       NaN          NaN      NaN                           NaN
# 1487       NaN          NaN      NaN                           NaN
# 1488       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1484          NaN      NaN
# 1485          NaN      NaN
# 1486          NaN      NaN
# 1487          NaN      NaN
# 1488          NaN      NaN
#
# [2600 rows x 9 columns]

# %%
########################03.29.2021###################################2700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-29'
    
}

api_0329 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0329.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data27_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data27_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data27_df])
joined_df_merge.head(2700)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 69           BR          EVA  Hartsfield-jackson Atlanta International
# 70           G3          GLO  Hartsfield-jackson Atlanta International
# 71           AM          AMX  Hartsfield-jackson Atlanta International
# 72           KL          KLM  Hartsfield-jackson Atlanta International
# 73           AM          AMX  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                      dep_airport  \
# 0         35            I     None                  Seoul (Incheon)
# 1       7851            I     None                  Seoul (Incheon)
# 2       5090            I     None                  Seoul (Incheon)
# 3       6786            S      B21     George Bush Intercontinental
# 4       5130            S      A12     George Bush Intercontinental
# ..       ...          ...      ...                              ...
# 69      3415            S      A31  Southwest Florida International
# 70      5839            S      A31  Southwest Florida International
# 71      3205            S      A31  Southwest Florida International
# 72      6117            S      A31  Southwest Florida International
# 73      5105            S      E17     John F Kennedy International
#
#    dep_terminal dep_gate
# 0             2      231
# 1             2      231
# 2             2      231
# 3             A       14
# 4             A       15
# ..          ...      ...
# 69         None       C6
# 70         None       C6
# 71         None       C6
# 72         None       C6
# 73            4      B41
#
# [2700 rows x 9 columns]

# %%
########################03.28.2021###################################2800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-28'
    
}

api_0328 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0328.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data28_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data28_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data28_df])
joined_df_merge.head(2800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 169           AF          AFR  Hartsfield-jackson Atlanta International
# 170           BR          EVA  Hartsfield-jackson Atlanta International
# 171           G3          GLO  Hartsfield-jackson Atlanta International
# 172           AM          AMX  Hartsfield-jackson Atlanta International
# 173           KL          KLM  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# 0          35            I     None                  Seoul (Incheon)
# 1        7851            I     None                  Seoul (Incheon)
# 2        5090            I     None                  Seoul (Incheon)
# 3        6786            S      B21     George Bush Intercontinental
# 4        5130            S      A12     George Bush Intercontinental
# ..        ...          ...      ...                              ...
# 169      2352            S      A31  Southwest Florida International
# 170      3415            S      A31  Southwest Florida International
# 171      5839            S      A31  Southwest Florida International
# 172      3205            S      A31  Southwest Florida International
# 173      6117            S      E17     John F Kennedy International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 169         None       C6
# 170         None       C6
# 171         None       C6
# 172         None       C6
# 173            4      B41
#
# [2800 rows x 9 columns]

# %%
########################03.27.2021###################################2900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-27'
    
}

api_0327 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0327.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data29_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data29_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data29_df])
joined_df_merge.head(2900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 269           KL          KLM  Hartsfield-jackson Atlanta International
# 270           VS          VIR  Hartsfield-jackson Atlanta International
# 271           AF          AFR  Hartsfield-jackson Atlanta International
# 272           BR          EVA  Hartsfield-jackson Atlanta International
# 273           G3          GLO  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# 0          35            I     None                  Seoul (Incheon)
# 1        7851            I     None                  Seoul (Incheon)
# 2        5090            I     None                  Seoul (Incheon)
# 3        6786            S      B21     George Bush Intercontinental
# 4        5130            S      A12     George Bush Intercontinental
# ..        ...          ...      ...                              ...
# 269      2823            S      A31  Southwest Florida International
# 270      4956            S      A31  Southwest Florida International
# 271      4974            S      A31  Southwest Florida International
# 272      3508            S      A31  Southwest Florida International
# 273      1762            S      E17     John F Kennedy International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 269         None       C6
# 270         None       C6
# 271         None       C6
# 272         None       C6
# 273            4      B41
#
# [2900 rows x 9 columns]

# %%
########################03.26.2021###################################3000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-26'
    
}

api_0326 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0326.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data30_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data30_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data30_df])
joined_df_merge.head(3000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 369          ATL         KATL  Hartsfield-jackson Atlanta International
# 370          ATL         KATL  Hartsfield-jackson Atlanta International
# 371          ATL         KATL  Hartsfield-jackson Atlanta International
# 372          ATL         KATL  Hartsfield-jackson Atlanta International
# 373          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# 0          35            I     None                  Seoul (Incheon)
# 1        7851            I     None                  Seoul (Incheon)
# 2        5090            I     None                  Seoul (Incheon)
# 3        6786            S      B21     George Bush Intercontinental
# 4        5130            S      A12     George Bush Intercontinental
# ..        ...          ...      ...                              ...
# 369      3539            S      A31  Southwest Florida International
# 370      7129            S      A31  Southwest Florida International
# 371      2823            S      A31  Southwest Florida International
# 372      4956            S      A31  Southwest Florida International
# 373      4974            S      E17     John F Kennedy International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 369         None       C6
# 370         None       C6
# 371         None       C6
# 372         None       C6
# 373            4      B41
#
# [3000 rows x 9 columns]

# %%
########################03.25.2021###################################3100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-25'
    
}

api_0325 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0325.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data31_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data31_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data31_df])
joined_df_merge.head(3100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 469          ATL         KATL  Hartsfield-jackson Atlanta International
# 470          ATL         KATL  Hartsfield-jackson Atlanta International
# 471          ATL         KATL  Hartsfield-jackson Atlanta International
# 472          ATL         KATL  Hartsfield-jackson Atlanta International
# 473          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# 0          35            I     None                 Seoul (Incheon)
# 1        7851            I     None                 Seoul (Incheon)
# 2        5090            I     None                 Seoul (Incheon)
# 3        6786            S      B21    George Bush Intercontinental
# 4        5130            S      A12    George Bush Intercontinental
# ..        ...          ...      ...                             ...
# 469      5867            S      E33          Joe Foss Field Airport
# 470      3224            S      E33          Joe Foss Field Airport
# 471      2366            S      A32  Austin-bergstrom International
# 472      2334            S      A32  Austin-bergstrom International
# 473       688            S      A32  Austin-bergstrom International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 469         None        2
# 470         None        2
# 471         None       10
# 472         None       10
# 473         None       10
#
# [3100 rows x 9 columns]

# %%
########################03.24.2021###################################3200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-24'
    
}

api_0324 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0324.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data32_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data32_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data32_df])
joined_df_merge.head(3200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 569           WS          WJA  Hartsfield-jackson Atlanta International
# 570           DL          DAL  Hartsfield-jackson Atlanta International
# 571           AF          AFR  Hartsfield-jackson Atlanta International
# 572           AM          AMX  Hartsfield-jackson Atlanta International
# 573           KL          KLM  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# 0          35            I     None                 Seoul (Incheon)
# 1        7851            I     None                 Seoul (Incheon)
# 2        5090            I     None                 Seoul (Incheon)
# 3        6786            S      B21    George Bush Intercontinental
# 4        5130            S      A12    George Bush Intercontinental
# ..        ...          ...      ...                             ...
# 569      5867            S      E33          Joe Foss Field Airport
# 570      3224            S      E33          Joe Foss Field Airport
# 571      2366            S      A32  Austin-bergstrom International
# 572      2334            S      A32  Austin-bergstrom International
# 573       688            S      A32  Austin-bergstrom International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 569         None        2
# 570         None        2
# 571         None       10
# 572         None       10
# 573         None       10
#
# [3200 rows x 9 columns]

# %%
########################03.23.2021###################################3300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-23'
    
}

api_0323 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0323.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data33_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data33_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data33_df])
joined_df_merge.head(3300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 669           VS          VIR  Hartsfield-jackson Atlanta International
# 670          ATL         KATL  Hartsfield-jackson Atlanta International
# 671           KL          KLM  Hartsfield-jackson Atlanta International
# 672          ATL         KATL  Hartsfield-jackson Atlanta International
# 673           AM          AMX  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# 1        7851            I     None
# 2        5090            I     None
# 3        6786            S      B21
# 4        5130            S      A12
# ..        ...          ...      ...
# 669       NaN            S      D38
# 670       NaN            S      D33
# 671       NaN            S      B21
# 672       NaN            S      B21
# 673       NaN            S      B21
#
#                                            dep_airport dep_terminal dep_gate
# 0                                      Seoul (Incheon)            2      231
# 1                                      Seoul (Incheon)            2      231
# 2                                      Seoul (Incheon)            2      231
# 3                         George Bush Intercontinental            A       14
# 4                         George Bush Intercontinental            A       15
# ..                                                 ...          ...      ...
# 669  Central Illinois Regional Airport at Bloomingt...         None     None
# 670                                          Municipal         None     None
# 671                                    Eppley Airfield         None       A4
# 672                                    Eppley Airfield         None       A4
# 673                                    Eppley Airfield         None       A4
#
# [3300 rows x 9 columns]

# %%
########################03.22.2021###################################3400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-22'
    
}

api_0322 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0322.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data34_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data34_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data34_df])
joined_df_merge.head(3400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 769           KL          KLM  Hartsfield-jackson Atlanta International
# 770          ATL         KATL  Hartsfield-jackson Atlanta International
# 771           AM          AMX  Hartsfield-jackson Atlanta International
# 772          ATL         KATL  Hartsfield-jackson Atlanta International
# 773           NK          NKS  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# 1        7851            I     None
# 2        5090            I     None
# 3        6786            S      B21
# 4        5130            S      A12
# ..        ...          ...      ...
# 769       NaN            S      D38
# 770       NaN            S      D33
# 771       NaN            S      B21
# 772       NaN            S      B21
# 773       NaN            S      B21
#
#                                            dep_airport dep_terminal dep_gate
# 0                                      Seoul (Incheon)            2      231
# 1                                      Seoul (Incheon)            2      231
# 2                                      Seoul (Incheon)            2      231
# 3                         George Bush Intercontinental            A       14
# 4                         George Bush Intercontinental            A       15
# ..                                                 ...          ...      ...
# 769  Central Illinois Regional Airport at Bloomingt...         None     None
# 770                                          Municipal         None     None
# 771                                    Eppley Airfield         None       A4
# 772                                    Eppley Airfield         None       A4
# 773                                    Eppley Airfield         None       A4
#
# [3400 rows x 9 columns]

# %%
########################03.21.2021###################################3500
params = {
   'access_key': api_key, 
   'arr_iata': 'ATL',
    'flight_date': '2021-03-21'
    
}

api_0321 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0321.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data35_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data35_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(3500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 869           VS          VIR                                       NaN
# 870          ATL         KATL                                       NaN
# 871           KL          KLM                                       NaN
# 872          ATL         KATL                                       NaN
# 873           AM          AMX                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 869       NaN          NaN      NaN                           NaN
# 870       NaN          NaN      NaN                           NaN
# 871       NaN          NaN      NaN                           NaN
# 872       NaN          NaN      NaN                           NaN
# 873       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 869          NaN      NaN
# 870          NaN      NaN
# 871          NaN      NaN
# 872          NaN      NaN
# 873          NaN      NaN
#
# [3500 rows x 9 columns]

# %%
########################03.20.2021###################################3600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-20'
    
}

api_0320 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0320.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data36_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data36_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data36_df])
joined_df_merge.head(3600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 969           KL          KLM                                       NaN
# 970          ATL         KATL                                       NaN
# 971           AM          AMX                                       NaN
# 972          ATL         KATL                                       NaN
# 973           NK          NKS                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 969       NaN          NaN      NaN                           NaN
# 970       NaN          NaN      NaN                           NaN
# 971       NaN          NaN      NaN                           NaN
# 972       NaN          NaN      NaN                           NaN
# 973       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 969          NaN      NaN
# 970          NaN      NaN
# 971          NaN      NaN
# 972          NaN      NaN
# 973          NaN      NaN
#
# [3600 rows x 9 columns]

# %%
########################03.19.2021###################################3700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-19'
    
}

api_0319 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0319.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data37_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data37_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data37_df])
joined_df_merge.head(3700)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1069           KL          KLM                                       NaN
# 1070           AM          AMX                                       NaN
# 1071           DL          DAL                                       NaN
# 1072           AF          AFR                                       NaN
# 1073           AM          AMX                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1069       NaN          NaN      NaN                           NaN
# 1070       NaN          NaN      NaN                           NaN
# 1071       NaN          NaN      NaN                           NaN
# 1072       NaN          NaN      NaN                           NaN
# 1073       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1069          NaN      NaN
# 1070          NaN      NaN
# 1071          NaN      NaN
# 1072          NaN      NaN
# 1073          NaN      NaN
#
# [3700 rows x 9 columns]

# %%
########################03.18.2021###################################3800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-18'
    
}

api_0318 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0318.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data38_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data38_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data38_df])
joined_df_merge.head(3800)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1169           VS          VIR                                       NaN
# 1170           KL          KLM                                       NaN
# 1171           AM          AMX                                       NaN
# 1172           DL          DAL                                       NaN
# 1173           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1169       NaN          NaN      NaN                           NaN
# 1170       NaN          NaN      NaN                           NaN
# 1171       NaN          NaN      NaN                           NaN
# 1172       NaN          NaN      NaN                           NaN
# 1173       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1169          NaN      NaN
# 1170          NaN      NaN
# 1171          NaN      NaN
# 1172          NaN      NaN
# 1173          NaN      NaN
#
# [3800 rows x 9 columns]

# %%
########################03.17.2021###################################3900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-17'
    
}

api_0317 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0317.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data39_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data39_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data39_df])
joined_df_merge.head(3900)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1269           VS          VIR                                       NaN
# 1270           DL          DAL                                       NaN
# 1271           AM          AMX                                       NaN
# 1272           KE          KAL                                       NaN
# 1273           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1269       NaN          NaN      NaN                           NaN
# 1270       NaN          NaN      NaN                           NaN
# 1271       NaN          NaN      NaN                           NaN
# 1272       NaN          NaN      NaN                           NaN
# 1273       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1269          NaN      NaN
# 1270          NaN      NaN
# 1271          NaN      NaN
# 1272          NaN      NaN
# 1273          NaN      NaN
#
# [3900 rows x 9 columns]

# %%
########################03.16.2021###################################4000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-16'
    
}

api_0316 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0316.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data40_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data40_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data40_df])
joined_df_merge.head(4000)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1369           AM          AMX                                       NaN
# 1370           KE          KAL                                       NaN
# 1371           KL          KLM                                       NaN
# 1372           VS          VIR                                       NaN
# 1373           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1369       NaN          NaN      NaN                           NaN
# 1370       NaN          NaN      NaN                           NaN
# 1371       NaN          NaN      NaN                           NaN
# 1372       NaN          NaN      NaN                           NaN
# 1373       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1369          NaN      NaN
# 1370          NaN      NaN
# 1371          NaN      NaN
# 1372          NaN      NaN
# 1373          NaN      NaN
#
# [4000 rows x 9 columns]

# %%
########################03.15.2021###################################4100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-15'
    
}

api_0315 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0315.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data41_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data41_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data41_df])
joined_df_merge.head(4100)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1469           WN          SWA                                       NaN
# 1470           DL          DAL                                       NaN
# 1471           VS          VIR                                       NaN
# 1472           KL          KLM                                       NaN
# 1473           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1469       NaN          NaN      NaN                           NaN
# 1470       NaN          NaN      NaN                           NaN
# 1471       NaN          NaN      NaN                           NaN
# 1472       NaN          NaN      NaN                           NaN
# 1473       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1469          NaN      NaN
# 1470          NaN      NaN
# 1471          NaN      NaN
# 1472          NaN      NaN
# 1473          NaN      NaN
#
# [4100 rows x 9 columns]

# %%
########################03.14.2021###################################4200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-14'
    
}

api_0314 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0314.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data42_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data42_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data42_df])
joined_df_merge.head(4200)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1569           WN          SWA                                       NaN
# 1570           DL          DAL                                       NaN
# 1571           VS          VIR                                       NaN
# 1572           KL          KLM                                       NaN
# 1573           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1569       NaN          NaN      NaN                           NaN
# 1570       NaN          NaN      NaN                           NaN
# 1571       NaN          NaN      NaN                           NaN
# 1572       NaN          NaN      NaN                           NaN
# 1573       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1569          NaN      NaN
# 1570          NaN      NaN
# 1571          NaN      NaN
# 1572          NaN      NaN
# 1573          NaN      NaN
#
# [4200 rows x 9 columns]

# %%
########################03.13.2021###################################4300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-13'
    
}

api_0313 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0313.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data43_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data43_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data43_df])
joined_df_merge.head(4300)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 54           KL          KLM  Hartsfield-jackson Atlanta International
# 55           AM          AMX  Hartsfield-jackson Atlanta International
# 56           DL          DAL  Hartsfield-jackson Atlanta International
# 57           AF          AFR  Hartsfield-jackson Atlanta International
# 58           AM          AMX  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0         35            I     None               Seoul (Incheon)            2
# 1       7851            I     None               Seoul (Incheon)            2
# 2       5090            I     None               Seoul (Incheon)            2
# 3       6786            S      B21  George Bush Intercontinental            A
# 4       5130            S      A12  George Bush Intercontinental            A
# ..       ...          ...      ...                           ...          ...
# 54      4784            S       B4           Tampa International         None
# 55      7262            S      E32                 Mc Ghee Tyson         None
# 56      7114            S      E32                 Mc Ghee Tyson         None
# 57      4549            S      E32                 Mc Ghee Tyson         None
# 58      6342            S      E32                 Mc Ghee Tyson         None
#
#    dep_gate
# 0       231
# 1       231
# 2       231
# 3        14
# 4        15
# ..      ...
# 54      E62
# 55        5
# 56        5
# 57        5
# 58        5
#
# [4300 rows x 9 columns]

# %%
########################03.12.2021###################################4400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-12'
    
}

api_0312 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0312.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data44_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data44_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data44_df])
joined_df_merge.head(4400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 154           VS          VIR  Hartsfield-jackson Atlanta International
# 155           KL          KLM  Hartsfield-jackson Atlanta International
# 156           AM          AMX  Hartsfield-jackson Atlanta International
# 157           DL          DAL  Hartsfield-jackson Atlanta International
# 158           AF          AFR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 154      2056            S       B4           Tampa International
# 155      4784            S      E32                 Mc Ghee Tyson
# 156      7262            S      E32                 Mc Ghee Tyson
# 157      7114            S      E32                 Mc Ghee Tyson
# 158      4549            S      E32                 Mc Ghee Tyson
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 154         None      E62
# 155         None        5
# 156         None        5
# 157         None        5
# 158         None        5
#
# [4400 rows x 9 columns]

# %%
########################03.11.2021###################################4500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-11'
    
}

api_0311 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0311.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data45_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data45_df])
joined_df_merge.head(4500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 254           WS          WJA  Hartsfield-jackson Atlanta International
# 255           WS          WJA  Hartsfield-jackson Atlanta International
# 256           VS          VIR  Hartsfield-jackson Atlanta International
# 257           KL          KLM  Hartsfield-jackson Atlanta International
# 258           AM          AMX  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 254      1480            S       B4           Tampa International
# 255      3219            S      E32                 Mc Ghee Tyson
# 256      3784            S      E32                 Mc Ghee Tyson
# 257      6245            S      E32                 Mc Ghee Tyson
# 258      2520            S      E32                 Mc Ghee Tyson
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 254         None      E62
# 255         None        5
# 256         None        5
# 257         None        5
# 258         None        5
#
# [4500 rows x 9 columns]

# %%
########################03.10.2021###################################4600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-10'
    
}

api_0310 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0310.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data46_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data46_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data46_df])
joined_df_merge.head(4600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 354          ATL         KATL  Hartsfield-jackson Atlanta International
# 355          ATL         KATL  Hartsfield-jackson Atlanta International
# 356          ATL         KATL  Hartsfield-jackson Atlanta International
# 357          ATL         KATL  Hartsfield-jackson Atlanta International
# 358          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 354      3397            S       B4           Tampa International
# 355      1001            S      E32                 Mc Ghee Tyson
# 356      1480            S      E32                 Mc Ghee Tyson
# 357      3219            S      E32                 Mc Ghee Tyson
# 358      3784            S      E32                 Mc Ghee Tyson
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 354         None      E62
# 355         None        5
# 356         None        5
# 357         None        5
# 358         None        5
#
# [4600 rows x 9 columns]

# %%
########################03.09.2021###################################4700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-09'
    
}

api_0309 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0309.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data47_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data47_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data47_df])
joined_df_merge.head(4700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 454          ATL         KATL  Hartsfield-jackson Atlanta International
# 455          ATL         KATL  Hartsfield-jackson Atlanta International
# 456          ATL         KATL  Hartsfield-jackson Atlanta International
# 457          ATL         KATL  Hartsfield-jackson Atlanta International
# 458          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 454      2318            S       C3     Will Rogers World Airport
# 455      6707            S      B21         Bradley International
# 456      2203            S      B21         Bradley International
# 457      1182            S      B21         Bradley International
# 458      1800            S      B21         Bradley International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 454         None       16
# 455            A       10
# 456            A       10
# 457            A       10
# 458            A       10
#
# [4700 rows x 9 columns]

# %%
########################03.08.2021###################################4800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-08'
    
}

api_0308 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0308.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data48_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data48_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data48_df])
joined_df_merge.head(4800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 554           KL          KLM  Hartsfield-jackson Atlanta International
# 555           AF          AFR  Hartsfield-jackson Atlanta International
# 556           DL          DAL  Hartsfield-jackson Atlanta International
# 557           DL          DAL  Hartsfield-jackson Atlanta International
# 558           WS          WJA  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 554      2318            S       C3     Will Rogers World Airport
# 555      6707            S      B21         Bradley International
# 556      2203            S      B21         Bradley International
# 557      1182            S      B21         Bradley International
# 558      1800            S      B21         Bradley International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 554         None       16
# 555            A       10
# 556            A       10
# 557            A       10
# 558            A       10
#
# [4800 rows x 9 columns]

# %%
########################03.07.2021###################################4900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-07'
    
}

api_0307 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0307.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data49_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data49_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data49_df])
joined_df_merge.head(4900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 654          ATL         KATL  Hartsfield-jackson Atlanta International
# 655           AF          AFR  Hartsfield-jackson Atlanta International
# 656          ATL         KATL  Hartsfield-jackson Atlanta International
# 657           KL          KLM  Hartsfield-jackson Atlanta International
# 658          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                           dep_airport  \
# 0          35            I     None                       Seoul (Incheon)
# 1        7851            I     None                       Seoul (Incheon)
# 2        5090            I     None                       Seoul (Incheon)
# 3        6786            S      B21          George Bush Intercontinental
# 4        5130            S      A12          George Bush Intercontinental
# ..        ...          ...      ...                                   ...
# 654       NaN            S      A33  Raleigh-durham International Airport
# 655       NaN            S      C15  Raleigh-durham International Airport
# 656       NaN            I      E30                Sangster International
# 657       NaN            I      E30                Sangster International
# 658       NaN            I      E30                Sangster International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 654            2       C1
# 655            1       A7
# 656         None       15
# 657         None       15
# 658         None       15
#
# [4900 rows x 9 columns]

# %%
########################03.06.2021###################################5000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-06'
    
}

api_0306 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0306.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data50_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data50_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data50_df])
joined_df_merge.head(5000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 754          ATL         KATL  Hartsfield-jackson Atlanta International
# 755           KL          KLM  Hartsfield-jackson Atlanta International
# 756          ATL         KATL  Hartsfield-jackson Atlanta International
# 757           KE          KAL  Hartsfield-jackson Atlanta International
# 758          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                           dep_airport  \
# 0          35            I     None                       Seoul (Incheon)
# 1        7851            I     None                       Seoul (Incheon)
# 2        5090            I     None                       Seoul (Incheon)
# 3        6786            S      B21          George Bush Intercontinental
# 4        5130            S      A12          George Bush Intercontinental
# ..        ...          ...      ...                                   ...
# 754       NaN            S      A33  Raleigh-durham International Airport
# 755       NaN            S      C15  Raleigh-durham International Airport
# 756       NaN            I      E30                Sangster International
# 757       NaN            I      E30                Sangster International
# 758       NaN            I      E30                Sangster International
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 754            2       C1
# 755            1       A7
# 756         None       15
# 757         None       15
# 758         None       15
#
# [5000 rows x 9 columns]

# %%
########################03.05.2021###################################5100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-05'
    
}

api_0305 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0305.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data51_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data51_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data51_df])
joined_df_merge.head(5100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 854          ATL         KATL                                       NaN
# 855           AF          AFR                                       NaN
# 856          ATL         KATL                                       NaN
# 857           KL          KLM                                       NaN
# 858          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 854       NaN          NaN      NaN                           NaN
# 855       NaN          NaN      NaN                           NaN
# 856       NaN          NaN      NaN                           NaN
# 857       NaN          NaN      NaN                           NaN
# 858       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 854          NaN      NaN
# 855          NaN      NaN
# 856          NaN      NaN
# 857          NaN      NaN
# 858          NaN      NaN
#
# [5100 rows x 9 columns]

# %%
########################03.04.2021###################################5200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-04'
    
}

api_0304 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0304.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data52_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data52_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data52_df])
joined_df_merge.head(5200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 954          ATL         KATL                                       NaN
# 955           KL          KLM                                       NaN
# 956          ATL         KATL                                       NaN
# 957           KE          KAL                                       NaN
# 958          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# 0          35            I     None               Seoul (Incheon)
# 1        7851            I     None               Seoul (Incheon)
# 2        5090            I     None               Seoul (Incheon)
# 3        6786            S      B21  George Bush Intercontinental
# 4        5130            S      A12  George Bush Intercontinental
# ..        ...          ...      ...                           ...
# 954       NaN          NaN      NaN                           NaN
# 955       NaN          NaN      NaN                           NaN
# 956       NaN          NaN      NaN                           NaN
# 957       NaN          NaN      NaN                           NaN
# 958       NaN          NaN      NaN                           NaN
#
#     dep_terminal dep_gate
# 0              2      231
# 1              2      231
# 2              2      231
# 3              A       14
# 4              A       15
# ..           ...      ...
# 954          NaN      NaN
# 955          NaN      NaN
# 956          NaN      NaN
# 957          NaN      NaN
# 958          NaN      NaN
#
# [5200 rows x 9 columns]

# %%
########################03.03.2021###################################5300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-03'
    
}

api_0303 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0303.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data53_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data53_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data53_df])
joined_df_merge.head(5300)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1054           KL          KLM                                       NaN
# 1055           AF          AFR                                       NaN
# 1056           DL          DAL                                       NaN
# 1057           KL          KLM                                       NaN
# 1058           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1054       NaN          NaN      NaN                           NaN
# 1055       NaN          NaN      NaN                           NaN
# 1056       NaN          NaN      NaN                           NaN
# 1057       NaN          NaN      NaN                           NaN
# 1058       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1054          NaN      NaN
# 1055          NaN      NaN
# 1056          NaN      NaN
# 1057          NaN      NaN
# 1058          NaN      NaN
#
# [5300 rows x 9 columns]

# %%
########################03.02.2021###################################5400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-02'
    
}

api_0302 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0302.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data54_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data54_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data54_df])
joined_df_merge.head(5400)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1154           DL          DAL                                       NaN
# 1155           KL          KLM                                       NaN
# 1156           AF          AFR                                       NaN
# 1157           DL          DAL                                       NaN
# 1158           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1154       NaN          NaN      NaN                           NaN
# 1155       NaN          NaN      NaN                           NaN
# 1156       NaN          NaN      NaN                           NaN
# 1157       NaN          NaN      NaN                           NaN
# 1158       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1154          NaN      NaN
# 1155          NaN      NaN
# 1156          NaN      NaN
# 1157          NaN      NaN
# 1158          NaN      NaN
#
# [5400 rows x 9 columns]

# %%
########################03.01.2021###################################5500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-01'
    
}

api_0301 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0301.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data55_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data55_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data55_df])
joined_df_merge.head(5500)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1254           WN          SWA                                       NaN
# 1255           KE          KAL                                       NaN
# 1256           DL          DAL                                       NaN
# 1257           AM          AMX                                       NaN
# 1258           KE          KAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# 0           35            I     None               Seoul (Incheon)
# 1         7851            I     None               Seoul (Incheon)
# 2         5090            I     None               Seoul (Incheon)
# 3         6786            S      B21  George Bush Intercontinental
# 4         5130            S      A12  George Bush Intercontinental
# ...        ...          ...      ...                           ...
# 1254       NaN          NaN      NaN                           NaN
# 1255       NaN          NaN      NaN                           NaN
# 1256       NaN          NaN      NaN                           NaN
# 1257       NaN          NaN      NaN                           NaN
# 1258       NaN          NaN      NaN                           NaN
#
#      dep_terminal dep_gate
# 0               2      231
# 1               2      231
# 2               2      231
# 3               A       14
# 4               A       15
# ...           ...      ...
# 1254          NaN      NaN
# 1255          NaN      NaN
# 1256          NaN      NaN
# 1257          NaN      NaN
# 1258          NaN      NaN
#
# [5500 rows x 9 columns]

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-28'
    
}

api_0228 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-27'
    
}

api_0227 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0227.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-26'
    
}

api_0226 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0226.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-25'
    
}

api_0225 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0225.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-24'
    
}

api_0224 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0224.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-23'
    
}

api_0223 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0223.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-22'
    
}

api_0222 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_022.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-21'
    
}

api_0221 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0221.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-20'
    
}

api_0220 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0220.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-19'
    
}

api_0219 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0219.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-18'
    
}

api_0218 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0218.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-17'
    
}

api_0217 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0217.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-16'
    
}

api_0216 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0216.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-15'
    
}

api_0215 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0215.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-14'
    
}

api_0214 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0214.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-13'
    
}

api_0213 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0213.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0211.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-10'
    
}

api_0210 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0210.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-09'
    
}

api_0209 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0209.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-08'
    
}

api_0208 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0208.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-07'
    
}

api_0207 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0207.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-06'
    
}

api_0206 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0206.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-05'
    
}

api_0205 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0205.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-04'
    
}

api_0204 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0204.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-03'
    
}

api_0203 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0203.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-02'
    
}

api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-01'
    
}

api_0201 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0201.json()


pd.DataFrame.from_dict(api_response, orient='index').T.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4ef8e370ee87> in <module>
#      11
#      12
# ---> 13 pd.DataFrame.from_dict(api_response, orient='index').T.set_index('index')
#
# C:\Users\melin\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1298                 # TODO speed up Series case
#    1299                 if isinstance(list(data.values())[0], (Series, dict)):
# -> 1300                     data = _from_nested_dict(data)
#    1301                 else:
#    1302                     data, index = list(data.values()), list(data.keys())
#
# C:\Users\melin\Anaconda3\lib\site-packages\pandas\core\frame.py in _from_nested_dict(data)
#    9275     new_data = collections.defaultdict(dict)
#    9276     for index, s in data.items():
# -> 9277         for col, v in s.items():
#    9278             new_data[col][index] = v
#    9279     return new_data
#
# AttributeError: 'list' object has no attribute 'items'

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])
