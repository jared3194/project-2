# %%
import requests
import json
import pandas as pd
from pprint import pprint

# %%
# Real time flights
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0424.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T08:51:00+00:00',
#                        'actual_runway': '2021-04-24T08:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': 4,
#                        'estimated': '2021-04-24T08:48:00+00:00',
#                        'estimated_runway': '2021-04-24T08:51:00+00:00',
#                        'gate': 'B17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T07:08:00+00:00',
#                          'actual_runway': '2021-04-24T07:08:00+00:00',
# ...

# %%
# Out:
#                                                    0
# 0  b'{"pagination":{"limit":100,"offset":0,"count...
# 1  b'departure":{"airport":"Hopkins International...
# 2  b'B4","delay":8,"scheduled":"2021-04-24T07:00:...
# 3  b'0","estimated_runway":"2021-04-24T07:08:00+0...
# 4  b'jackson Atlanta International","timezone":"A...

# %%
# Flight specific date
# params = {
#   'access_key': '6289ca69e9e258ac06e0faa6602570be',
#     'airline': 'Emirates'
# }

api_result = requests.get(‘https://api.aviationstack.com/v1/flights?access_key=’
                                  + ‘6289ca69e9e258ac06e0faa6602570be’
                         + ‘&flight_date=2021-04-01’)

api_response = api_result.json()

pprint(api_response)
# Out:
#   File "<ipython-input-4-2e6bd5296cce>", line 7
#     api_result = requests.get(‘https://api.aviationstack.com/v1/flights?access_key=’
#                                    ^
# SyntaxError: invalid character in identifier
