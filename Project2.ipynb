# %%
import requests
import json
import pandas as pd
from pprint import pprint

# %%
# Real time flights
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0424.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 6,
#                          'estimated': '2021-04-24T14:10:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '14',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T14:10:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1113',
#                                      'flight_icao': 'dal1113',
#                                      'flight_number': '1113'},
#                       'iata': 'KL5090',
#                       'icao': 'KLM5090',
#                       'number': '5090'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 4,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'WS6786',
#                       'icao': 'WJA6786',
#                       'number': '6786'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 4,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'VS5130',
#                       'icao': 'VIR5130',
#                       'number': '5130'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 4,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'KL6327',
#                       'icao': 'KLM6327',
#                       'number': '6327'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 4,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'AM4908',
#                       'icao': 'AMX4908',
#                       'number': '4908'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 4,
#                          'estimated': '2021-04-24T12:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:50:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1119',
#                                      'flight_icao': 'dal1119',
#                                      'flight_number': '1119'},
#                       'iata': 'AF3708',
#                       'icao': 'AFR3708',
#                       'number': '3708'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T15:29:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T15:29:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 14,
#                          'estimated': '2021-04-24T12:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '42',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:30:00+00:00',
#                          'terminal': 'C',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'ua',
#                                      'airline_icao': 'ual',
#                                      'airline_name': 'united airlines',
#                                      'flight_iata': 'ua6017',
#                                      'flight_icao': 'ual6017',
#                                      'flight_number': '6017'},
#                       'iata': 'NZ6320',
#                       'icao': 'ANZ6320',
#                       'number': '6320'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T13:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 7,
#                          'estimated': '2021-04-24T10:46:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T10:46:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl752',
#                                      'flight_icao': 'dal752',
#                                      'flight_number': '752'},
#                       'iata': 'VS4374',
#                       'icao': 'VIR4374',
#                       'number': '4374'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T13:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T13:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 7,
#                          'estimated': '2021-04-24T10:46:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '15',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T10:46:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl752',
#                                      'flight_icao': 'dal752',
#                                      'flight_number': '752'},
#                       'iata': 'AM5116',
#                       'icao': 'AMX5116',
#                       'number': '5116'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D28',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:50:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Salina',
#                          'delay': 30,
#                          'estimated': '2021-04-24T09:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'SLN',
#                          'icao': 'KSLN',
#                          'scheduled': '2021-04-24T09:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5554',
#                       'icao': 'DAL5554',
#                       'number': '5554'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A9',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': None,
#                          'estimated': '2021-04-24T15:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D6',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T15:55:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1049',
#                       'icao': 'DAL1049',
#                       'number': '1049'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T17:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A9',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T17:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': None,
#                          'estimated': '2021-04-24T15:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D6',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T15:55:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1049',
#                                      'flight_icao': 'dal1049',
#                                      'flight_number': '1049'},
#                       'iata': 'WS6672',
#                       'icao': 'WJA6672',
#                       'number': '6672'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:48:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B28',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hopkins International',
#                          'delay': 25,
#                          'estimated': '2021-04-24T16:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T18:48:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B28',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hopkins International',
#                          'delay': 25,
#                          'estimated': '2021-04-24T16:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T19:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'C21',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'La Guardia',
#                          'delay': 23,
#                          'estimated': '2021-04-24T16:25:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '55',
#                          'iata': 'LGA',
#                          'icao': 'KLGA',
#                          'scheduled': '2021-04-24T16:25:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN2625',
#                       'icao': 'SWA2625',
#                       'number': '2625'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T08:51:00+00:00',
#                        'actual_runway': '2021-04-24T08:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': 4,
#                        'estimated': '2021-04-24T08:48:00+00:00',
#                        'estimated_runway': '2021-04-24T08:51:00+00:00',
#                        'gate': 'B17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T07:08:00+00:00',
#                          'actual_runway': '2021-04-24T07:08:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 8,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': '2021-04-24T07:08:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2218',
#                       'icao': 'DAL2218',
#                       'number': '2218'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-24T08:51:00+00:00',
#                        'actual_runway': '2021-04-24T08:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': 4,
#                        'estimated': '2021-04-24T08:48:00+00:00',
#                        'estimated_runway': '2021-04-24T08:51:00+00:00',
#                        'gate': 'B17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T07:08:00+00:00',
#                          'actual_runway': '2021-04-24T07:08:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 8,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': '2021-04-24T07:08:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2218',
#                                      'flight_icao': 'dal2218',
#                                      'flight_number': '2218'},
#                       'iata': 'AM5210',
#                       'icao': 'AMX5210',
#                       'number': '5210'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T11:23:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T11:23:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T08:34:00+00:00',
#                          'actual_runway': '2021-04-24T08:34:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 4,
#                          'estimated': '2021-04-24T08:30:00+00:00',
#                          'estimated_runway': '2021-04-24T08:34:00+00:00',
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-24T08:30:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl843',
#                                      'flight_icao': 'dal843',
#                                      'flight_number': '843'},
#                       'iata': 'AM3558',
#                       'icao': 'AMX3558',
#                       'number': '3558'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T11:23:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T11:23:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T08:34:00+00:00',
#                          'actual_runway': '2021-04-24T08:34:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 4,
#                          'estimated': '2021-04-24T08:30:00+00:00',
#                          'estimated_runway': '2021-04-24T08:34:00+00:00',
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-24T08:30:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl843',
#                                      'flight_icao': 'dal843',
#                                      'flight_number': '843'},
#                       'iata': 'KE6986',
#                       'icao': 'KAL6986',
#                       'number': '6986'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:57:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D07',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Hilton Head',
#                          'delay': 2,
#                          'estimated': '2021-04-24T11:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '03',
#                          'iata': 'HHH',
#                          'icao': 'KHXD',
#                          'scheduled': '2021-04-24T11:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5846',
#                       'icao': 'DAL5846',
#                       'number': '5846'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A01',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tallahassee Regional Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:38:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B1',
#                          'iata': 'TLH',
#                          'icao': 'KTLH',
#                          'scheduled': '2021-04-24T11:38:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2026',
#                       'icao': 'DAL2026',
#                       'number': '2026'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B24',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tallahassee Regional Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:38:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B1',
#                          'iata': 'TLH',
#                          'icao': 'KTLH',
#                          'scheduled': '2021-04-24T11:38:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2026',
#                                      'flight_icao': 'dal2026',
#                                      'flight_number': '2026'},
#                       'iata': 'WS7072',
#                       'icao': 'WJA7072',
#                       'number': '7072'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B24',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tallahassee Regional Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:38:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B1',
#                          'iata': 'TLH',
#                          'icao': 'KTLH',
#                          'scheduled': '2021-04-24T11:38:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2026',
#                                      'flight_icao': 'dal2026',
#                                      'flight_number': '2026'},
#                       'iata': 'VS2986',
#                       'icao': 'VIR2986',
#                       'number': '2986'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B24',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tallahassee Regional Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:38:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B1',
#                          'iata': 'TLH',
#                          'icao': 'KTLH',
#                          'scheduled': '2021-04-24T11:38:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2026',
#                                      'flight_icao': 'dal2026',
#                                      'flight_number': '2026'},
#                       'iata': 'KL5880',
#                       'icao': 'KLM5880',
#                       'number': '5880'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-24T12:49:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B24',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T12:49:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Tallahassee Regional Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:38:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B1',
#                          'iata': 'TLH',
#                          'icao': 'KTLH',
#                          'scheduled': '2021-04-24T11:38:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2026',
#                                      'flight_icao': 'dal2026',
#                                      'flight_number': '2026'},
#                       'iata': 'AM3525',
#                       'icao': 'AMX3525',
#                       'number': '3525'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'QR', 'icao': 'QTR', 'name': 'Qatar Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-25T01:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-25T01:30:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Findel',
#                          'delay': 10,
#                          'estimated': '2021-04-24T22:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'LUX',
#                          'icao': 'ELLX',
#                          'scheduled': '2021-04-24T22:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Europe/Luxembourg'},
#            'flight': {'codeshared': None,
#                       'iata': 'QR8143',
# ...
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1693',
#                                      'flight_icao': 'dal1693',
#                                      'flight_number': '1693'},
#                       'iata': 'VS2278',
#                       'icao': 'VIR2278',
#                       'number': '2278'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Cyril E King Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '06',
#                          'iata': 'STT',
#                          'icao': 'TIST',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/St_Thomas'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1950',
#                       'icao': 'DAL1950',
#                       'number': '1950'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Cyril E King Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '06',
#                          'iata': 'STT',
#                          'icao': 'TIST',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/St_Thomas'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1950',
#                                      'flight_icao': 'dal1950',
#                                      'flight_number': '1950'},
#                       'iata': 'VS2422',
#                       'icao': 'VIR2422',
#                       'number': '2422'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Cyril E King Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '06',
#                          'iata': 'STT',
#                          'icao': 'TIST',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/St_Thomas'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1950',
#                                      'flight_icao': 'dal1950',
#                                      'flight_number': '1950'},
#                       'iata': 'KL6583',
#                       'icao': 'KLM6583',
#                       'number': '6583'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Cyril E King Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '06',
#                          'iata': 'STT',
#                          'icao': 'TIST',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/St_Thomas'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1950',
#                                      'flight_icao': 'dal1950',
#                                      'flight_number': '1950'},
#                       'iata': 'AZ3398',
#                       'icao': 'AZA3398',
#                       'number': '3398'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'T7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Cyril E King Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '06',
#                          'iata': 'STT',
#                          'icao': 'TIST',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/St_Thomas'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1950',
#                                      'flight_icao': 'dal1950',
#                                      'flight_number': '1950'},
#                       'iata': 'AF2286',
#                       'icao': 'AFR2286',
#                       'number': '2286'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD185F',
#                         'registration': 'N943AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-24T08:44:00+00:00',
#                        'actual_runway': '2021-04-24T08:44:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T08:58:00+00:00',
#                        'estimated_runway': '2021-04-24T08:44:00+00:00',
#                        'gate': 'A17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:58:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T06:35:00+00:00',
#                          'actual_runway': '2021-04-24T06:35:00+00:00',
#                          'airport': 'Syracuse Hancock International Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-24T06:30:00+00:00',
#                          'estimated_runway': '2021-04-24T06:35:00+00:00',
#                          'gate': '24',
#                          'iata': 'SYR',
#                          'icao': 'KSYR',
#                          'scheduled': '2021-04-24T06:30:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL687',
#                       'icao': 'DAL687',
#                       'number': '687'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-24T08:44:00+00:00',
#                        'actual_runway': '2021-04-24T08:44:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T08:58:00+00:00',
#                        'estimated_runway': '2021-04-24T08:44:00+00:00',
#                        'gate': 'A17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:58:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T06:35:00+00:00',
#                          'actual_runway': '2021-04-24T06:35:00+00:00',
#                          'airport': 'Syracuse Hancock International Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-24T06:30:00+00:00',
#                          'estimated_runway': '2021-04-24T06:35:00+00:00',
#                          'gate': '24',
#                          'iata': 'SYR',
#                          'icao': 'KSYR',
#                          'scheduled': '2021-04-24T06:30:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl687',
#                                      'flight_icao': 'dal687',
#                                      'flight_number': '687'},
#                       'iata': 'VS2063',
#                       'icao': 'VIR2063',
#                       'number': '2063'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-24T08:44:00+00:00',
#                        'actual_runway': '2021-04-24T08:44:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-24T08:58:00+00:00',
#                        'estimated_runway': '2021-04-24T08:44:00+00:00',
#                        'gate': 'A17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-24T08:58:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-24T06:35:00+00:00',
#                          'actual_runway': '2021-04-24T06:35:00+00:00',
#                          'airport': 'Syracuse Hancock International Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-24T06:30:00+00:00',
#                          'estimated_runway': '2021-04-24T06:35:00+00:00',
#                          'gate': '24',
#                          'iata': 'SYR',
#                          'icao': 'KSYR',
#                          'scheduled': '2021-04-24T06:30:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl687',
#                                      'flight_icao': 'dal687',
#                                      'flight_number': '687'},
#                       'iata': 'KL5881',
#                       'icao': 'KLM5881',
#                       'number': '5881'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 254608}}

# %%
df=json_normalize(api_response,['data'],meta=['airline',['name']],['arrival',['airport','scheduled'],
                                        ['city','coord','lat'],
                                                 ['city','coord','lon']])
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-cf7ea8bc661f> in <module>
# ----> 1 pd.api_response(data,orient='columns')
#
# C:\Users\melin\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'api_response'

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'LAX'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0424.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'CZ',
#                        'icao': 'CSN',
#                        'name': 'China Southern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T22:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T22:25:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': None,
#                          'estimated': '2021-04-25T02:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-25T02:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CZ447',
#                       'icao': 'CSN447',
#                       'number': '447'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CA', 'icao': 'CCA', 'name': 'Air China LTD'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T21:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T21:50:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': 10,
#                          'estimated': '2021-04-25T02:10:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-25T02:10:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CA1051',
#                       'icao': 'CCA1051',
#                       'number': '1051'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CZ',
#                        'icao': 'CSN',
#                        'name': 'China Southern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T20:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T20:30:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': 185,
#                          'estimated': '2021-04-25T00:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-25T00:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CZ445',
#                       'icao': 'CSN445',
#                       'number': '445'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'Y8', 'icao': 'YZR', 'name': 'Suparna Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-25T00:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-25T00:05:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': None,
#                          'estimated': '2021-04-25T03:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-25T03:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'Y87455',
#                       'icao': 'YZR7455',
#                       'number': '7455'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BR', 'icao': 'EVA', 'name': 'EVA Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-25T00:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-25T00:10:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Taiwan Taoyuan International (Chiang Kai '
#                                     'Shek International)',
#                          'delay': 1120,
#                          'estimated': '2021-04-25T03:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'TPE',
#                          'icao': 'RCTP',
#                          'scheduled': '2021-04-25T03:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Taipei'},
#            'flight': {'codeshared': None,
#                       'iata': 'BR620',
#                       'icao': 'EVA620',
#                       'number': '620'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'Y8', 'icao': 'YZR', 'name': 'Suparna Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T22:00:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T22:00:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Nanjing Lukou International Airport',
#                          'delay': None,
#                          'estimated': '2021-04-25T01:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'NKG',
#                          'icao': 'ZSNJ',
#                          'scheduled': '2021-04-25T01:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'Y87459',
#                       'icao': 'YZR7459',
#                       'number': '7459'},
#            'flight_date': '2021-04-25',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T16:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T16:45:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': 62,
#                          'estimated': '2021-04-24T20:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'H',
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-24T20:05:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA9736',
#                       'icao': 'AAL9736',
#                       'number': '9736'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': '1',
#                        'delay': None,
#                        'estimated': '2021-04-24T14:02:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '75B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T14:02:00+00:00',
#                        'terminal': '7',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'George Bush Intercontinental',
#                          'delay': 15,
#                          'estimated': '2021-04-24T12:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '12',
#                          'iata': 'IAH',
#                          'icao': 'KIAH',
#                          'scheduled': '2021-04-24T12:20:00+00:00',
#                          'terminal': 'C',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'ua',
#                                      'airline_icao': 'ual',
#                                      'airline_name': 'united airlines',
#                                      'flight_iata': 'ua2224',
#                                      'flight_icao': 'ual2224',
#                                      'flight_number': '2224'},
#                       'iata': 'NZ9654',
#                       'icao': 'ANZ9654',
#                       'number': '9654'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:11:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '22',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:11:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T08:01:00+00:00',
#                          'actual_runway': '2021-04-24T08:01:00+00:00',
#                          'airport': 'San Antonio International',
#                          'delay': 4,
#                          'estimated': '2021-04-24T07:58:00+00:00',
#                          'estimated_runway': '2021-04-24T08:01:00+00:00',
#                          'gate': '7',
#                          'iata': 'SAT',
#                          'icao': 'KSAT',
#                          'scheduled': '2021-04-24T07:58:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl466',
#                                      'flight_icao': 'dal466',
#                                      'flight_number': '466'},
#                       'iata': 'AF2915',
#                       'icao': 'AFR2915',
#                       'number': '2915'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CK', 'icao': 'CKK', 'name': 'China Cargo'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T22:45:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T22:45:00+00:00',
#                        'terminal': '6',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Shanghai Pudong International',
#                          'delay': 10,
#                          'estimated': '2021-04-24T03:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'PVG',
#                          'icao': 'ZSPD',
#                          'scheduled': '2021-04-24T03:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Shanghai'},
#            'flight': {'codeshared': None,
#                       'iata': 'CK223',
#                       'icao': 'CKK223',
#                       'number': '223'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'TBIT',
#                        'delay': None,
#                        'estimated': '2021-04-24T16:59:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '52A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T16:59:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Gen Rafael Buelna',
#                          'delay': 10,
#                          'estimated': '2021-04-24T15:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'MZT',
#                          'icao': 'MMMZ',
#                          'scheduled': '2021-04-24T15:05:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/Mazatlan'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA3019',
#                       'icao': 'AAL3019',
#                       'number': '3019'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'UA', 'icao': 'UAL', 'name': 'United Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T08:22:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T08:22:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Kingsford Smith',
#                          'delay': 10,
#                          'estimated': '2021-04-24T11:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'SYD',
#                          'icao': 'YSSY',
#                          'scheduled': '2021-04-24T11:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Australia/Sydney'},
#            'flight': {'codeshared': None,
#                       'iata': 'UA2795',
#                       'icao': 'UAL2795',
#                       'number': '2795'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-24T05:58:00+00:00',
#                        'actual_runway': '2021-04-24T05:58:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': 4,
#                        'estimated': '2021-04-24T06:05:00+00:00',
#                        'estimated_runway': '2021-04-24T05:58:00+00:00',
#                        'gate': '133',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T06:05:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T10:19:00+00:00',
#                          'actual_runway': '2021-04-24T10:19:00+00:00',
#                          'airport': 'Kingsford Smith',
#                          'delay': 24,
#                          'estimated': '2021-04-24T09:55:00+00:00',
#                          'estimated_runway': '2021-04-24T10:19:00+00:00',
#                          'gate': '59',
#                          'iata': 'SYD',
#                          'icao': 'YSSY',
#                          'scheduled': '2021-04-24T09:55:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Sydney'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl40',
#                                      'flight_icao': 'dal40',
#                                      'flight_number': '40'},
#                       'iata': 'VS3822',
#                       'icao': 'VIR3822',
#                       'number': '3822'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-24T05:58:00+00:00',
#                        'actual_runway': '2021-04-24T05:58:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': 4,
#                        'estimated': '2021-04-24T06:05:00+00:00',
#                        'estimated_runway': '2021-04-24T05:58:00+00:00',
#                        'gate': '133',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T06:05:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T10:19:00+00:00',
#                          'actual_runway': '2021-04-24T10:19:00+00:00',
#                          'airport': 'Kingsford Smith',
#                          'delay': 24,
#                          'estimated': '2021-04-24T09:55:00+00:00',
#                          'estimated_runway': '2021-04-24T10:19:00+00:00',
#                          'gate': '59',
#                          'iata': 'SYD',
#                          'icao': 'YSSY',
#                          'scheduled': '2021-04-24T09:55:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Sydney'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl40',
#                                      'flight_icao': 'dal40',
#                                      'flight_number': '40'},
#                       'iata': 'AF3606',
#                       'icao': 'AFR3606',
#                       'number': '3606'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'NZ', 'icao': 'ANZ', 'name': 'Air New Zealand'},
#            'arrival': {'actual': '2021-04-24T05:25:00+00:00',
#                        'actual_runway': '2021-04-24T05:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T06:00:00+00:00',
#                        'estimated_runway': '2021-04-24T05:25:00+00:00',
#                        'gate': '159',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T06:00:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T09:47:00+00:00',
#                          'actual_runway': '2021-04-24T09:47:00+00:00',
#                          'airport': 'Kingsford Smith',
#                          'delay': 17,
#                          'estimated': '2021-04-24T09:30:00+00:00',
#                          'estimated_runway': '2021-04-24T09:47:00+00:00',
#                          'gate': '60',
#                          'iata': 'SYD',
#                          'icao': 'YSSY',
#                          'scheduled': '2021-04-24T09:30:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Sydney'},
#            'flight': {'codeshared': {'airline_iata': 'ua',
#                                      'airline_icao': 'ual',
#                                      'airline_name': 'united airlines',
#                                      'flight_iata': 'ua842',
#                                      'flight_icao': 'ual842',
#                                      'flight_number': '842'},
#                       'iata': 'NZ9840',
#                       'icao': 'ANZ9840',
#                       'number': '9840'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'LH', 'icao': 'DLH', 'name': 'Lufthansa'},
#            'arrival': {'actual': '2021-04-24T05:25:00+00:00',
#                        'actual_runway': '2021-04-24T05:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T06:00:00+00:00',
#                        'estimated_runway': '2021-04-24T05:25:00+00:00',
#                        'gate': '159',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T06:00:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T09:47:00+00:00',
#                          'actual_runway': '2021-04-24T09:47:00+00:00',
#                          'airport': 'Kingsford Smith',
#                          'delay': 17,
#                          'estimated': '2021-04-24T09:30:00+00:00',
#                          'estimated_runway': '2021-04-24T09:47:00+00:00',
#                          'gate': '60',
#                          'iata': 'SYD',
#                          'icao': 'YSSY',
#                          'scheduled': '2021-04-24T09:30:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Australia/Sydney'},
#            'flight': {'codeshared': {'airline_iata': 'ua',
#                                      'airline_icao': 'ual',
#                                      'airline_name': 'united airlines',
#                                      'flight_iata': 'ua842',
#                                      'flight_icao': 'ual842',
#                                      'flight_number': '842'},
#                       'iata': 'LH7591',
#                       'icao': 'DLH7591',
#                       'number': '7591'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CZ',
#                        'icao': 'CSN',
#                        'name': 'China Southern Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T07:40:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T07:40:00+00:00',
#                        'terminal': '7',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Ted Stevens Anchorage International '
#                                     'Airport',
#                          'delay': 125,
#                          'estimated': '2021-04-24T01:50:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'ANC',
#                          'icao': 'PANC',
#                          'scheduled': '2021-04-24T01:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Anchorage'},
#            'flight': {'codeshared': None,
#                       'iata': 'CZ477',
#                       'icao': 'CSN477',
#                       'number': '477'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T21:00:00+00:00',
#                        'actual_runway': '2021-04-23T21:00:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': 5,
#                        'estimated': '2021-04-23T21:00:00+00:00',
#                        'estimated_runway': '2021-04-23T21:00:00+00:00',
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T21:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T02:25:00+00:00',
#                          'actual_runway': '2021-04-24T02:25:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 25,
#                          'estimated': '2021-04-24T02:00:00+00:00',
#                          'estimated_runway': '2021-04-24T02:25:00+00:00',
#                          'gate': None,
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T02:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': None,
#                       'iata': 'KE213D',
#                       'icao': 'KAL213D',
#                       'number': '213D'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'B6', 'icao': 'JBU', 'name': 'JetBlue Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:54:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '51B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:54:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 10,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E4',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'B62801',
#                       'icao': 'JBU2801',
#                       'number': '2801'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HA',
#                        'icao': 'HAL',
#                        'name': 'Hawaiian Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:54:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '51B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:54:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 10,
#                          'estimated': '2021-04-24T07:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E4',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-24T07:00:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'b6',
#                                      'airline_icao': 'jbu',
#                                      'airline_name': 'jetblue airways',
#                                      'flight_iata': 'b62801',
#                                      'flight_icao': 'jbu2801',
#                                      'flight_number': '2801'},
#                       'iata': 'HA2339',
#                       'icao': 'HAL2339',
#                       'number': '2339'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': None, 'icao': None, 'name': 'empty'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T10:24:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T10:24:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 19,
#                          'estimated': '2021-04-24T08:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-24T08:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': None,
#                       'icao': None,
#                       'number': None},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'D0', 'icao': 'DHK', 'name': 'DHL Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T02:05:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T02:05:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T07:51:00+00:00',
#                          'actual_runway': '2021-04-24T07:51:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 27,
#                          'estimated': '2021-04-24T07:25:00+00:00',
#                          'estimated_runway': '2021-04-24T07:51:00+00:00',
#                          'gate': None,
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T07:25:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': None,
#                       'iata': 'D096',
#                       'icao': 'DHK96',
#                       'number': '96'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'TG',
#                        'icao': 'THA',
#                        'name': 'Thai Airways International'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:50:00+00:00',
#                        'terminal': 'TBIT',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T14:50:00+00:00',
#                          'actual_runway': '2021-04-24T14:50:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 10,
#                          'estimated': '2021-04-24T14:40:00+00:00',
#                          'estimated_runway': '2021-04-24T14:50:00+00:00',
#                          'gate': '14',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T14:40:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'oz',
#                                      'airline_icao': 'aar',
#                                      'airline_name': 'asiana airlines',
#                                      'flight_iata': 'oz202',
#                                      'flight_icao': 'aar202',
#                                      'flight_number': '202'},
#                       'iata': 'TG6737',
#                       'icao': 'THA6737',
#                       'number': '6737'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'SQ',
#                        'icao': 'SIA',
#                        'name': 'Singapore Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:50:00+00:00',
#                        'terminal': 'TBIT',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T14:50:00+00:00',
#                          'actual_runway': '2021-04-24T14:50:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 10,
#                          'estimated': '2021-04-24T14:40:00+00:00',
#                          'estimated_runway': '2021-04-24T14:50:00+00:00',
#                          'gate': '14',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T14:40:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'oz',
#                                      'airline_icao': 'aar',
#                                      'airline_name': 'asiana airlines',
#                                      'flight_iata': 'oz202',
#                                      'flight_icao': 'aar202',
#                                      'flight_number': '202'},
#                       'iata': 'SQ5702',
#                       'icao': 'SIA5702',
#                       'number': '5702'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CM', 'icao': 'CMP', 'name': 'Copa Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:50:00+00:00',
#                        'terminal': 'TBIT',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T14:50:00+00:00',
#                          'actual_runway': '2021-04-24T14:50:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 10,
#                          'estimated': '2021-04-24T14:40:00+00:00',
#                          'estimated_runway': '2021-04-24T14:50:00+00:00',
#                          'gate': '14',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T14:40:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'oz',
#                                      'airline_icao': 'aar',
#                                      'airline_name': 'asiana airlines',
#                                      'flight_iata': 'oz202',
#                                      'flight_icao': 'aar202',
#                                      'flight_number': '202'},
#                       'iata': 'CM8000',
#                       'icao': 'CMP8000',
#                       'number': '8000'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'UA', 'icao': 'UAL', 'name': 'United Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:50:00+00:00',
#                        'terminal': 'TBIT',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T14:50:00+00:00',
#                          'actual_runway': '2021-04-24T14:50:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 10,
#                          'estimated': '2021-04-24T14:40:00+00:00',
#                          'estimated_runway': '2021-04-24T14:50:00+00:00',
#                          'gate': '14',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-24T14:40:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'oz',
#                                      'airline_icao': 'aar',
#                                      'airline_name': 'asiana airlines',
#                                      'flight_iata': 'oz202',
#                                      'flight_icao': 'aar202',
#                                      'flight_number': '202'},
#                       'iata': 'UA7285',
#                       'icao': 'UAL7285',
#                       'number': '7285'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': {'iata': 'A359',
#                         'icao': 'A359',
#                         'icao24': '71BF71',
#                         'registration': 'HL7771'},
#            'airline': {'iata': 'OZ', 'icao': 'AAR', 'name': 'Asiana Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T09:50:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:50:00+00:00',
#                        'terminal': 'TBIT',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T14:50:00+00:00',
#                          'actual_runway': '2021-04-24T14:50:00+00:00',
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 10,
#                          'estimated': '2021-04-24T14:40:00+00:00',
#                          'estimated_runway': '2021-04-24T14:50:00+00:00',
#                          'gate': '14',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
# ...
#                        'delay': None,
#                        'estimated': '2021-04-24T09:21:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '46B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:21:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'John F Kennedy International',
#                          'delay': 16,
#                          'estimated': '2021-04-24T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-24T06:00:00+00:00',
#                          'terminal': '8',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa33',
#                                      'flight_icao': 'aal33',
#                                      'flight_number': '33'},
#                       'iata': 'QF3212',
#                       'icao': 'QFA3212',
#                       'number': '3212'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'BA', 'icao': 'BAW', 'name': 'British Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-24T09:21:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '46B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:21:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'John F Kennedy International',
#                          'delay': 16,
#                          'estimated': '2021-04-24T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-24T06:00:00+00:00',
#                          'terminal': '8',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa33',
#                                      'flight_icao': 'aal33',
#                                      'flight_number': '33'},
#                       'iata': 'BA4310',
#                       'icao': 'BAW4310',
#                       'number': '4310'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'B6', 'icao': 'JBU', 'name': 'JetBlue Airways'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-24T09:21:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '46B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:21:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'John F Kennedy International',
#                          'delay': 16,
#                          'estimated': '2021-04-24T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-24T06:00:00+00:00',
#                          'terminal': '8',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa33',
#                                      'flight_icao': 'aal33',
#                                      'flight_number': '33'},
#                       'iata': 'B64013',
#                       'icao': 'JBU4013',
#                       'number': '4013'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AT', 'icao': 'RAM', 'name': 'Royal Air Maroc'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-24T09:21:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '46B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T09:21:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'John F Kennedy International',
#                          'delay': 16,
#                          'estimated': '2021-04-24T06:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-24T06:00:00+00:00',
#                          'terminal': '8',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa33',
#                                      'flight_icao': 'aal33',
#                                      'flight_number': '33'},
#                       'iata': 'AT5029',
#                       'icao': 'RAM5029',
#                       'number': '5029'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T12:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '28',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T12:28:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Detroit Metropolitan Wayne County',
#                          'delay': None,
#                          'estimated': '2021-04-24T10:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'A24',
#                          'iata': 'DTW',
#                          'icao': 'KDTW',
#                          'scheduled': '2021-04-24T10:30:00+00:00',
#                          'terminal': 'EM',
#                          'timezone': 'America/Detroit'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL793',
#                       'icao': 'DAL793',
#                       'number': '793'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T12:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T12:28:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Detroit Metropolitan Wayne County',
#                          'delay': None,
#                          'estimated': '2021-04-24T10:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'A24',
#                          'iata': 'DTW',
#                          'icao': 'KDTW',
#                          'scheduled': '2021-04-24T10:30:00+00:00',
#                          'terminal': 'EM',
#                          'timezone': 'America/Detroit'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl793',
#                                      'flight_icao': 'dal793',
#                                      'flight_number': '793'},
#                       'iata': 'AM4953',
#                       'icao': 'AMX4953',
#                       'number': '4953'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T12:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T12:55:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-24T10:41:00+00:00',
#                          'actual_runway': '2021-04-24T10:41:00+00:00',
#                          'airport': 'Charles De Gaulle',
#                          'delay': 26,
#                          'estimated': '2021-04-24T10:15:00+00:00',
#                          'estimated_runway': '2021-04-24T10:41:00+00:00',
#                          'gate': 'L34',
#                          'iata': 'CDG',
#                          'icao': 'LFPG',
#                          'scheduled': '2021-04-24T10:15:00+00:00',
#                          'terminal': '2E',
#                          'timezone': 'Europe/Paris'},
#            'flight': {'codeshared': None,
#                       'iata': 'AF66',
#                       'icao': 'AFR66',
#                       'number': '66'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'N8',
#                        'icao': 'NCR',
#                        'name': 'National Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T10:42:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T10:42:00+00:00',
#                        'terminal': None,
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Ted Stevens Anchorage International '
#                                     'Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-24T05:00:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'ANC',
#                          'icao': 'PANC',
#                          'scheduled': '2021-04-24T05:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Anchorage'},
#            'flight': {'codeshared': None,
#                       'iata': 'N8636',
#                       'icao': 'NCR636',
#                       'number': '636'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'UA', 'icao': 'UAL', 'name': 'United Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-24T15:17:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '76A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T15:17:00+00:00',
#                        'terminal': '7',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'San Francisco International',
#                          'delay': 15,
#                          'estimated': '2021-04-24T13:55:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E8',
#                          'iata': 'SFO',
#                          'icao': 'KSFO',
#                          'scheduled': '2021-04-24T13:55:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'UA2114',
#                       'icao': 'UAL2114',
#                       'number': '2114'},
#            'flight_date': '2021-04-24',
#            'flight_status': 'scheduled',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 123961}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-23',    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'NK', 'icao': 'NKS', 'name': 'Spirit Airlines'},
#            'arrival': {'actual': '2021-04-22T18:31:00+00:00',
#                        'actual_runway': '2021-04-22T18:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:52:00+00:00',
#                        'estimated_runway': '2021-04-22T18:31:00+00:00',
#                        'gate': 'D3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:52:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:56:00+00:00',
#                          'actual_runway': '2021-04-22T15:56:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 16,
#                          'estimated': '2021-04-22T15:40:00+00:00',
#                          'estimated_runway': '2021-04-22T15:56:00+00:00',
#                          'gate': '11',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-22T15:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'NK465',
#                       'icao': 'NKS465',
#                       'number': '465'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD876E',
#                         'registration': 'N971AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL977',
#                       'icao': 'DAL977',
#                       'number': '977'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'VS2924',
#                       'icao': 'VIR2924',
#                       'number': '2924'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AZ3245',
#                       'icao': 'AZA3245',
#                       'number': '3245'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'KL5257',
#                       'icao': 'KLM5257',
#                       'number': '5257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AF2905',
#                       'icao': 'AFR2905',
#                       'number': '2905'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A17C12',
#                         'registration': 'N195PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5043',
#                       'icao': 'DAL5043',
#                       'number': '5043'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Outagamie County',
#                          'delay': 3,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'VS2310',
#                       'icao': 'VIR2310',
#                       'number': '2310'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'KL6393',
#                       'icao': 'KLM6393',
#                       'number': '6393'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'AF2331',
#                       'icao': 'AFR2331',
#                       'number': '2331'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-22T17:25:00+00:00',
#                        'actual_runway': '2021-04-22T17:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '10',
#                        'delay': None,
#                        'estimated': '2021-04-22T17:50:00+00:00',
#                        'estimated_runway': '2021-04-22T17:25:00+00:00',
#                        'gate': 'T11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T17:50:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:35:00+00:00',
#                          'actual_runway': '2021-04-22T16:35:00+00:00',
#                          'airport': 'Charlotte Douglas',
#                          'delay': 12,
#                          'estimated': '2021-04-22T16:24:00+00:00',
#                          'estimated_runway': '2021-04-22T16:35:00+00:00',
#                          'gate': 'E14',
#                          'iata': 'CLT',
#                          'icao': 'KCLT',
#                          'scheduled': '2021-04-22T16:24:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA5360',
#                       'icao': 'AAL5360',
#                       'number': '5360'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'ADA16F',
#                         'registration': 'N978AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 5,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 6,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'AF2912',
#                       'icao': 'AFR2912',
#                       'number': '2912'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'KL5503',
#                       'icao': 'KLM5503',
#                       'number': '5503'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'VS2506',
#                       'icao': 'VIR2506',
#                       'number': '2506'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5131',
#                       'icao': 'DAL5131',
#                       'number': '5131'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A320',
#                         'icao': 'A320',
#                         'icao24': 'A3E5FA',
#                         'registration': 'N350NA'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:58:00+00:00',
#                        'actual_runway': '2021-04-22T19:58:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-22T20:26:00+00:00',
#                        'estimated_runway': '2021-04-22T19:58:00+00:00',
#                        'gate': 'T5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T20:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:18:00+00:00',
#                          'actual_runway': '2021-04-22T13:18:00+00:00',
#                          'airport': 'Spokane International',
#                          'delay': 8,
#                          'estimated': '2021-04-22T13:11:00+00:00',
#                          'estimated_runway': '2021-04-22T13:18:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'GEG',
#                          'icao': 'KGEG',
#                          'scheduled': '2021-04-22T13:11:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL499',
#                       'icao': 'DAL499',
#                       'number': '499'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5053',
#                       'icao': 'DAL5053',
#                       'number': '5053'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Eglin AFB',
#                          'delay': 3,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'VS2709',
#                       'icao': 'VIR2709',
#                       'number': '2709'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'WS7266',
#                       'icao': 'WJA7266',
#                       'number': '7266'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'KL6306',
#                       'icao': 'KLM6306',
#                       'number': '6306'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'AF2897',
#                       'icao': 'AFR2897',
#                       'number': '2897'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-22T18:09:00+00:00',
#                        'actual_runway': '2021-04-22T18:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:15:00+00:00',
#                        'estimated_runway': '2021-04-22T18:09:00+00:00',
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:20:00+00:00',
#                          'actual_runway': '2021-04-22T17:20:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 21,
#                          'estimated': '2021-04-22T17:00:00+00:00',
#                          'estimated_runway': '2021-04-22T17:20:00+00:00',
#                          'gate': 'C2',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T17:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN917',
#                       'icao': 'SWA917',
#                       'number': '917'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T17:51:00+00:00',
#                        'actual_runway': '2021-04-22T17:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:09:00+00:00',
#                        'estimated_runway': '2021-04-22T17:51:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:09:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:02:00+00:00',
#                          'actual_runway': '2021-04-22T17:02:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 8,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T17:02:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
# ...
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4829',
#                       'icao': 'DAL4829',
#                       'number': '4829'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'VS5418',
#                       'icao': 'VIR5418',
#                       'number': '5418'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'KL5011',
#                       'icao': 'KLM5011',
#                       'number': '5011'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AM3537',
#                       'icao': 'AMX3537',
#                       'number': '3537'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AF2341',
#                       'icao': 'AFR2341',
#                       'number': '2341'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5409',
#                       'icao': 'DAL5409',
#                       'number': '5409'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'KL5797',
#                       'icao': 'KLM5797',
#                       'number': '5797'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'AM3601',
#                       'icao': 'AMX3601',
#                       'number': '3601'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3165}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'LAX',
    'flight_date': '2021-04-23'
    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'AS', 'icao': 'ASA', 'name': 'Alaska Airlines'},
#            'arrival': {'actual': '2021-04-23T08:41:00+00:00',
#                        'actual_runway': '2021-04-23T08:41:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T5C5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:07:00+00:00',
#                        'estimated_runway': '2021-04-23T08:41:00+00:00',
#                        'gate': '54A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:07:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:41:00+00:00',
#                          'actual_runway': '2021-04-23T06:41:00+00:00',
#                          'airport': 'Nashville International',
#                          'delay': 12,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': '2021-04-23T06:41:00+00:00',
#                          'gate': 'C11',
#                          'iata': 'BNA',
#                          'icao': 'KBNA',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa2348',
#                                      'flight_icao': 'aal2348',
#                                      'flight_number': '2348'},
#                       'iata': 'AS6577',
#                       'icao': 'ASA6577',
#                       'number': '6577'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JL',
#                        'icao': 'JTL',
#                        'name': 'Jet Linx Aviation'},
#            'arrival': {'actual': '2021-04-23T08:41:00+00:00',
#                        'actual_runway': '2021-04-23T08:41:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T5C5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:07:00+00:00',
#                        'estimated_runway': '2021-04-23T08:41:00+00:00',
#                        'gate': '54A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:07:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:41:00+00:00',
#                          'actual_runway': '2021-04-23T06:41:00+00:00',
#                          'airport': 'Nashville International',
#                          'delay': 12,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': '2021-04-23T06:41:00+00:00',
#                          'gate': 'C11',
#                          'iata': 'BNA',
#                          'icao': 'KBNA',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa2348',
#                                      'flight_icao': 'aal2348',
#                                      'flight_number': '2348'},
#                       'iata': 'JL7557',
#                       'icao': 'JTL7557',
#                       'number': '7557'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'MH',
#                        'icao': 'MAS',
#                        'name': 'Malaysia Airlines'},
#            'arrival': {'actual': '2021-04-23T08:41:00+00:00',
#                        'actual_runway': '2021-04-23T08:41:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T5C5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:07:00+00:00',
#                        'estimated_runway': '2021-04-23T08:41:00+00:00',
#                        'gate': '54A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:07:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:41:00+00:00',
#                          'actual_runway': '2021-04-23T06:41:00+00:00',
#                          'airport': 'Nashville International',
#                          'delay': 12,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': '2021-04-23T06:41:00+00:00',
#                          'gate': 'C11',
#                          'iata': 'BNA',
#                          'icao': 'KBNA',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa2348',
#                                      'flight_icao': 'aal2348',
#                                      'flight_number': '2348'},
#                       'iata': 'MH9448',
#                       'icao': 'MAS9448',
#                       'number': '9448'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A21N',
#                         'icao': 'A21N',
#                         'icao24': 'A50E3F',
#                         'registration': 'N425AN'},
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-23T08:41:00+00:00',
#                        'actual_runway': '2021-04-23T08:41:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T5C5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:07:00+00:00',
#                        'estimated_runway': '2021-04-23T08:41:00+00:00',
#                        'gate': '54A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:07:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:41:00+00:00',
#                          'actual_runway': '2021-04-23T06:41:00+00:00',
#                          'airport': 'Nashville International',
#                          'delay': 12,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': '2021-04-23T06:41:00+00:00',
#                          'gate': 'C11',
#                          'iata': 'BNA',
#                          'icao': 'KBNA',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA2348',
#                       'icao': 'AAL2348',
#                       'number': '2348'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T10:48:00+00:00',
#                        'actual_runway': '2021-04-23T10:48:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T11:10:00+00:00',
#                        'estimated_runway': '2021-04-23T10:48:00+00:00',
#                        'gate': '23',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T11:10:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:58:00+00:00',
#                          'actual_runway': '2021-04-23T07:58:00+00:00',
#                          'airport': 'Logan International',
#                          'delay': 20,
#                          'estimated': '2021-04-23T07:38:00+00:00',
#                          'estimated_runway': '2021-04-23T07:58:00+00:00',
#                          'gate': 'A21',
#                          'iata': 'BOS',
#                          'icao': 'KBOS',
#                          'scheduled': '2021-04-23T07:38:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl312',
#                                      'flight_icao': 'dal312',
#                                      'flight_number': '312'},
#                       'iata': 'VS2160',
#                       'icao': 'VIR2160',
#                       'number': '2160'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B738',
#                         'icao': 'B738',
#                         'icao24': 'A44502',
#                         'registration': 'N3740C'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T10:48:00+00:00',
#                        'actual_runway': '2021-04-23T10:48:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T11:10:00+00:00',
#                        'estimated_runway': '2021-04-23T10:48:00+00:00',
#                        'gate': '23',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T11:10:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:58:00+00:00',
#                          'actual_runway': '2021-04-23T07:58:00+00:00',
#                          'airport': 'Logan International',
#                          'delay': 20,
#                          'estimated': '2021-04-23T07:38:00+00:00',
#                          'estimated_runway': '2021-04-23T07:58:00+00:00',
#                          'gate': 'A21',
#                          'iata': 'BOS',
#                          'icao': 'KBOS',
#                          'scheduled': '2021-04-23T07:38:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL312',
#                       'icao': 'DAL312',
#                       'number': '312'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A320',
#                         'icao': 'A320',
#                         'icao24': 'A7D751',
#                         'registration': 'N604NK'},
#            'airline': {'iata': 'NK', 'icao': 'NKS', 'name': 'Spirit Airlines'},
#            'arrival': {'actual': '2021-04-23T08:04:00+00:00',
#                        'actual_runway': '2021-04-23T08:04:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:33:00+00:00',
#                        'estimated_runway': '2021-04-23T08:04:00+00:00',
#                        'gate': '56',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:33:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:10:00+00:00',
#                          'actual_runway': '2021-04-23T06:10:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 5,
#                          'estimated': '2021-04-23T06:05:00+00:00',
#                          'estimated_runway': '2021-04-23T06:10:00+00:00',
#                          'gate': 'L11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:05:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'NK731',
#                       'icao': 'NKS731',
#                       'number': '731'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'JL',
#                        'icao': 'JTL',
#                        'name': 'Jet Linx Aviation'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:02:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '54B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:02:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 9,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'K13',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa669',
#                                      'flight_icao': 'aal669',
#                                      'flight_number': '669'},
#                       'iata': 'JL7523',
#                       'icao': 'JTL7523',
#                       'number': '7523'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'MH',
#                        'icao': 'MAS',
#                        'name': 'Malaysia Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:02:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '54B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:02:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 9,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'K13',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa669',
#                                      'flight_icao': 'aal669',
#                                      'flight_number': '669'},
#                       'iata': 'MH9583',
#                       'icao': 'MAS9583',
#                       'number': '9583'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': {'iata': 'B738',
#                         'icao': 'B738',
#                         'icao24': 'ADCDCC',
#                         'registration': 'N989NN'},
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C1',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:02:00+00:00',
#                        'estimated_runway': None,
#                        'gate': '54B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:02:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 9,
#                          'estimated': '2021-04-23T06:30:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'K13',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-23T06:30:00+00:00',
#                          'terminal': '3',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA669',
#                       'icao': 'AAL669',
#                       'number': '669'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'active',
#            'live': {'altitude': 0,
#                     'direction': 140,
#                     'is_ground': True,
#                     'latitude': 41.97,
#                     'longitude': -87.9,
#                     'speed_horizontal': 0,
#                     'speed_vertical': 0,
#                     'updated': '2021-04-24T11:26:05+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'MH',
#                        'icao': 'MAS',
#                        'name': 'Malaysia Airlines'},
#            'arrival': {'actual': '2021-04-23T08:01:00+00:00',
#                        'actual_runway': '2021-04-23T08:01:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C2',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:28:00+00:00',
#                        'estimated_runway': '2021-04-23T08:01:00+00:00',
#                        'gate': '47A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:28:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:10:00+00:00',
#                          'actual_runway': '2021-04-23T07:10:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 11,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:10:00+00:00',
#                          'gate': 'C29',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'C',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa524',
#                                      'flight_icao': 'aal524',
#                                      'flight_number': '524'},
#                       'iata': 'MH9486',
#                       'icao': 'MAS9486',
#                       'number': '9486'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A21N',
#                         'icao': 'A21N',
#                         'icao24': 'A4E307',
#                         'registration': 'N414AL'},
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-23T08:01:00+00:00',
#                        'actual_runway': '2021-04-23T08:01:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T4C2',
#                        'delay': None,
#                        'estimated': '2021-04-23T08:28:00+00:00',
#                        'estimated_runway': '2021-04-23T08:01:00+00:00',
#                        'gate': '47A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:28:00+00:00',
#                        'terminal': '4',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:10:00+00:00',
#                          'actual_runway': '2021-04-23T07:10:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 11,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:10:00+00:00',
#                          'gate': 'C29',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'C',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA524',
#                       'icao': 'AAL524',
#                       'number': '524'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'AF2621',
#                       'icao': 'AFR2621',
#                       'number': '2621'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'AM4703',
#                       'icao': 'AMX4703',
#                       'number': '4703'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'CI', 'icao': 'CAL', 'name': 'China Airlines'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'CI9004',
#                       'icao': 'CAL9004',
#                       'number': '9004'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'KE7406',
#                       'icao': 'KAL7406',
#                       'number': '7406'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'KL7819',
#                       'icao': 'KLM7819',
#                       'number': '7819'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'VS2075',
#                       'icao': 'VIR2075',
#                       'number': '2075'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl954',
#                                      'flight_icao': 'dal954',
#                                      'flight_number': '954'},
#                       'iata': 'WS6951',
#                       'icao': 'WJA6951',
#                       'number': '6951'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:03:00+00:00',
#                        'actual_runway': '2021-04-23T08:03:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:30:00+00:00',
#                        'estimated_runway': '2021-04-23T08:03:00+00:00',
#                        'gate': '24',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:30:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:12:00+00:00',
#                          'actual_runway': '2021-04-23T07:12:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 13,
#                          'estimated': '2021-04-23T07:00:00+00:00',
#                          'estimated_runway': '2021-04-23T07:12:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL954',
#                       'icao': 'DAL954',
#                       'number': '954'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T08:38:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T08:38:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': None,
#                          'estimated': '2021-04-23T07:04:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-23T07:04:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1765',
#                       'icao': 'DAL1765',
#                       'number': '1765'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'cancelled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T09:32:00+00:00',
#                        'actual_runway': '2021-04-23T09:32:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:47:00+00:00',
#                        'estimated_runway': '2021-04-23T09:32:00+00:00',
#                        'gate': '25B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:47:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:17:00+00:00',
#                          'actual_runway': '2021-04-23T07:17:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 5,
#                          'estimated': '2021-04-23T07:13:00+00:00',
#                          'estimated_runway': '2021-04-23T07:17:00+00:00',
#                          'gate': '84',
#                          'iata': 'MCO',
#                          'icao': 'KMCO',
#                          'scheduled': '2021-04-23T07:13:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl491',
#                                      'flight_icao': 'dal491',
#                                      'flight_number': '491'},
#                       'iata': 'KE7430',
#                       'icao': 'KAL7430',
#                       'number': '7430'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T09:32:00+00:00',
#                        'actual_runway': '2021-04-23T09:32:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:47:00+00:00',
#                        'estimated_runway': '2021-04-23T09:32:00+00:00',
#                        'gate': '25B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:47:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:17:00+00:00',
#                          'actual_runway': '2021-04-23T07:17:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 5,
#                          'estimated': '2021-04-23T07:13:00+00:00',
#                          'estimated_runway': '2021-04-23T07:17:00+00:00',
#                          'gate': '84',
#                          'iata': 'MCO',
#                          'icao': 'KMCO',
#                          'scheduled': '2021-04-23T07:13:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl491',
#                                      'flight_icao': 'dal491',
#                                      'flight_number': '491'},
#                       'iata': 'VS2223',
#                       'icao': 'VIR2223',
#                       'number': '2223'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T09:32:00+00:00',
#                        'actual_runway': '2021-04-23T09:32:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:47:00+00:00',
#                        'estimated_runway': '2021-04-23T09:32:00+00:00',
#                        'gate': '25B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:47:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T07:17:00+00:00',
#                          'actual_runway': '2021-04-23T07:17:00+00:00',
#                          'airport': 'Orlando International',
#                          'delay': 5,
#                          'estimated': '2021-04-23T07:13:00+00:00',
#                          'estimated_runway': '2021-04-23T07:17:00+00:00',
#                          'gate': '84',
#                          'iata': 'MCO',
#                          'icao': 'KMCO',
#                          'scheduled': '2021-04-23T07:13:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL491',
#                       'icao': 'DAL491',
#                       'number': '491'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'HY',
#                        'icao': 'UZB',
#                        'name': 'Uzbekistan Airways'},
#            'arrival': {'actual': '2021-04-23T17:21:00+00:00',
# ...
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'AF8858',
#                       'icao': 'AFR8858',
#                       'number': '8858'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'AM4375',
#                       'icao': 'AMX4375',
#                       'number': '4375'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'KE7200',
#                       'icao': 'KAL7200',
#                       'number': '7200'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'KL8121',
#                       'icao': 'KLM8121',
#                       'number': '8121'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'VS2249',
#                       'icao': 'VIR2249',
#                       'number': '2249'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl999',
#                                      'flight_icao': 'dal999',
#                                      'flight_number': '999'},
#                       'iata': 'WS6667',
#                       'icao': 'WJA6667',
#                       'number': '6667'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'AAFFED',
#                         'registration': 'N808DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-23T08:25:00+00:00',
#                        'actual_runway': '2021-04-23T08:25:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T09:00:00+00:00',
#                        'estimated_runway': '2021-04-23T08:25:00+00:00',
#                        'gate': '23B',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:00:00+00:00',
#                        'terminal': '2',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:37:00+00:00',
#                          'actual_runway': '2021-04-23T06:37:00+00:00',
#                          'airport': 'Louis Armstrong New Orléans International '
#                                     'Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-23T06:31:00+00:00',
#                          'estimated_runway': '2021-04-23T06:37:00+00:00',
#                          'gate': 'C6',
#                          'iata': 'MSY',
#                          'icao': 'KMSY',
#                          'scheduled': '2021-04-23T06:31:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL999',
#                       'icao': 'DAL999',
#                       'number': '999'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B763',
#                         'icao': 'B763',
#                         'icao24': 'A0EC20',
#                         'registration': 'N159FE'},
#            'airline': {'iata': 'FX', 'icao': 'FDX', 'name': 'FedEx'},
#            'arrival': {'actual': '2021-04-23T04:24:00+00:00',
#                        'actual_runway': '2021-04-23T04:24:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-23T04:29:00+00:00',
#                        'estimated_runway': '2021-04-23T04:24:00+00:00',
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T04:29:00+00:00',
#                        'terminal': '3',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T03:34:00+00:00',
#                          'actual_runway': '2021-04-23T03:34:00+00:00',
#                          'airport': 'Fort Worth Alliance',
#                          'delay': 4,
#                          'estimated': '2021-04-23T03:30:00+00:00',
#                          'estimated_runway': '2021-04-23T03:34:00+00:00',
#                          'gate': None,
#                          'iata': 'AFW',
#                          'icao': 'KAFW',
#                          'scheduled': '2021-04-23T03:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'FX1151',
#                       'icao': 'FDX1151',
#                       'number': '1151'},
#            'flight_date': '2021-04-23',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 1657}}
