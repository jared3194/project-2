# %%
import requests
import json
import os
import pandas as pd
from pprint import pprint

# %%
# Real time flights
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params).json()

ATL0424 = json.dumps(api_0424, indent = 4, sort_keys=True)

api_0424['data']

#pprint(api_response)

flight_id = []
flight_number = []
flight_type = []
iata = []
icao = []
arr_airport = []
dep_airport = []
terminal = []
gate = []
baggage = []
delay = []
scheduled_date = []
estimated_date = []
acutal_date = []
estimated_runway_date = []
actual_runway_date = []

for row in api_0424['data']:
    try:
        #flight_id.append(row[]),
        flight_number.append(row['flight']['number']),
        #flight_type.append(row['location']['address1']),
        iata.append(row['airline']['iata']),
        icao.append(row['airline']['icao']),
        arr_airport_id.append(row['arrival']['airport']),
        dep_airport_id.append(row['departure']['airport']),
        terminal.append(row['arrival']['terminal']),
        gate.append(row['arrival']['gate']),
        baggage.append(row['arrival']['baggage'])
    except:
        pass

# %%
json.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-2c11a81f75b5> in <module>
# ----> 1 json.keys()
#
# AttributeError: module 'json' has no attribute 'keys'

# %%
data = {'flight number': flight_number, 'iata': iata, 'icao': icao, 'arrive airport': arr_airport, 'depart airport': dep_airport, 'termimal': terminal, 'gate': gate, 'baggage': baggage}
ATL0424_df = pd.DataFrame(json['data'])
ATL0424_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-91e2add0ed35> in <module>
#       1 data = {'flight number': flight_number, 'iata': iata, 'icao': icao, 'arrive airport': arr_airport, 'depart airport': dep_airport, 'termimal': terminal, 'gate': gate, 'baggage': baggage}
# ----> 2 ATL0424_df = pd.DataFrame(json['data'])
#       3 ATL0424_df.head()
#
# TypeError: 'module' object is not subscriptable

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-23',    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'NK', 'icao': 'NKS', 'name': 'Spirit Airlines'},
#            'arrival': {'actual': '2021-04-22T18:31:00+00:00',
#                        'actual_runway': '2021-04-22T18:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:52:00+00:00',
#                        'estimated_runway': '2021-04-22T18:31:00+00:00',
#                        'gate': 'D3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:52:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:56:00+00:00',
#                          'actual_runway': '2021-04-22T15:56:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 16,
#                          'estimated': '2021-04-22T15:40:00+00:00',
#                          'estimated_runway': '2021-04-22T15:56:00+00:00',
#                          'gate': '11',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-22T15:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'NK465',
#                       'icao': 'NKS465',
#                       'number': '465'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD876E',
#                         'registration': 'N971AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL977',
#                       'icao': 'DAL977',
#                       'number': '977'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'VS2924',
#                       'icao': 'VIR2924',
#                       'number': '2924'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AZ3245',
#                       'icao': 'AZA3245',
#                       'number': '3245'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'KL5257',
#                       'icao': 'KLM5257',
#                       'number': '5257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AF2905',
#                       'icao': 'AFR2905',
#                       'number': '2905'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A17C12',
#                         'registration': 'N195PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5043',
#                       'icao': 'DAL5043',
#                       'number': '5043'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Outagamie County',
#                          'delay': 3,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'VS2310',
#                       'icao': 'VIR2310',
#                       'number': '2310'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'KL6393',
#                       'icao': 'KLM6393',
#                       'number': '6393'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'AF2331',
#                       'icao': 'AFR2331',
#                       'number': '2331'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-22T17:25:00+00:00',
#                        'actual_runway': '2021-04-22T17:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '10',
#                        'delay': None,
#                        'estimated': '2021-04-22T17:50:00+00:00',
#                        'estimated_runway': '2021-04-22T17:25:00+00:00',
#                        'gate': 'T11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T17:50:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:35:00+00:00',
#                          'actual_runway': '2021-04-22T16:35:00+00:00',
#                          'airport': 'Charlotte Douglas',
#                          'delay': 12,
#                          'estimated': '2021-04-22T16:24:00+00:00',
#                          'estimated_runway': '2021-04-22T16:35:00+00:00',
#                          'gate': 'E14',
#                          'iata': 'CLT',
#                          'icao': 'KCLT',
#                          'scheduled': '2021-04-22T16:24:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA5360',
#                       'icao': 'AAL5360',
#                       'number': '5360'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'ADA16F',
#                         'registration': 'N978AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 5,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 6,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'AF2912',
#                       'icao': 'AFR2912',
#                       'number': '2912'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'KL5503',
#                       'icao': 'KLM5503',
#                       'number': '5503'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'VS2506',
#                       'icao': 'VIR2506',
#                       'number': '2506'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5131',
#                       'icao': 'DAL5131',
#                       'number': '5131'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A320',
#                         'icao': 'A320',
#                         'icao24': 'A3E5FA',
#                         'registration': 'N350NA'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:58:00+00:00',
#                        'actual_runway': '2021-04-22T19:58:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-22T20:26:00+00:00',
#                        'estimated_runway': '2021-04-22T19:58:00+00:00',
#                        'gate': 'T5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T20:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:18:00+00:00',
#                          'actual_runway': '2021-04-22T13:18:00+00:00',
#                          'airport': 'Spokane International',
#                          'delay': 8,
#                          'estimated': '2021-04-22T13:11:00+00:00',
#                          'estimated_runway': '2021-04-22T13:18:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'GEG',
#                          'icao': 'KGEG',
#                          'scheduled': '2021-04-22T13:11:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL499',
#                       'icao': 'DAL499',
#                       'number': '499'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5053',
#                       'icao': 'DAL5053',
#                       'number': '5053'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Eglin AFB',
#                          'delay': 3,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'VS2709',
#                       'icao': 'VIR2709',
#                       'number': '2709'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'WS7266',
#                       'icao': 'WJA7266',
#                       'number': '7266'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'KL6306',
#                       'icao': 'KLM6306',
#                       'number': '6306'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'AF2897',
#                       'icao': 'AFR2897',
#                       'number': '2897'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-22T18:09:00+00:00',
#                        'actual_runway': '2021-04-22T18:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:15:00+00:00',
#                        'estimated_runway': '2021-04-22T18:09:00+00:00',
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:20:00+00:00',
#                          'actual_runway': '2021-04-22T17:20:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 21,
#                          'estimated': '2021-04-22T17:00:00+00:00',
#                          'estimated_runway': '2021-04-22T17:20:00+00:00',
#                          'gate': 'C2',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T17:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN917',
#                       'icao': 'SWA917',
#                       'number': '917'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T17:51:00+00:00',
#                        'actual_runway': '2021-04-22T17:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:09:00+00:00',
#                        'estimated_runway': '2021-04-22T17:51:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:09:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:02:00+00:00',
#                          'actual_runway': '2021-04-22T17:02:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 8,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T17:02:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
# ...
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4829',
#                       'icao': 'DAL4829',
#                       'number': '4829'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'VS5418',
#                       'icao': 'VIR5418',
#                       'number': '5418'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'KL5011',
#                       'icao': 'KLM5011',
#                       'number': '5011'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AM3537',
#                       'icao': 'AMX3537',
#                       'number': '3537'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AF2341',
#                       'icao': 'AFR2341',
#                       'number': '2341'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5409',
#                       'icao': 'DAL5409',
#                       'number': '5409'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'KL5797',
#                       'icao': 'KLM5797',
#                       'number': '5797'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'AM3601',
#                       'icao': 'AMX3601',
#                       'number': '3601'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3165}}

# %%
data = {'name': name, 'phone': phone, 'address1':address1, 'city': city, 'state': state, 'zip_code': zip_code, 'website': url, 'price': price, 'rating': rating, 'review_count': review_count}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-22'
    
}

api_0422 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0422.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'NK', 'icao': 'NKS', 'name': 'Spirit Airlines'},
#            'arrival': {'actual': '2021-04-22T18:31:00+00:00',
#                        'actual_runway': '2021-04-22T18:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:52:00+00:00',
#                        'estimated_runway': '2021-04-22T18:31:00+00:00',
#                        'gate': 'D3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:52:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:56:00+00:00',
#                          'actual_runway': '2021-04-22T15:56:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 16,
#                          'estimated': '2021-04-22T15:40:00+00:00',
#                          'estimated_runway': '2021-04-22T15:56:00+00:00',
#                          'gate': '11',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-22T15:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'NK465',
#                       'icao': 'NKS465',
#                       'number': '465'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD876E',
#                         'registration': 'N971AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL977',
#                       'icao': 'DAL977',
#                       'number': '977'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'VS2924',
#                       'icao': 'VIR2924',
#                       'number': '2924'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Adams Field Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AZ3245',
#                       'icao': 'AZA3245',
#                       'number': '3245'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'KL5257',
#                       'icao': 'KLM5257',
#                       'number': '5257'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T17:54:00+00:00',
#                        'actual_runway': '2021-04-22T17:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:14:00+00:00',
#                        'estimated_runway': '2021-04-22T17:54:00+00:00',
#                        'gate': 'B32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:14:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:50:00+00:00',
#                          'actual_runway': '2021-04-22T15:50:00+00:00',
#                          'airport': 'Adams Field Airport',
#                          'delay': 6,
#                          'estimated': '2021-04-22T15:45:00+00:00',
#                          'estimated_runway': '2021-04-22T15:50:00+00:00',
#                          'gate': '4',
#                          'iata': 'LIT',
#                          'icao': 'KLIT',
#                          'scheduled': '2021-04-22T15:45:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl977',
#                                      'flight_icao': 'dal977',
#                                      'flight_number': '977'},
#                       'iata': 'AF2905',
#                       'icao': 'AFR2905',
#                       'number': '2905'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A17C12',
#                         'registration': 'N195PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5043',
#                       'icao': 'DAL5043',
#                       'number': '5043'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Outagamie County',
#                          'delay': 3,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'VS2310',
#                       'icao': 'VIR2310',
#                       'number': '2310'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'KL6393',
#                       'icao': 'KLM6393',
#                       'number': '6393'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T19:03:00+00:00',
#                        'actual_runway': '2021-04-22T19:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T19:28:00+00:00',
#                        'estimated_runway': '2021-04-22T19:03:00+00:00',
#                        'gate': 'D27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T19:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:22:00+00:00',
#                          'actual_runway': '2021-04-22T16:22:00+00:00',
#                          'airport': 'Outagamie County',
#                          'delay': 17,
#                          'estimated': '2021-04-22T16:05:00+00:00',
#                          'estimated_runway': '2021-04-22T16:22:00+00:00',
#                          'gate': '3',
#                          'iata': 'ATW',
#                          'icao': 'KATW',
#                          'scheduled': '2021-04-22T16:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5043',
#                                      'flight_icao': 'dal5043',
#                                      'flight_number': '5043'},
#                       'iata': 'AF2331',
#                       'icao': 'AFR2331',
#                       'number': '2331'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-22T17:25:00+00:00',
#                        'actual_runway': '2021-04-22T17:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '10',
#                        'delay': None,
#                        'estimated': '2021-04-22T17:50:00+00:00',
#                        'estimated_runway': '2021-04-22T17:25:00+00:00',
#                        'gate': 'T11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T17:50:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:35:00+00:00',
#                          'actual_runway': '2021-04-22T16:35:00+00:00',
#                          'airport': 'Charlotte Douglas',
#                          'delay': 12,
#                          'estimated': '2021-04-22T16:24:00+00:00',
#                          'estimated_runway': '2021-04-22T16:35:00+00:00',
#                          'gate': 'E14',
#                          'iata': 'CLT',
#                          'icao': 'KCLT',
#                          'scheduled': '2021-04-22T16:24:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'AA5360',
#                       'icao': 'AAL5360',
#                       'number': '5360'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'ADA16F',
#                         'registration': 'N978AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 5,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2908',
#                       'icao': 'DAL2908',
#                       'number': '2908'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:11:00+00:00',
#                        'actual_runway': '2021-04-22T18:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:48:00+00:00',
#                        'estimated_runway': '2021-04-22T18:11:00+00:00',
#                        'gate': 'B03',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:48:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:52:00+00:00',
#                          'actual_runway': '2021-04-22T16:52:00+00:00',
#                          'airport': 'Hopkins International',
#                          'delay': 6,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T16:52:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'CLE',
#                          'icao': 'KCLE',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2908',
#                                      'flight_icao': 'dal2908',
#                                      'flight_number': '2908'},
#                       'iata': 'AF6854',
#                       'icao': 'AFR6854',
#                       'number': '6854'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'AF2912',
#                       'icao': 'AFR2912',
#                       'number': '2912'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'KL5503',
#                       'icao': 'KLM5503',
#                       'number': '5503'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5131',
#                                      'flight_icao': 'dal5131',
#                                      'flight_number': '5131'},
#                       'iata': 'VS2506',
#                       'icao': 'VIR2506',
#                       'number': '2506'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T16:32:00+00:00',
#                        'actual_runway': '2021-04-22T16:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T16:54:00+00:00',
#                        'estimated_runway': '2021-04-22T16:32:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T16:54:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T15:57:00+00:00',
#                          'actual_runway': '2021-04-22T15:57:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 7,
#                          'estimated': '2021-04-22T15:50:00+00:00',
#                          'estimated_runway': '2021-04-22T15:57:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-22T15:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5131',
#                       'icao': 'DAL5131',
#                       'number': '5131'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A320',
#                         'icao': 'A320',
#                         'icao24': 'A3E5FA',
#                         'registration': 'N350NA'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T19:58:00+00:00',
#                        'actual_runway': '2021-04-22T19:58:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-22T20:26:00+00:00',
#                        'estimated_runway': '2021-04-22T19:58:00+00:00',
#                        'gate': 'T5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T20:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:18:00+00:00',
#                          'actual_runway': '2021-04-22T13:18:00+00:00',
#                          'airport': 'Spokane International',
#                          'delay': 8,
#                          'estimated': '2021-04-22T13:11:00+00:00',
#                          'estimated_runway': '2021-04-22T13:18:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'GEG',
#                          'icao': 'KGEG',
#                          'scheduled': '2021-04-22T13:11:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Los_Angeles'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL499',
#                       'icao': 'DAL499',
#                       'number': '499'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5053',
#                       'icao': 'DAL5053',
#                       'number': '5053'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Eglin AFB',
#                          'delay': 3,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'VS2709',
#                       'icao': 'VIR2709',
#                       'number': '2709'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'WS7266',
#                       'icao': 'WJA7266',
#                       'number': '7266'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'KL6306',
#                       'icao': 'KLM6306',
#                       'number': '6306'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T18:10:00+00:00',
#                        'actual_runway': '2021-04-22T18:10:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:16:00+00:00',
#                        'estimated_runway': '2021-04-22T18:10:00+00:00',
#                        'gate': 'E34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:16:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T16:25:00+00:00',
#                          'actual_runway': '2021-04-22T16:25:00+00:00',
#                          'airport': 'Eglin AFB',
#                          'delay': 27,
#                          'estimated': '2021-04-22T15:59:00+00:00',
#                          'estimated_runway': '2021-04-22T16:25:00+00:00',
#                          'gate': 'B2',
#                          'iata': 'VPS',
#                          'icao': 'KVPS',
#                          'scheduled': '2021-04-22T15:59:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5053',
#                                      'flight_icao': 'dal5053',
#                                      'flight_number': '5053'},
#                       'iata': 'AF2897',
#                       'icao': 'AFR2897',
#                       'number': '2897'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-22T18:09:00+00:00',
#                        'actual_runway': '2021-04-22T18:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-22T18:15:00+00:00',
#                        'estimated_runway': '2021-04-22T18:09:00+00:00',
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:20:00+00:00',
#                          'actual_runway': '2021-04-22T17:20:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 21,
#                          'estimated': '2021-04-22T17:00:00+00:00',
#                          'estimated_runway': '2021-04-22T17:20:00+00:00',
#                          'gate': 'C2',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T17:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN917',
#                       'icao': 'SWA917',
#                       'number': '917'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-22T17:51:00+00:00',
#                        'actual_runway': '2021-04-22T17:51:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-22T18:09:00+00:00',
#                        'estimated_runway': '2021-04-22T17:51:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T18:09:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T17:02:00+00:00',
#                          'actual_runway': '2021-04-22T17:02:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 8,
#                          'estimated': '2021-04-22T16:55:00+00:00',
#                          'estimated_runway': '2021-04-22T17:02:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-22T16:55:00+00:00',
# ...
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4829',
#                       'icao': 'DAL4829',
#                       'number': '4829'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'VS5418',
#                       'icao': 'VIR5418',
#                       'number': '5418'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'KL5011',
#                       'icao': 'KLM5011',
#                       'number': '5011'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AM3537',
#                       'icao': 'AMX3537',
#                       'number': '3537'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-22T14:34:00+00:00',
#                        'actual_runway': '2021-04-22T14:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T15:04:00+00:00',
#                        'estimated_runway': '2021-04-22T14:34:00+00:00',
#                        'gate': 'D29',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T15:04:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T12:06:00+00:00',
#                          'actual_runway': '2021-04-22T12:06:00+00:00',
#                          'airport': 'Will Rogers World Airport',
#                          'delay': 4,
#                          'estimated': '2021-04-22T12:02:00+00:00',
#                          'estimated_runway': '2021-04-22T12:06:00+00:00',
#                          'gate': '20',
#                          'iata': 'OKC',
#                          'icao': 'KOKC',
#                          'scheduled': '2021-04-22T12:02:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4829',
#                                      'flight_icao': 'dal4829',
#                                      'flight_number': '4829'},
#                       'iata': 'AF2341',
#                       'icao': 'AFR2341',
#                       'number': '2341'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5409',
#                       'icao': 'DAL5409',
#                       'number': '5409'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'KL5797',
#                       'icao': 'KLM5797',
#                       'number': '5797'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-22T13:40:00+00:00',
#                        'actual_runway': '2021-04-22T13:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-22T13:57:00+00:00',
#                        'estimated_runway': '2021-04-22T13:40:00+00:00',
#                        'gate': 'D12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-22T13:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-22T13:11:00+00:00',
#                          'actual_runway': '2021-04-22T13:11:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 16,
#                          'estimated': '2021-04-22T12:55:00+00:00',
#                          'estimated_runway': '2021-04-22T13:11:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-22T12:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5409',
#                                      'flight_icao': 'dal5409',
#                                      'flight_number': '5409'},
#                       'iata': 'AM3601',
#                       'icao': 'AMX3601',
#                       'number': '3601'},
#            'flight_date': '2021-04-22',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3165}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-21'
    
}

api_0421 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0421.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-20'
    
}

api_0420 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0420.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2357',
#                       'icao': 'DAL2357',
#                       'number': '2357'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AZ', 'icao': 'AZA', 'name': 'Alitalia'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'AZ3361',
#                       'icao': 'AZA3361',
#                       'number': '3361'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'WS6934',
#                       'icao': 'WJA6934',
#                       'number': '6934'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'VS2257',
#                       'icao': 'VIR2257',
#                       'number': '2257'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'KL5511',
#                       'icao': 'KLM5511',
#                       'number': '5511'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T13:53:00+00:00',
#                          'estimated_runway': '2021-04-20T13:52:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-20T13:53:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2357',
#                                      'flight_icao': 'dal2357',
#                                      'flight_number': '2357'},
#                       'iata': 'AF3491',
#                       'icao': 'AFR3491',
#                       'number': '3491'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1480',
#                                      'flight_icao': 'dal1480',
#                                      'flight_number': '1480'},
#                       'iata': 'AM3589',
#                       'icao': 'AMX3589',
#                       'number': '3589'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1480',
#                                      'flight_icao': 'dal1480',
#                                      'flight_number': '1480'},
#                       'iata': 'KE3723',
#                       'icao': 'KAL3723',
#                       'number': '3723'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B739',
#                         'icao': 'B739',
#                         'icao24': 'AB2B23',
#                         'registration': 'N819DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:26:00+00:00',
#                        'actual_runway': '2021-04-20T07:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:26:00+00:00',
#                        'gate': 'A34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': 'B11',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1480',
#                       'icao': 'DAL1480',
#                       'number': '1480'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1172',
#                                      'flight_icao': 'dal1172',
#                                      'flight_number': '1172'},
#                       'iata': 'AM4319',
#                       'icao': 'AMX4319',
#                       'number': '4319'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1172',
#                                      'flight_icao': 'dal1172',
#                                      'flight_number': '1172'},
#                       'iata': 'KE3667',
#                       'icao': 'KAL3667',
#                       'number': '3667'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:08:00+00:00',
#                        'actual_runway': '2021-04-20T07:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:21:00+00:00',
#                        'estimated_runway': '2021-04-20T07:08:00+00:00',
#                        'gate': 'A05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:21:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:09:00+00:00',
#                          'actual_runway': '2021-04-20T06:09:00+00:00',
#                          'airport': 'Daytona Beach International Airport',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:09:00+00:00',
#                          'gate': '06',
#                          'iata': 'DAB',
#                          'icao': 'KDAB',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1172',
#                       'icao': 'DAL1172',
#                       'number': '1172'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:31:00+00:00',
#                        'actual_runway': '2021-04-20T07:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:31:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:19:00+00:00',
#                          'actual_runway': '2021-04-20T06:19:00+00:00',
#                          'airport': 'Albert J Ellis',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:19:00+00:00',
#                          'gate': '02',
#                          'iata': 'OAJ',
#                          'icao': 'KOAJ',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4830',
#                                      'flight_icao': 'dal4830',
#                                      'flight_number': '4830'},
#                       'iata': 'KE6980',
#                       'icao': 'KAL6980',
#                       'number': '6980'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:31:00+00:00',
#                        'actual_runway': '2021-04-20T07:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:31:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:19:00+00:00',
#                          'actual_runway': '2021-04-20T06:19:00+00:00',
#                          'airport': 'Albert J Ellis',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:19:00+00:00',
#                          'gate': '02',
#                          'iata': 'OAJ',
#                          'icao': 'KOAJ',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4830',
#                       'icao': 'DAL4830',
#                       'number': '4830'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:29:00+00:00',
#                        'actual_runway': '2021-04-20T07:29:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:29:00+00:00',
#                        'gate': 'B7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Sarasota/Bradenton International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'SRQ',
#                          'icao': 'KSRQ',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2272',
#                                      'flight_icao': 'dal2272',
#                                      'flight_number': '2272'},
#                       'iata': 'AM3490',
#                       'icao': 'AMX3490',
#                       'number': '3490'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A321',
#                         'icao': 'A321',
#                         'icao24': 'A3FB6F',
#                         'registration': 'N356DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:29:00+00:00',
#                        'actual_runway': '2021-04-20T07:29:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T07:40:00+00:00',
#                        'estimated_runway': '2021-04-20T07:29:00+00:00',
#                        'gate': 'B7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T07:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Sarasota/Bradenton International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'B4',
#                          'iata': 'SRQ',
#                          'icao': 'KSRQ',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2272',
#                       'icao': 'DAL2272',
#                       'number': '2272'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'AM3809',
#                       'icao': 'AMX3809',
#                       'number': '3809'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'KE3566',
#                       'icao': 'KAL3566',
#                       'number': '3566'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'KL6600',
#                       'icao': 'KLM6600',
#                       'number': '6600'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2647',
#                                      'flight_icao': 'dal2647',
#                                      'flight_number': '2647'},
#                       'iata': 'VS2261',
#                       'icao': 'VIR2261',
#                       'number': '2261'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:56:00+00:00',
#                        'actual_runway': '2021-04-20T08:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:59:00+00:00',
#                        'estimated_runway': '2021-04-20T08:56:00+00:00',
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:22:00+00:00',
#                          'actual_runway': '2021-04-20T06:22:00+00:00',
#                          'airport': 'International Jetport',
#                          'delay': 22,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:22:00+00:00',
#                          'gate': '8',
#                          'iata': 'PWM',
#                          'icao': 'KPWM',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2647',
#                       'icao': 'DAL2647',
#                       'number': '2647'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:06:00+00:00',
#                        'actual_runway': '2021-04-20T08:06:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:28:00+00:00',
#                        'estimated_runway': '2021-04-20T08:06:00+00:00',
#                        'gate': 'A10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:10:00+00:00',
#                          'actual_runway': '2021-04-20T06:10:00+00:00',
#                          'airport': 'John F Kennedy International',
#                          'delay': 10,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:10:00+00:00',
#                          'gate': 'B38',
#                          'iata': 'JFK',
#                          'icao': 'KJFK',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': '4',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL424',
#                       'icao': 'DAL424',
#                       'number': '424'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:21:00+00:00',
#                        'actual_runway': '2021-04-20T08:21:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:42:00+00:00',
#                        'estimated_runway': '2021-04-20T08:21:00+00:00',
#                        'gate': 'B11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:42:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Bradley International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': '12',
#                          'iata': 'BDL',
#                          'icao': 'KBDL',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1198',
#                                      'flight_icao': 'dal1198',
#                                      'flight_number': '1198'},
#                       'iata': 'AM5585',
#                       'icao': 'AMX5585',
#                       'number': '5585'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD4395',
#                         'registration': 'N954AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:21:00+00:00',
#                        'actual_runway': '2021-04-20T08:21:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:42:00+00:00',
#                        'estimated_runway': '2021-04-20T08:21:00+00:00',
#                        'gate': 'B11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:42:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:07:00+00:00',
#                          'actual_runway': '2021-04-20T06:07:00+00:00',
#                          'airport': 'Bradley International',
#                          'delay': 2,
#                          'estimated': '2021-04-20T06:05:00+00:00',
#                          'estimated_runway': '2021-04-20T06:07:00+00:00',
#                          'gate': '12',
#                          'iata': 'BDL',
#                          'icao': 'KBDL',
#                          'scheduled': '2021-04-20T06:05:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1198',
#                       'icao': 'DAL1198',
#                       'number': '1198'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T07:38:00+00:00',
#                        'actual_runway': '2021-04-20T07:38:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:10:00+00:00',
# ...
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1458',
#                                      'flight_icao': 'dal1458',
#                                      'flight_number': '1458'},
#                       'iata': 'AM3351',
#                       'icao': 'AMX3351',
#                       'number': '3351'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T07:45:00+00:00',
#                        'actual_runway': '2021-04-20T07:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:05:00+00:00',
#                        'estimated_runway': '2021-04-20T07:45:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1458',
#                                      'flight_icao': 'dal1458',
#                                      'flight_number': '1458'},
#                       'iata': 'KE3718',
#                       'icao': 'KAL3718',
#                       'number': '3718'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD6B14',
#                         'registration': 'N964AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T07:45:00+00:00',
#                        'actual_runway': '2021-04-20T07:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:05:00+00:00',
#                        'estimated_runway': '2021-04-20T07:45:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:09:00+00:00',
#                          'actual_runway': '2021-04-20T07:09:00+00:00',
#                          'airport': 'Greenville Spartanburg International '
#                                     'Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:09:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'GSP',
#                          'icao': 'KGSP',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1458',
#                       'icao': 'DAL1458',
#                       'number': '1458'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1647',
#                                      'flight_icao': 'dal1647',
#                                      'flight_number': '1647'},
#                       'iata': 'AM5132',
#                       'icao': 'AMX5132',
#                       'number': '5132'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1647',
#                                      'flight_icao': 'dal1647',
#                                      'flight_number': '1647'},
#                       'iata': 'KE3797',
#                       'icao': 'KAL3797',
#                       'number': '3797'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A321',
#                         'icao': 'A321',
#                         'icao24': 'A3BDA6',
#                         'registration': 'N340DN'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T08:45:00+00:00',
#                        'actual_runway': '2021-04-20T08:45:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-20T09:05:00+00:00',
#                        'estimated_runway': '2021-04-20T08:45:00+00:00',
#                        'gate': 'A11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T09:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T06:14:00+00:00',
#                          'actual_runway': '2021-04-20T06:14:00+00:00',
#                          'airport': 'Dallas/Fort Worth International',
#                          'delay': 15,
#                          'estimated': '2021-04-20T06:00:00+00:00',
#                          'estimated_runway': '2021-04-20T06:14:00+00:00',
#                          'gate': 'E13',
#                          'iata': 'DFW',
#                          'icao': 'KDFW',
#                          'scheduled': '2021-04-20T06:00:00+00:00',
#                          'terminal': 'E',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1647',
#                       'icao': 'DAL1647',
#                       'number': '1647'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-20T08:15:00+00:00',
#                        'actual_runway': '2021-04-20T08:15:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:34:00+00:00',
#                        'estimated_runway': '2021-04-20T08:15:00+00:00',
#                        'gate': 'A27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:13:00+00:00',
#                          'actual_runway': '2021-04-20T07:13:00+00:00',
#                          'airport': 'Raleigh-durham International Airport',
#                          'delay': 13,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:13:00+00:00',
#                          'gate': 'C1',
#                          'iata': 'RDU',
#                          'icao': 'KRDU',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1585',
#                                      'flight_icao': 'dal1585',
#                                      'flight_number': '1585'},
#                       'iata': 'AM3814',
#                       'icao': 'AMX3814',
#                       'number': '3814'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-20T08:15:00+00:00',
#                        'actual_runway': '2021-04-20T08:15:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-20T08:34:00+00:00',
#                        'estimated_runway': '2021-04-20T08:15:00+00:00',
#                        'gate': 'A27',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T08:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T07:13:00+00:00',
#                          'actual_runway': '2021-04-20T07:13:00+00:00',
#                          'airport': 'Raleigh-durham International Airport',
#                          'delay': 13,
#                          'estimated': '2021-04-20T07:00:00+00:00',
#                          'estimated_runway': '2021-04-20T07:13:00+00:00',
#                          'gate': 'C1',
#                          'iata': 'RDU',
#                          'icao': 'KRDU',
#                          'scheduled': '2021-04-20T07:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1585',
#                                      'flight_icao': 'dal1585',
#                                      'flight_number': '1585'},
#                       'iata': 'KE3732',
#                       'icao': 'KAL3732',
#                       'number': '3732'},
#            'flight_date': '2021-04-20',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 2864}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-19'
    
}

api_0419 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0419.json()

#pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:34:00+00:00',
#                        'actual_runway': '2021-04-19T12:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:56:00+00:00',
#                        'estimated_runway': '2021-04-19T12:34:00+00:00',
#                        'gate': 'T08',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:56:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:17:00+00:00',
#                          'actual_runway': '2021-04-19T11:17:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T11:07:00+00:00',
#                          'estimated_runway': '2021-04-19T11:17:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1448',
#                                      'flight_icao': 'dal1448',
#                                      'flight_number': '1448'},
#                       'iata': 'VS2674',
#                       'icao': 'VIR2674',
#                       'number': '2674'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:52:00+00:00',
#                        'actual_runway': '2021-04-19T20:52:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T21:15:00+00:00',
#                        'estimated_runway': '2021-04-19T20:52:00+00:00',
#                        'gate': 'E26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T21:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T19:35:00+00:00',
#                          'actual_runway': '2021-04-19T19:35:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 5,
#                          'estimated': '2021-04-19T19:30:00+00:00',
#                          'estimated_runway': '2021-04-19T19:35:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T19:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1492',
#                                      'flight_icao': 'dal1492',
#                                      'flight_number': '1492'},
#                       'iata': 'KL5161',
#                       'icao': 'KLM5161',
#                       'number': '5161'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:34:00+00:00',
#                        'actual_runway': '2021-04-19T12:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:56:00+00:00',
#                        'estimated_runway': '2021-04-19T12:34:00+00:00',
#                        'gate': 'T08',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:56:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:17:00+00:00',
#                          'actual_runway': '2021-04-19T11:17:00+00:00',
#                          'airport': 'Pittsburgh International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T11:07:00+00:00',
#                          'estimated_runway': '2021-04-19T11:17:00+00:00',
#                          'gate': 'D76',
#                          'iata': 'PIT',
#                          'icao': 'KPIT',
#                          'scheduled': '2021-04-19T11:07:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1448',
#                       'icao': 'DAL1448',
#                       'number': '1448'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A333',
#                         'icao': 'A333',
#                         'icao24': '484FFF',
#                         'registration': 'PH-AKE'},
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:03:00+00:00',
#                        'actual_runway': '2021-04-19T20:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': 'F1',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:30:00+00:00',
#                        'estimated_runway': '2021-04-19T20:03:00+00:00',
#                        'gate': 'E14',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:30:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:59:00+00:00',
#                          'actual_runway': '2021-04-19T16:59:00+00:00',
#                          'airport': 'Schiphol',
#                          'delay': None,
#                          'estimated': '2021-04-19T17:00:00+00:00',
#                          'estimated_runway': '2021-04-19T16:59:00+00:00',
#                          'gate': 'D43',
#                          'iata': 'AMS',
#                          'icao': 'EHAM',
#                          'scheduled': '2021-04-19T17:00:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Europe/Amsterdam'},
#            'flight': {'codeshared': None,
#                       'iata': 'KL621',
#                       'icao': 'KLM621',
#                       'number': '621'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'A319',
#                         'icao': 'A319',
#                         'icao24': 'A3D4C6',
#                         'registration': 'N346NB'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T18:05:00+00:00',
#                        'actual_runway': '2021-04-19T18:05:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': 39,
#                        'estimated': '2021-04-19T17:26:00+00:00',
#                        'estimated_runway': '2021-04-19T18:05:00+00:00',
#                        'gate': 'T04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T17:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:22:00+00:00',
#                          'actual_runway': '2021-04-19T16:22:00+00:00',
#                          'airport': 'International',
#                          'delay': 56,
#                          'estimated': '2021-04-19T15:26:00+00:00',
#                          'estimated_runway': '2021-04-19T16:22:00+00:00',
#                          'gate': 'ARR',
#                          'iata': 'EYW',
#                          'icao': 'KEYW',
#                          'scheduled': '2021-04-19T15:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2371',
#                       'icao': 'DAL2371',
#                       'number': '2371'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T18:05:00+00:00',
#                        'actual_runway': '2021-04-19T18:05:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': 39,
#                        'estimated': '2021-04-19T17:26:00+00:00',
#                        'estimated_runway': '2021-04-19T18:05:00+00:00',
#                        'gate': 'T04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T17:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:22:00+00:00',
#                          'actual_runway': '2021-04-19T16:22:00+00:00',
#                          'airport': 'International',
#                          'delay': 56,
#                          'estimated': '2021-04-19T15:26:00+00:00',
#                          'estimated_runway': '2021-04-19T16:22:00+00:00',
#                          'gate': 'ARR',
#                          'iata': 'EYW',
#                          'icao': 'KEYW',
#                          'scheduled': '2021-04-19T15:26:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2371',
#                                      'flight_icao': 'dal2371',
#                                      'flight_number': '2371'},
#                       'iata': 'KL5807',
#                       'icao': 'KLM5807',
#                       'number': '5807'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4791',
#                                      'flight_icao': 'dal4791',
#                                      'flight_number': '4791'},
#                       'iata': 'KL6911',
#                       'icao': 'KLM6911',
#                       'number': '6911'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4791',
#                                      'flight_icao': 'dal4791',
#                                      'flight_number': '4791'},
#                       'iata': 'VS2811',
#                       'icao': 'VIR2811',
#                       'number': '2811'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T18:17:00+00:00',
#                        'actual_runway': '2021-04-19T18:17:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:31:00+00:00',
#                        'estimated_runway': '2021-04-19T18:17:00+00:00',
#                        'gate': 'D26',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:31:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T16:40:00+00:00',
#                          'actual_runway': '2021-04-19T16:40:00+00:00',
#                          'airport': 'Dothan Airport',
#                          'delay': 5,
#                          'estimated': '2021-04-19T16:36:00+00:00',
#                          'estimated_runway': '2021-04-19T16:40:00+00:00',
#                          'gate': None,
#                          'iata': 'DHN',
#                          'icao': 'KDHN',
#                          'scheduled': '2021-04-19T16:36:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4791',
#                       'icao': 'DAL4791',
#                       'number': '4791'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'AF2095',
#                       'icao': 'AFR2095',
#                       'number': '2095'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'KL6367',
#                       'icao': 'KLM6367',
#                       'number': '6367'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Harrisburg International',
#                          'delay': 10,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4847',
#                                      'flight_icao': 'dal4847',
#                                      'flight_number': '4847'},
#                       'iata': 'VS2226',
#                       'icao': 'VIR2226',
#                       'number': '2226'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:14:00+00:00',
#                        'actual_runway': '2021-04-19T19:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:41:00+00:00',
#                        'estimated_runway': '2021-04-19T19:14:00+00:00',
#                        'gate': 'E30',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:41:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:42:00+00:00',
#                          'actual_runway': '2021-04-19T17:42:00+00:00',
#                          'airport': 'Harrisburg International',
#                          'delay': 8,
#                          'estimated': '2021-04-19T17:35:00+00:00',
#                          'estimated_runway': '2021-04-19T17:42:00+00:00',
#                          'gate': 'A3',
#                          'iata': 'MDT',
#                          'icao': 'KMDT',
#                          'scheduled': '2021-04-19T17:35:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4847',
#                       'icao': 'DAL4847',
#                       'number': '4847'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 32,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'AF3726',
#                       'icao': 'AFR3726',
#                       'number': '3726'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'D41',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 4,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '13',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4759',
#                                      'flight_icao': 'dal4759',
#                                      'flight_number': '4759'},
#                       'iata': 'KL6811',
#                       'icao': 'KLM6811',
#                       'number': '6811'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 9,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'KL5223',
#                       'icao': 'KLM5223',
#                       'number': '5223'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 9,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2038',
#                                      'flight_icao': 'dal2038',
#                                      'flight_number': '2038'},
#                       'iata': 'VS3209',
#                       'icao': 'VIR3209',
#                       'number': '3209'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:09:00+00:00',
#                        'actual_runway': '2021-04-19T19:09:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T19:10:00+00:00',
#                        'estimated_runway': '2021-04-19T19:09:00+00:00',
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T19:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T18:29:00+00:00',
#                          'actual_runway': '2021-04-19T18:29:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 32,
#                          'estimated': '2021-04-19T17:57:00+00:00',
#                          'estimated_runway': '2021-04-19T18:29:00+00:00',
#                          'gate': '11',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-19T17:57:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2038',
#                       'icao': 'DAL2038',
#                       'number': '2038'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': 53,
#                        'estimated': '2021-04-19T13:15:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T13:15:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T13:33:00+00:00',
#                          'actual_runway': '2021-04-19T13:33:00+00:00',
#                          'airport': 'Bush Field',
#                          'delay': 78,
#                          'estimated': '2021-04-19T12:15:00+00:00',
#                          'estimated_runway': '2021-04-19T13:33:00+00:00',
#                          'gate': '1',
#                          'iata': 'AGS',
#                          'icao': 'KAGS',
#                          'scheduled': '2021-04-19T12:15:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5559',
#                       'icao': 'DAL5559',
#                       'number': '5559'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'AF5873',
#                       'icao': 'AFR5873',
#                       'number': '5873'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'KL5669',
#                       'icao': 'KLM5669',
#                       'number': '5669'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'William P Hobby',
#                          'delay': 3,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1720',
#                                      'flight_icao': 'dal1720',
#                                      'flight_number': '1720'},
#                       'iata': 'VS5122',
#                       'icao': 'VIR5122',
#                       'number': '5122'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T19:41:00+00:00',
#                        'actual_runway': '2021-04-19T19:41:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-19T20:07:00+00:00',
#                        'estimated_runway': '2021-04-19T19:41:00+00:00',
#                        'gate': 'B10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:07:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:09:00+00:00',
#                          'actual_runway': '2021-04-19T17:09:00+00:00',
#                          'airport': 'William P Hobby',
#                          'delay': 5,
#                          'estimated': '2021-04-19T17:05:00+00:00',
#                          'estimated_runway': '2021-04-19T17:09:00+00:00',
#                          'gate': '32',
#                          'iata': 'HOU',
#                          'icao': 'KHOU',
#                          'scheduled': '2021-04-19T17:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1720',
#                       'icao': 'DAL1720',
#                       'number': '1720'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B737',
#                         'icao': 'B737',
#                         'icao24': 'A2BB10',
#                         'registration': 'N275WN'},
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-19T20:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T20:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:22:00+00:00',
#                          'actual_runway': '2021-04-19T17:22:00+00:00',
#                          'airport': 'Austin-bergstrom International',
#                          'delay': 28,
#                          'estimated': '2021-04-19T16:55:00+00:00',
#                          'estimated_runway': '2021-04-19T17:22:00+00:00',
#                          'gate': '16',
#                          'iata': 'AUS',
#                          'icao': 'KAUS',
#                          'scheduled': '2021-04-19T16:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN189',
#                       'icao': 'SWA189',
#                       'number': '189'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'active',
#            'live': {'altitude': 8938.26,
#                     'direction': 138.32,
#                     'is_ground': True,
#                     'latitude': 33.64,
#                     'longitude': -84.43,
#                     'speed_horizontal': 927.432,
#                     'speed_vertical': -47.988,
#                     'updated': '2021-04-20T01:33:58+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-19T18:33:00+00:00',
#                        'actual_runway': '2021-04-19T18:33:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-19T18:50:00+00:00',
#                        'estimated_runway': '2021-04-19T18:33:00+00:00',
#                        'gate': 'B34',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T18:50:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T17:58:00+00:00',
#                          'actual_runway': '2021-04-19T17:58:00+00:00',
#                          'airport': 'Asheville Regional Airport',
#                          'delay': 18,
#                          'estimated': '2021-04-19T17:40:00+00:00',
#                          'estimated_runway': '2021-04-19T17:58:00+00:00',
#                          'gate': '2',
#                          'iata': 'AVL',
#                          'icao': 'KAVL',
#                          'scheduled': '2021-04-19T17:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
# ...
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5287',
#                                      'flight_icao': 'dal5287',
#                                      'flight_number': '5287'},
#                       'iata': 'VS2959',
#                       'icao': 'VIR2959',
#                       'number': '2959'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5287',
#                                      'flight_icao': 'dal5287',
#                                      'flight_number': '5287'},
#                       'iata': 'WS6721',
#                       'icao': 'WJA6721',
#                       'number': '6721'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T20:54:00+00:00',
#                        'actual_runway': '2021-04-19T20:54:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T21:28:00+00:00',
#                        'estimated_runway': '2021-04-19T20:54:00+00:00',
#                        'gate': 'D9A',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T21:28:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T19:01:00+00:00',
#                          'actual_runway': '2021-04-19T19:01:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 7,
#                          'estimated': '2021-04-19T18:55:00+00:00',
#                          'estimated_runway': '2021-04-19T19:01:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T18:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4971',
#                                      'flight_icao': 'dal4971',
#                                      'flight_number': '4971'},
#                       'iata': 'KL5317',
#                       'icao': 'KLM5317',
#                       'number': '5317'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:32:00+00:00',
#                        'actual_runway': '2021-04-19T12:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:55:00+00:00',
#                        'estimated_runway': '2021-04-19T12:32:00+00:00',
#                        'gate': 'E33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T10:42:00+00:00',
#                          'actual_runway': '2021-04-19T10:42:00+00:00',
#                          'airport': 'Jackson-evers',
#                          'delay': 9,
#                          'estimated': '2021-04-19T10:34:00+00:00',
#                          'estimated_runway': '2021-04-19T10:42:00+00:00',
#                          'gate': '17',
#                          'iata': 'JAN',
#                          'icao': 'KJAN',
#                          'scheduled': '2021-04-19T10:34:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5287',
#                       'icao': 'DAL5287',
#                       'number': '5287'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-19T12:11:00+00:00',
#                        'actual_runway': '2021-04-19T12:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:37:00+00:00',
#                        'estimated_runway': '2021-04-19T12:11:00+00:00',
#                        'gate': 'A18',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:37:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:24:00+00:00',
#                          'actual_runway': '2021-04-19T11:24:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 4,
#                          'estimated': '2021-04-19T11:20:00+00:00',
#                          'estimated_runway': '2021-04-19T11:24:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-19T11:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1682',
#                                      'flight_icao': 'dal1682',
#                                      'flight_number': '1682'},
#                       'iata': 'WS6775',
#                       'icao': 'WJA6775',
#                       'number': '6775'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-19T12:11:00+00:00',
#                        'actual_runway': '2021-04-19T12:11:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:37:00+00:00',
#                        'estimated_runway': '2021-04-19T12:11:00+00:00',
#                        'gate': 'A18',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:37:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:24:00+00:00',
#                          'actual_runway': '2021-04-19T11:24:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 4,
#                          'estimated': '2021-04-19T11:20:00+00:00',
#                          'estimated_runway': '2021-04-19T11:24:00+00:00',
#                          'gate': 'A9',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-19T11:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1682',
#                       'icao': 'DAL1682',
#                       'number': '1682'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-19T12:40:00+00:00',
#                        'actual_runway': '2021-04-19T12:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:59:00+00:00',
#                        'estimated_runway': '2021-04-19T12:40:00+00:00',
#                        'gate': 'D39',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:51:00+00:00',
#                          'actual_runway': '2021-04-19T11:51:00+00:00',
#                          'airport': 'Valdosta Regional Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-19T11:40:00+00:00',
#                          'estimated_runway': '2021-04-19T11:51:00+00:00',
#                          'gate': None,
#                          'iata': 'VLD',
#                          'icao': 'KVLD',
#                          'scheduled': '2021-04-19T11:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4650',
#                                      'flight_icao': 'dal4650',
#                                      'flight_number': '4650'},
#                       'iata': 'KL7207',
#                       'icao': 'KLM7207',
#                       'number': '7207'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:40:00+00:00',
#                        'actual_runway': '2021-04-19T12:40:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:59:00+00:00',
#                        'estimated_runway': '2021-04-19T12:40:00+00:00',
#                        'gate': 'D39',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:59:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:51:00+00:00',
#                          'actual_runway': '2021-04-19T11:51:00+00:00',
#                          'airport': 'Valdosta Regional Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-19T11:40:00+00:00',
#                          'estimated_runway': '2021-04-19T11:51:00+00:00',
#                          'gate': None,
#                          'iata': 'VLD',
#                          'icao': 'KVLD',
#                          'scheduled': '2021-04-19T11:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4650',
#                                      'flight_icao': 'dal4650',
#                                      'flight_number': '4650'},
#                       'iata': 'VS2330',
#                       'icao': 'VIR2330',
#                       'number': '2330'},
#            'flight_date': '2021-04-19',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 2992}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-18'
    
}

api_0418 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0418.json()

#pprint(api_response)
# Out:
# {'data': [{'aircraft': {'iata': 'B737',
#                         'icao': 'B737',
#                         'icao24': 'A1EA70',
#                         'registration': 'N222WN'},
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-18T18:04:00+00:00',
#                        'actual_runway': '2021-04-18T18:04:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-18T18:20:00+00:00',
#                        'estimated_runway': '2021-04-18T18:04:00+00:00',
#                        'gate': 'C4',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:20:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:33:00+00:00',
#                          'actual_runway': '2021-04-18T16:33:00+00:00',
#                          'airport': 'Ronald Reagan Washington National Airport',
#                          'delay': 9,
#                          'estimated': '2021-04-18T16:25:00+00:00',
#                          'estimated_runway': '2021-04-18T16:33:00+00:00',
#                          'gate': '8',
#                          'iata': 'DCA',
#                          'icao': 'KDCA',
#                          'scheduled': '2021-04-18T16:25:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN143',
#                       'icao': 'SWA143',
#                       'number': '143'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-18T18:26:00+00:00',
#                        'actual_runway': '2021-04-18T18:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T18:34:00+00:00',
#                        'estimated_runway': '2021-04-18T18:26:00+00:00',
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:45:00+00:00',
#                          'actual_runway': '2021-04-18T16:45:00+00:00',
#                          'airport': 'Ronald Reagan Washington National Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-18T16:38:00+00:00',
#                          'estimated_runway': '2021-04-18T16:45:00+00:00',
#                          'gate': '15',
#                          'iata': 'DCA',
#                          'icao': 'KDCA',
#                          'scheduled': '2021-04-18T16:38:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl464',
#                                      'flight_icao': 'dal464',
#                                      'flight_number': '464'},
#                       'iata': 'AF3064',
#                       'icao': 'AFR3064',
#                       'number': '3064'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-18T18:26:00+00:00',
#                        'actual_runway': '2021-04-18T18:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T18:34:00+00:00',
#                        'estimated_runway': '2021-04-18T18:26:00+00:00',
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:45:00+00:00',
#                          'actual_runway': '2021-04-18T16:45:00+00:00',
#                          'airport': 'Ronald Reagan Washington National Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-18T16:38:00+00:00',
#                          'estimated_runway': '2021-04-18T16:45:00+00:00',
#                          'gate': '15',
#                          'iata': 'DCA',
#                          'icao': 'KDCA',
#                          'scheduled': '2021-04-18T16:38:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl464',
#                                      'flight_icao': 'dal464',
#                                      'flight_number': '464'},
#                       'iata': 'KL5451',
#                       'icao': 'KLM5451',
#                       'number': '5451'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-18T18:26:00+00:00',
#                        'actual_runway': '2021-04-18T18:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T18:34:00+00:00',
#                        'estimated_runway': '2021-04-18T18:26:00+00:00',
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:45:00+00:00',
#                          'actual_runway': '2021-04-18T16:45:00+00:00',
#                          'airport': 'Ronald Reagan Washington National Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-18T16:38:00+00:00',
#                          'estimated_runway': '2021-04-18T16:45:00+00:00',
#                          'gate': '15',
#                          'iata': 'DCA',
#                          'icao': 'KDCA',
#                          'scheduled': '2021-04-18T16:38:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl464',
#                                      'flight_icao': 'dal464',
#                                      'flight_number': '464'},
#                       'iata': 'VS2579',
#                       'icao': 'VIR2579',
#                       'number': '2579'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T18:26:00+00:00',
#                        'actual_runway': '2021-04-18T18:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T18:34:00+00:00',
#                        'estimated_runway': '2021-04-18T18:26:00+00:00',
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:45:00+00:00',
#                          'actual_runway': '2021-04-18T16:45:00+00:00',
#                          'airport': 'Ronald Reagan Washington National Airport',
#                          'delay': 7,
#                          'estimated': '2021-04-18T16:38:00+00:00',
#                          'estimated_runway': '2021-04-18T16:45:00+00:00',
#                          'gate': '15',
#                          'iata': 'DCA',
#                          'icao': 'KDCA',
#                          'scheduled': '2021-04-18T16:38:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL464',
#                       'icao': 'DAL464',
#                       'number': '464'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T05:06:00+00:00',
#                        'actual_runway': '2021-04-18T05:06:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-18T05:36:00+00:00',
#                        'estimated_runway': '2021-04-18T05:06:00+00:00',
#                        'gate': 'T2',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T05:36:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T00:53:00+00:00',
#                          'actual_runway': '2021-04-18T00:53:00+00:00',
#                          'airport': 'Denver International',
#                          'delay': 3,
#                          'estimated': '2021-04-18T00:50:00+00:00',
#                          'estimated_runway': '2021-04-18T00:53:00+00:00',
#                          'gate': 'A37',
#                          'iata': 'DEN',
#                          'icao': 'KDEN',
#                          'scheduled': '2021-04-18T00:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Denver'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2525',
#                                      'flight_icao': 'dal2525',
#                                      'flight_number': '2525'},
#                       'iata': 'AM3283',
#                       'icao': 'AMX3283',
#                       'number': '3283'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T08:13:00+00:00',
#                        'actual_runway': '2021-04-18T08:13:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T08:57:00+00:00',
#                        'estimated_runway': '2021-04-18T08:13:00+00:00',
#                        'gate': 'D8',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T08:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:31:00+00:00',
#                          'actual_runway': '2021-04-18T05:31:00+00:00',
#                          'airport': 'Austin-straubel Field',
#                          'delay': 2,
#                          'estimated': '2021-04-18T05:30:00+00:00',
#                          'estimated_runway': '2021-04-18T05:31:00+00:00',
#                          'gate': 'B5',
#                          'iata': 'GRB',
#                          'icao': 'KGRB',
#                          'scheduled': '2021-04-18T05:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4683',
#                                      'flight_icao': 'dal4683',
#                                      'flight_number': '4683'},
#                       'iata': 'AM3341',
#                       'icao': 'AMX3341',
#                       'number': '3341'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-18T08:13:00+00:00',
#                        'actual_runway': '2021-04-18T08:13:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T08:57:00+00:00',
#                        'estimated_runway': '2021-04-18T08:13:00+00:00',
#                        'gate': 'D8',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T08:57:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:31:00+00:00',
#                          'actual_runway': '2021-04-18T05:31:00+00:00',
#                          'airport': 'Austin-straubel Field',
#                          'delay': 2,
#                          'estimated': '2021-04-18T05:30:00+00:00',
#                          'estimated_runway': '2021-04-18T05:31:00+00:00',
#                          'gate': 'B5',
#                          'iata': 'GRB',
#                          'icao': 'KGRB',
#                          'scheduled': '2021-04-18T05:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4683',
#                                      'flight_icao': 'dal4683',
#                                      'flight_number': '4683'},
#                       'iata': 'KL5959',
#                       'icao': 'KLM5959',
#                       'number': '5959'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-18T16:03:00+00:00',
#                        'actual_runway': '2021-04-18T16:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-18T16:26:00+00:00',
#                        'estimated_runway': '2021-04-18T16:03:00+00:00',
#                        'gate': 'E11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T16:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:09:00+00:00',
#                          'actual_runway': '2021-04-18T13:09:00+00:00',
#                          'airport': 'Minneapolis - St. Paul International',
#                          'delay': 14,
#                          'estimated': '2021-04-18T12:55:00+00:00',
#                          'estimated_runway': '2021-04-18T13:09:00+00:00',
#                          'gate': 'F12',
#                          'iata': 'MSP',
#                          'icao': 'KMSP',
#                          'scheduled': '2021-04-18T12:55:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1081',
#                                      'flight_icao': 'dal1081',
#                                      'flight_number': '1081'},
#                       'iata': 'KL7149',
#                       'icao': 'KLM7149',
#                       'number': '7149'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-18T16:03:00+00:00',
#                        'actual_runway': '2021-04-18T16:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-18T16:26:00+00:00',
#                        'estimated_runway': '2021-04-18T16:03:00+00:00',
#                        'gate': 'E11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T16:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:09:00+00:00',
#                          'actual_runway': '2021-04-18T13:09:00+00:00',
#                          'airport': 'Minneapolis - St. Paul International',
#                          'delay': 14,
#                          'estimated': '2021-04-18T12:55:00+00:00',
#                          'estimated_runway': '2021-04-18T13:09:00+00:00',
#                          'gate': 'F12',
#                          'iata': 'MSP',
#                          'icao': 'KMSP',
#                          'scheduled': '2021-04-18T12:55:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1081',
#                                      'flight_icao': 'dal1081',
#                                      'flight_number': '1081'},
#                       'iata': 'VS2638',
#                       'icao': 'VIR2638',
#                       'number': '2638'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T16:03:00+00:00',
#                        'actual_runway': '2021-04-18T16:03:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-18T16:26:00+00:00',
#                        'estimated_runway': '2021-04-18T16:03:00+00:00',
#                        'gate': 'E11',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T16:26:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:09:00+00:00',
#                          'actual_runway': '2021-04-18T13:09:00+00:00',
#                          'airport': 'Minneapolis - St. Paul International',
#                          'delay': 14,
#                          'estimated': '2021-04-18T12:55:00+00:00',
#                          'estimated_runway': '2021-04-18T13:09:00+00:00',
#                          'gate': 'F12',
#                          'iata': 'MSP',
#                          'icao': 'KMSP',
#                          'scheduled': '2021-04-18T12:55:00+00:00',
#                          'terminal': '1',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1081',
#                       'icao': 'DAL1081',
#                       'number': '1081'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl575',
#                                      'flight_icao': 'dal575',
#                                      'flight_number': '575'},
#                       'iata': 'AF2609',
#                       'icao': 'AFR2609',
#                       'number': '2609'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl575',
#                                      'flight_icao': 'dal575',
#                                      'flight_number': '575'},
#                       'iata': 'AM3000',
#                       'icao': 'AMX3000',
#                       'number': '3000'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl575',
#                                      'flight_icao': 'dal575',
#                                      'flight_number': '575'},
#                       'iata': 'KL5675',
#                       'icao': 'KLM5675',
#                       'number': '5675'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl575',
#                                      'flight_icao': 'dal575',
#                                      'flight_number': '575'},
#                       'iata': 'VS2285',
#                       'icao': 'VIR2285',
#                       'number': '2285'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl575',
#                                      'flight_icao': 'dal575',
#                                      'flight_number': '575'},
#                       'iata': 'WS6301',
#                       'icao': 'WJA6301',
#                       'number': '6301'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'ACD83D',
#                         'registration': 'N927AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T15:26:00+00:00',
#                        'actual_runway': '2021-04-18T15:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-18T15:52:00+00:00',
#                        'estimated_runway': '2021-04-18T15:26:00+00:00',
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T15:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T13:11:00+00:00',
#                          'actual_runway': '2021-04-18T13:11:00+00:00',
#                          'airport': 'Albany International',
#                          'delay': 10,
#                          'estimated': '2021-04-18T13:13:00+00:00',
#                          'estimated_runway': '2021-04-18T13:11:00+00:00',
#                          'gate': 'B7',
#                          'iata': 'ALB',
#                          'icao': 'KALB',
#                          'scheduled': '2021-04-18T13:13:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL575',
#                       'icao': 'DAL575',
#                       'number': '575'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-18T18:00:00+00:00',
#                        'actual_runway': '2021-04-18T18:00:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': 6,
#                        'estimated': '2021-04-18T18:05:00+00:00',
#                        'estimated_runway': '2021-04-18T18:00:00+00:00',
#                        'gate': 'C12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:05:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:45:00+00:00',
#                          'actual_runway': '2021-04-18T16:45:00+00:00',
#                          'airport': 'Southwest Florida International',
#                          'delay': 26,
#                          'estimated': '2021-04-18T16:20:00+00:00',
#                          'estimated_runway': '2021-04-18T16:45:00+00:00',
#                          'gate': 'B8',
#                          'iata': 'RSW',
#                          'icao': 'KRSW',
#                          'scheduled': '2021-04-18T16:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN1521',
#                       'icao': 'SWA1521',
#                       'number': '1521'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B77W',
#                         'icao': 'B77W',
#                         'icao24': '8990DF',
#                         'registration': 'B-16717'},
#            'airline': {'iata': 'BR', 'icao': 'EVA', 'name': 'EVA Air'},
#            'arrival': {'actual': '2021-04-18T11:46:00+00:00',
#                        'actual_runway': '2021-04-18T11:46:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': 4,
#                        'estimated': '2021-04-18T11:46:00+00:00',
#                        'estimated_runway': '2021-04-18T11:46:00+00:00',
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T11:46:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T09:38:00+00:00',
#                          'actual_runway': '2021-04-18T09:38:00+00:00',
#                          'airport': 'Taiwan Taoyuan International (Chiang Kai '
#                                     'Shek International)',
#                          'delay': 88,
#                          'estimated': '2021-04-18T08:10:00+00:00',
#                          'estimated_runway': '2021-04-18T09:38:00+00:00',
#                          'gate': None,
#                          'iata': 'TPE',
#                          'icao': 'RCTP',
#                          'scheduled': '2021-04-18T08:10:00+00:00',
#                          'terminal': None,
#                          'timezone': 'Asia/Taipei'},
#            'flight': {'codeshared': None,
#                       'iata': 'BR650',
#                       'icao': 'EVA650',
#                       'number': '650'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:47:00+00:00',
#                          'actual_runway': '2021-04-18T05:47:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 8,
#                          'estimated': '2021-04-18T05:40:00+00:00',
#                          'estimated_runway': '2021-04-18T05:47:00+00:00',
#                          'gate': '13',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-18T05:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2044',
#                                      'flight_icao': 'dal2044',
#                                      'flight_number': '2044'},
#                       'iata': 'AM3613',
#                       'icao': 'AMX3613',
#                       'number': '3613'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:47:00+00:00',
#                          'actual_runway': '2021-04-18T05:47:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 8,
#                          'estimated': '2021-04-18T05:40:00+00:00',
#                          'estimated_runway': '2021-04-18T05:47:00+00:00',
#                          'gate': '13',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-18T05:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl2044',
#                                      'flight_icao': 'dal2044',
#                                      'flight_number': '2044'},
#                       'iata': 'KE3727',
#                       'icao': 'KAL3727',
#                       'number': '3727'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B712',
#                         'icao': 'B712',
#                         'icao24': 'AD6B14',
#                         'registration': 'N964AT'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'B12',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:47:00+00:00',
#                          'actual_runway': '2021-04-18T05:47:00+00:00',
#                          'airport': 'Savannah/Hilton Head',
#                          'delay': 8,
#                          'estimated': '2021-04-18T05:40:00+00:00',
#                          'estimated_runway': '2021-04-18T05:47:00+00:00',
#                          'gate': '13',
#                          'iata': 'SAV',
#                          'icao': 'KSAV',
#                          'scheduled': '2021-04-18T05:40:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2044',
#                       'icao': 'DAL2044',
#                       'number': '2044'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-18T17:56:00+00:00',
#                        'actual_runway': '2021-04-18T17:56:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-18T18:10:00+00:00',
#                        'estimated_runway': '2021-04-18T17:56:00+00:00',
#                        'gate': 'C9',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T18:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T16:31:00+00:00',
#                          'actual_runway': '2021-04-18T16:31:00+00:00',
#                          'airport': 'Richmond International Airport',
#                          'delay': 12,
#                          'estimated': '2021-04-18T16:20:00+00:00',
#                          'estimated_runway': '2021-04-18T16:31:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'RIC',
#                          'icao': 'KRIC',
#                          'scheduled': '2021-04-18T16:20:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN154',
#                       'icao': 'SWA154',
#                       'number': '154'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-18T14:06:00+00:00',
#                        'actual_runway': '2021-04-18T14:06:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': 6,
#                        'estimated': '2021-04-18T14:00:00+00:00',
#                        'estimated_runway': '2021-04-18T14:06:00+00:00',
#                        'gate': 'C9',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T14:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T12:44:00+00:00',
#                          'actual_runway': '2021-04-18T12:44:00+00:00',
#                          'airport': 'International',
#                          'delay': 34,
#                          'estimated': '2021-04-18T12:10:00+00:00',
#                          'estimated_runway': '2021-04-18T12:44:00+00:00',
#                          'gate': 'B3',
#                          'iata': 'PBI',
#                          'icao': 'KPBI',
#                          'scheduled': '2021-04-18T12:10:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'WN952',
#                       'icao': 'SWA952',
#                       'number': '952'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': {'iata': 'B38M',
#                         'icao': 'B38M',
#                         'icao24': 'ABFD8C',
#                         'registration': 'N8718Q'},
#            'airline': {'iata': 'WN',
#                        'icao': 'SWA',
#                        'name': 'Southwest Airlines'},
#            'arrival': {'actual': '2021-04-18T11:41:00+00:00',
# ...
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T06:26:00+00:00',
#                        'actual_runway': '2021-04-18T06:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:38:00+00:00',
#                        'estimated_runway': '2021-04-18T06:26:00+00:00',
#                        'gate': 'A04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:38:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:40:00+00:00',
#                          'actual_runway': '2021-04-18T05:40:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 11,
#                          'estimated': '2021-04-18T05:30:00+00:00',
#                          'estimated_runway': '2021-04-18T05:40:00+00:00',
#                          'gate': 'A7',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-18T05:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1133',
#                                      'flight_icao': 'dal1133',
#                                      'flight_number': '1133'},
#                       'iata': 'AM5354',
#                       'icao': 'AMX5354',
#                       'number': '5354'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-18T06:26:00+00:00',
#                        'actual_runway': '2021-04-18T06:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:38:00+00:00',
#                        'estimated_runway': '2021-04-18T06:26:00+00:00',
#                        'gate': 'A04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:38:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:40:00+00:00',
#                          'actual_runway': '2021-04-18T05:40:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 11,
#                          'estimated': '2021-04-18T05:30:00+00:00',
#                          'estimated_runway': '2021-04-18T05:40:00+00:00',
#                          'gate': 'A7',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-18T05:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1133',
#                                      'flight_icao': 'dal1133',
#                                      'flight_number': '1133'},
#                       'iata': 'WS7339',
#                       'icao': 'WJA7339',
#                       'number': '7339'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T06:26:00+00:00',
#                        'actual_runway': '2021-04-18T06:26:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:38:00+00:00',
#                        'estimated_runway': '2021-04-18T06:26:00+00:00',
#                        'gate': 'A04',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:38:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T05:40:00+00:00',
#                          'actual_runway': '2021-04-18T05:40:00+00:00',
#                          'airport': 'Jacksonville,',
#                          'delay': 11,
#                          'estimated': '2021-04-18T05:30:00+00:00',
#                          'estimated_runway': '2021-04-18T05:40:00+00:00',
#                          'gate': 'A7',
#                          'iata': 'JAX',
#                          'icao': 'KJAX',
#                          'scheduled': '2021-04-18T05:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1133',
#                       'icao': 'DAL1133',
#                       'number': '1133'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T06:05:00+00:00',
#                          'actual_runway': '2021-04-18T06:05:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 15,
#                          'estimated': '2021-04-18T05:50:00+00:00',
#                          'estimated_runway': '2021-04-18T06:05:00+00:00',
#                          'gate': '05',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-18T05:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4879',
#                                      'flight_icao': 'dal4879',
#                                      'flight_number': '4879'},
#                       'iata': 'AM3434',
#                       'icao': 'AMX3434',
#                       'number': '3434'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'D44',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T06:05:00+00:00',
#                          'actual_runway': '2021-04-18T06:05:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 2,
#                          'estimated': '2021-04-18T05:50:00+00:00',
#                          'estimated_runway': '2021-04-18T06:05:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-18T05:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5364',
#                                      'flight_icao': 'dal5364',
#                                      'flight_number': '5364'},
#                       'iata': 'KE7064',
#                       'icao': 'KAL7064',
#                       'number': '7064'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': '2021-04-18T08:44:00+00:00',
#                        'actual_runway': '2021-04-18T08:44:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T09:00:00+00:00',
#                        'estimated_runway': '2021-04-18T08:44:00+00:00',
#                        'gate': 'D44',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T09:00:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T08:17:00+00:00',
#                          'actual_runway': '2021-04-18T08:17:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 22,
#                          'estimated': '2021-04-18T07:55:00+00:00',
#                          'estimated_runway': '2021-04-18T08:17:00+00:00',
#                          'gate': '03',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-18T07:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5364',
#                                      'flight_icao': 'dal5364',
#                                      'flight_number': '5364'},
#                       'iata': 'KE3792',
#                       'icao': 'KAL3792',
#                       'number': '3792'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-18T06:31:00+00:00',
#                        'actual_runway': '2021-04-18T06:31:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T06:47:00+00:00',
#                        'estimated_runway': '2021-04-18T06:31:00+00:00',
#                        'gate': 'D38',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T06:47:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T06:05:00+00:00',
#                          'actual_runway': '2021-04-18T06:05:00+00:00',
#                          'airport': 'Lovell Field',
#                          'delay': 15,
#                          'estimated': '2021-04-18T05:50:00+00:00',
#                          'estimated_runway': '2021-04-18T06:05:00+00:00',
#                          'gate': '05',
#                          'iata': 'CHA',
#                          'icao': 'KCHA',
#                          'scheduled': '2021-04-18T05:50:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL4879',
#                       'icao': 'DAL4879',
#                       'number': '4879'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-18T07:32:00+00:00',
#                        'actual_runway': '2021-04-18T07:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-18T07:45:00+00:00',
#                        'estimated_runway': '2021-04-18T07:32:00+00:00',
#                        'gate': 'D31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-18T07:45:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-18T06:14:00+00:00',
#                          'actual_runway': '2021-04-18T06:14:00+00:00',
#                          'airport': 'Albemarle',
#                          'delay': 10,
#                          'estimated': '2021-04-18T06:05:00+00:00',
#                          'estimated_runway': '2021-04-18T06:14:00+00:00',
#                          'gate': None,
#                          'iata': 'CHO',
#                          'icao': 'KCHO',
#                          'scheduled': '2021-04-18T06:05:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl4945',
#                                      'flight_icao': 'dal4945',
#                                      'flight_number': '4945'},
#                       'iata': 'AM4645',
#                       'icao': 'AMX4645',
#                       'number': '4645'},
#            'flight_date': '2021-04-18',
#            'flight_status': 'landed',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 3151}}

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-17'
    
}

api_0417 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0417.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-16'
    
}

api_0416 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0416.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-15'
    
}

api_0415 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0415.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-14'
    
}

api_0414 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0414.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-13'
    
}

api_0413 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0413.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-12'
    
}

api_0412 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0412.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-11'
    
}

api_0411 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0411.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-10'
    
}

api_0410 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0410.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-09'
    
}

api_0409 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0409.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-08'
    
}

api_0408 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0408.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-07'
    
}

api_0407 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0407.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-06'
    
}

api_0406 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0406.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-05'
    
}

api_0405 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0405.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-04'
    
}

api_0404 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0404.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-03'
    
}

api_0403 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0403.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-02'
    
}

api_0402 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0402.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-04-01'
    
}

api_0401 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0401.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-31'
    
}

api_0331 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0331.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-30'
    
}

api_0330 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0330.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-29'
    
}

api_0329 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0329.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-28'
    
}

api_0328 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0328.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-27'
    
}

api_0327 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0327.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-26'
    
}

api_0326 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0326.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-25'
    
}

api_0325 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0325.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-24'
    
}

api_0324 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0324.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-23'
    
}

api_0323 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0323.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-22'
    
}

api_0322 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0322.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-21'
    
}

api_0321 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0321.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-20'
    
}

api_0320 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0320.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-19'
    
}

api_0319 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0319.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-18'
    
}

api_0318 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0318.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-17'
    
}

api_0317 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0317.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-16'
    
}

api_0316 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0316.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-15'
    
}

api_0315 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0315.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-14'
    
}

api_0314 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0314.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-13'
    
}

api_0313 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0313.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-12'
    
}

api_0312 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0312.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-11'
    
}

api_0311 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0311.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-10'
    
}

api_0310 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0310.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-09'
    
}

api_0309 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0309.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-08'
    
}

api_0308 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0308.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-07'
    
}

api_0307 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0307.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-06'
    
}

api_0306 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0306.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-05'
    
}

api_0305 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0305.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-04'
    
}

api_0304 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0304.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-03'
    
}

api_0303 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0303.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-02'
    
}

api_0302 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0302.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-03-01'
    
}

api_0301 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0301.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-28'
    
}

api_0228 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-27'
    
}

api_0227 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0227.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-26'
    
}

api_0226 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0226.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-25'
    
}

api_0225 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0225.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-24'
    
}

api_0224 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0224.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-23'
    
}

api_0223 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0223.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-22'
    
}

api_0222 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_022.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-21'
    
}

api_0221 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0221.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-20'
    
}

api_0220 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0220.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-19'
    
}

api_0219 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0219.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-18'
    
}

api_0218 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0218.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-17'
    
}

api_0217 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0217.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-16'
    
}

api_0216 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0216.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-15'
    
}

api_0215 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0215.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-14'
    
}

api_0214 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0214.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-13'
    
}

api_0213 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0213.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0211.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-10'
    
}

api_0210 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0210.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-09'
    
}

api_0209 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0209.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-08'
    
}

api_0208 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0208.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-07'
    
}

api_0207 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0207.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-06'
    
}

api_0206 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0206.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-05'
    
}

api_0205 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0205.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-04'
    
}

api_0204 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0204.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-03'
    
}

api_0203 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0203.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-02'
    
}

api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
params = {
  'access_key': '6289ca69e9e258ac06e0faa6602570be',
   'arr_iata': 'ATL',
    'flight_date': '2021-02-01'
    
}

api_0201 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0201.json()


pd.DataFrame.from_dict(api_response, orient='index').T.set_index('index')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4ef8e370ee87> in <module>
#      11
#      12
# ---> 13 pd.DataFrame.from_dict(api_response, orient='index').T.set_index('index')
#
# C:\Users\melin\Anaconda3\lib\site-packages\pandas\core\frame.py in from_dict(cls, data, orient, dtype, columns)
#    1298                 # TODO speed up Series case
#    1299                 if isinstance(list(data.values())[0], (Series, dict)):
# -> 1300                     data = _from_nested_dict(data)
#    1301                 else:
#    1302                     data, index = list(data.values()), list(data.keys())
#
# C:\Users\melin\Anaconda3\lib\site-packages\pandas\core\frame.py in _from_nested_dict(data)
#    9275     new_data = collections.defaultdict(dict)
#    9276     for index, s in data.items():
# -> 9277         for col, v in s.items():
#    9278             new_data[col][index] = v
#    9279     return new_data
#
# AttributeError: 'list' object has no attribute 'items'

# %%
pd.DataFrame.from_dict(data, orient='index').T.set_index('index')
