# %%
import requests
import json
import pandas as pd
from config import api_key
from pprint import pprint

# %%
########################4.24.2021###################################100
params = {
    'access_key': api_key,
    'arr_iata': 'LAX',
    'flight_date': '2021-04-24'
}

api_0424_lax = requests.get('https://api.aviationstack.com/v1/flights', params)

api_responselax = api_0424_lax.json()

pprint(api_responselax)
# Out:
# {'data': [{'aircraft': {'iata': 'B738',
#                         'icao': 'B738',
#                         'icao24': 'A69424',
#                         'registration': 'N523AS'},
#            'airline': {'iata': 'AS', 'icao': 'ASA', 'name': 'Alaska Airlines'},
#            'arrival': {'actual': '2021-04-24T15:42:00+00:00',
#                        'actual_runway': '2021-04-24T15:42:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-24T15:53:00+00:00',
#                        'estimated_runway': '2021-04-24T15:42:00+00:00',
#                        'gate': '67',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-24T15:53:00+00:00',
#                        'terminal': '6',
#                        'timezone': 'America/Los_Angeles'},
# ...

# %%
# Grab needed rows from airline
flightslax = []

for row in api_responselax['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data2 = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data_lax_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data2.items() ]))
flights_data_lax_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
########################4.23.2021###################################200
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-23',    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'AS', 'icao': 'ASA', 'name': 'Alaska Airlines'},
#            'arrival': {'actual': '2021-04-23T08:41:00+00:00',
#                        'actual_runway': '2021-04-23T08:41:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': 'T5C5',
#                        'delay': None,
#                        'estimated': '2021-04-23T09:07:00+00:00',
#                        'estimated_runway': '2021-04-23T08:41:00+00:00',
#                        'gate': '54A',
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-23T09:07:00+00:00',
#                        'terminal': '5',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-23T06:41:00+00:00',
#                          'actual_runway': '2021-04-23T06:41:00+00:00',
# ...

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data2_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data2_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([flights_data_df, flights_data2_df])
joined_df_merge.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
########################4.22.2021###################################300
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-22'
    
}

api_0422 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0422.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'AA',
#                        'icao': 'AAL',
#                        'name': 'American Airlines'},
#            'arrival': {'actual': '2021-04-21T22:01:00+00:00',
#                        'actual_runway': '2021-04-21T22:01:00+00:00',
#                        'airport': 'Los Angeles International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-21T22:15:00+00:00',
#                        'estimated_runway': '2021-04-21T22:01:00+00:00',
#                        'gate': None,
#                        'iata': 'LAX',
#                        'icao': 'KLAX',
#                        'scheduled': '2021-04-21T22:15:00+00:00',
#                        'terminal': 'B',
#                        'timezone': 'America/Los_Angeles'},
#            'departure': {'actual': '2021-04-22T00:21:00+00:00',
# ...

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data3_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data3_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data3_df])
joined_df_merge.head(300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 295           KL          KLM  Hartsfield-jackson Atlanta International
# 296           AM          AMX  Hartsfield-jackson Atlanta International
# 297           WS          WJA  Hartsfield-jackson Atlanta International
# 298           AS          ASA  Hartsfield-jackson Atlanta International
# 299           VS          VIR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.21.2021###################################400
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-21'
    
}

api_0421 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0421.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': {'iata': 'CRJ9',
#                         'icao': 'CRJ9',
#                         'icao24': 'A3A9B6',
#                         'registration': 'N335PQ'},
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-21T14:01:00+00:00',
#                        'actual_runway': '2021-04-21T14:01:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '8',
#                        'delay': None,
#                        'estimated': '2021-04-21T14:15:00+00:00',
#                        'estimated_runway': '2021-04-21T14:01:00+00:00',
#                        'gate': 'E32',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-21T14:15:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
# ...

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data4_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data4_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data4_df])
joined_df_merge.head(400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 395          ATL         KATL                                       NaN
# 396          ATL         KATL                                       NaN
# 397          ATL         KATL                                       NaN
# 398          ATL         KATL                                       NaN
# 399          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.20.2021###################################500
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-20'
    
}

api_0420 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0420.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-20T15:14:00+00:00',
#                        'actual_runway': '2021-04-20T15:14:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-20T15:40:00+00:00',
#                        'estimated_runway': '2021-04-20T15:14:00+00:00',
#                        'gate': 'B31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-20T15:40:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-20T13:52:00+00:00',
#                          'actual_runway': '2021-04-20T13:52:00+00:00',
# ...

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data5_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data5_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data5_df])
joined_df_merge.head(500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 495          ATL         KATL                                       NaN
# 496          ATL         KATL                                       NaN
# 497          ATL         KATL                                       NaN
# 498          ATL         KATL                                       NaN
# 499          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.19.2021###################################600
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-19'
    
}

api_0419 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0419.json()

#pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-19T12:34:00+00:00',
#                        'actual_runway': '2021-04-19T12:34:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '3',
#                        'delay': None,
#                        'estimated': '2021-04-19T12:56:00+00:00',
#                        'estimated_runway': '2021-04-19T12:34:00+00:00',
#                        'gate': 'T08',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-19T12:56:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-19T11:17:00+00:00',
#                          'actual_runway': '2021-04-19T11:17:00+00:00',
# ...

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data6_df])
joined_df_merge.head(600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 595           DL          DAL                                       NaN
# 596           DL          DAL                                       NaN
# 597           WS          WJA                                       NaN
# 598           VS          VIR                                       NaN
# 599           KL          KLM                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.18.2021###################################700
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-18'
    
}

api_0418 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0418.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data7_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data7_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data7_df])
joined_df_merge.head(700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 695           KL          KLM                                       NaN
# 696          ATL         KATL                                       NaN
# 697           AF          AFR                                       NaN
# 698          ATL         KATL                                       NaN
# 699           DL          DAL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.17.2021###################################800
params = {
    'access_key': api_key,
    'arr_iata': 'LAX',
    'flight_date': '2021-04-17'
    
}

api_0417 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0417.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data8_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data8_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data8_df])
joined_df_merge.head(800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 795           WS          WJA                                       NaN
# 796          ATL         KATL                                       NaN
# 797           KL          KLM                                       NaN
# 798          ATL         KATL                                       NaN
# 799           VS          VIR                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.16.2021###################################900
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-16'
    
}

api_0416 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0416.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data9_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data9_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data9_df])
joined_df_merge.head(900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 895           KL          KLM                                       NaN
# 896          ATL         KATL                                       NaN
# 897           AF          AFR                                       NaN
# 898          ATL         KATL                                       NaN
# 899           DL          DAL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.15.2021###################################1000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
'flight_date': '2021-04-15'
    
}

api_0415 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0415.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data10_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data10_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data10_df])
joined_df_merge.head(1000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 995           WS          WJA                                       NaN
# 996          ATL         KATL                                       NaN
# 997           KL          KLM                                       NaN
# 998          ATL         KATL                                       NaN
# 999           VS          VIR                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.14.2021###################################1100
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-14'
    
}

api_0414 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0414.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data11_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data11_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data11_df])
joined_df_merge.head(1100)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1095           AM          AMX                                       NaN
# 1096           DL          DAL                                       NaN
# 1097           KE          KAL                                       NaN
# 1098           AM          AMX                                       NaN
# 1099           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.13.2021###################################1200
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-13'
    
}

api_0413 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0413.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data12_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data12_df])
joined_df_merge.head(1200)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 84           AF          AFR  Hartsfield-jackson Atlanta International
# 85           WS          WJA  Hartsfield-jackson Atlanta International
# 86           KL          KLM  Hartsfield-jackson Atlanta International
# 87           VS          VIR  Hartsfield-jackson Atlanta International
# 88           DL          DAL  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                              dep_airport  \
# ...

# %%
########################4.12.2021###################################1300
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-12'
    
}

api_0412 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0412.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data13_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data13_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data13_df])
joined_df_merge.head(1300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 184           DL          DAL  Hartsfield-jackson Atlanta International
# 185           AF          AFR  Hartsfield-jackson Atlanta International
# 186           WS          WJA  Hartsfield-jackson Atlanta International
# 187           KL          KLM  Hartsfield-jackson Atlanta International
# 188           VS          VIR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# ...

# %%
########################4.11.2021###################################1400
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-11'
    
}

api_0411 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0411.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data14_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data14_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data14_df])
joined_df_merge.head(1400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 284           KE          KAL  Hartsfield-jackson Atlanta International
# 285           AM          AMX  Hartsfield-jackson Atlanta International
# 286           DL          DAL  Hartsfield-jackson Atlanta International
# 287           AF          AFR  Hartsfield-jackson Atlanta International
# 288           WS          WJA  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# ...

# %%
########################4.10.2021###################################1500
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-10'
    
}

api_0410 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0410.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data15_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data15_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data15_df])
joined_df_merge.head(1500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 384          ATL         KATL  Hartsfield-jackson Atlanta International
# 385          ATL         KATL  Hartsfield-jackson Atlanta International
# 386          ATL         KATL  Hartsfield-jackson Atlanta International
# 387          ATL         KATL  Hartsfield-jackson Atlanta International
# 388          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                              dep_airport  \
# ...

# %%
########################4.09.2021###################################1600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-09'
    
}

api_0409 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0409.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data16_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data16_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data16_df])
joined_df_merge.head(1600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 484          ATL         KATL  Hartsfield-jackson Atlanta International
# 485          ATL         KATL  Hartsfield-jackson Atlanta International
# 486          ATL         KATL  Hartsfield-jackson Atlanta International
# 487          ATL         KATL  Hartsfield-jackson Atlanta International
# 488          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.08.2021###################################1700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-08'
    
}

api_0408 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0408.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data17_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data17_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data17_df])
joined_df_merge.head(1700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 584           DL          DAL  Hartsfield-jackson Atlanta International
# 585           KE          KAL  Hartsfield-jackson Atlanta International
# 586           AM          AMX  Hartsfield-jackson Atlanta International
# 587           DL          DAL  Hartsfield-jackson Atlanta International
# 588           KE          KAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.07.2021###################################1800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-07'
    
}

api_0407 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0407.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data18_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data18_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data18_df])
joined_df_merge.head(1800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 684          ATL         KATL  Hartsfield-jackson Atlanta International
# 685           AF          AFR  Hartsfield-jackson Atlanta International
# 686          ATL         KATL  Hartsfield-jackson Atlanta International
# 687           AM          AMX  Hartsfield-jackson Atlanta International
# 688          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# ...

# %%
########################4.06.2021###################################1900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-06'
    
}

api_0406 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0406.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data19_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data19_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data19_df])
joined_df_merge.head(1900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 784          ATL         KATL                                       NaN
# 785           DL          DAL                                       NaN
# 786          ATL         KATL                                       NaN
# 787           KE          KAL                                       NaN
# 788          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.05.2021###################################2000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-05'
    
}

api_0405 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0405.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data20_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data20_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data20_df])
joined_df_merge.head(2000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 884          ATL         KATL                                       NaN
# 885           AF          AFR                                       NaN
# 886          ATL         KATL                                       NaN
# 887           AM          AMX                                       NaN
# 888          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.04.2021###################################2100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-04'
    
}

api_0404 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0404.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data21_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data21_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data21_df])
joined_df_merge.head(2100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 984          ATL         KATL                                       NaN
# 985           DL          DAL                                       NaN
# 986          ATL         KATL                                       NaN
# 987           KE          KAL                                       NaN
# 988          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.03.2021###################################2200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-03'
    
}

api_0403 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0403.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data22_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data22_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data22_df])
joined_df_merge.head(2200)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1084           KL          KLM                                       NaN
# 1085           KE          KAL                                       NaN
# 1086           AZ          AZA                                       NaN
# 1087           AF          AFR                                       NaN
# 1088           BR          EVA                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.02.2021###################################2300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-02'
    
}

api_0402 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0402.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data23_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data23_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data23_df])
joined_df_merge.head(2300)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1184           LA          LAN                                       NaN
# 1185           KL          KLM                                       NaN
# 1186           KE          KAL                                       NaN
# 1187           AZ          AZA                                       NaN
# 1188           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################4.01.2021###################################2400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-04-01'
    
}

api_0401 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0401.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data24_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data24_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(2400)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1284           DL          DAL                                       NaN
# 1285           PK          PIA                                       NaN
# 1286           SQ          SIA                                       NaN
# 1287           TK          THY                                       NaN
# 1288           AM          AMX                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.31.2021###################################2500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-31'
    
}

api_0331 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0331.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data25_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data25_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data25_df])
joined_df_merge.head(2500)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1384           DL          DAL                                       NaN
# 1385           AM          AMX                                       NaN
# 1386           KE          KAL                                       NaN
# 1387           DL          DAL                                       NaN
# 1388           PK          PIA                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.30.2021###################################2600
params = {
   'access_key': api_key,  
   'arr_iata': 'LAX',
    'flight_date': '2021-03-30'
    
}

api_0330 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0330.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data26_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data26_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data26_df])
joined_df_merge.head(2600)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1484           AF          AFR                                       NaN
# 1485           DL          DAL                                       NaN
# 1486           AZ          AZA                                       NaN
# 1487           VS          VIR                                       NaN
# 1488           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.29.2021###################################2700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-29'
    
}

api_0329 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0329.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data27_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data27_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data27_df])
joined_df_merge.head(2700)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 69           BR          EVA  Hartsfield-jackson Atlanta International
# 70           G3          GLO  Hartsfield-jackson Atlanta International
# 71           AM          AMX  Hartsfield-jackson Atlanta International
# 72           KL          KLM  Hartsfield-jackson Atlanta International
# 73           AM          AMX  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                      dep_airport  \
# ...

# %%
########################03.28.2021###################################2800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-28'
    
}

api_0328 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0328.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data28_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data28_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data28_df])
joined_df_merge.head(2800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 169           AF          AFR  Hartsfield-jackson Atlanta International
# 170           BR          EVA  Hartsfield-jackson Atlanta International
# 171           G3          GLO  Hartsfield-jackson Atlanta International
# 172           AM          AMX  Hartsfield-jackson Atlanta International
# 173           KL          KLM  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# ...

# %%
########################03.27.2021###################################2900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-27'
    
}

api_0327 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0327.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data29_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data29_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data29_df])
joined_df_merge.head(2900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 269           KL          KLM  Hartsfield-jackson Atlanta International
# 270           VS          VIR  Hartsfield-jackson Atlanta International
# 271           AF          AFR  Hartsfield-jackson Atlanta International
# 272           BR          EVA  Hartsfield-jackson Atlanta International
# 273           G3          GLO  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# ...

# %%
########################03.26.2021###################################3000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-26'
    
}

api_0326 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0326.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data30_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data30_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data30_df])
joined_df_merge.head(3000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 369          ATL         KATL  Hartsfield-jackson Atlanta International
# 370          ATL         KATL  Hartsfield-jackson Atlanta International
# 371          ATL         KATL  Hartsfield-jackson Atlanta International
# 372          ATL         KATL  Hartsfield-jackson Atlanta International
# 373          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                      dep_airport  \
# ...

# %%
########################03.25.2021###################################3100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-25'
    
}

api_0325 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0325.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data31_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data31_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data31_df])
joined_df_merge.head(3100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 469          ATL         KATL  Hartsfield-jackson Atlanta International
# 470          ATL         KATL  Hartsfield-jackson Atlanta International
# 471          ATL         KATL  Hartsfield-jackson Atlanta International
# 472          ATL         KATL  Hartsfield-jackson Atlanta International
# 473          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# ...

# %%
########################03.24.2021###################################3200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-24'
    
}

api_0324 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0324.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data32_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data32_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data32_df])
joined_df_merge.head(3200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 569           WS          WJA  Hartsfield-jackson Atlanta International
# 570           DL          DAL  Hartsfield-jackson Atlanta International
# 571           AF          AFR  Hartsfield-jackson Atlanta International
# 572           AM          AMX  Hartsfield-jackson Atlanta International
# 573           KL          KLM  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# ...

# %%
########################03.23.2021###################################3300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-23'
    
}

api_0323 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0323.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data33_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data33_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data33_df])
joined_df_merge.head(3300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 669           VS          VIR  Hartsfield-jackson Atlanta International
# 670          ATL         KATL  Hartsfield-jackson Atlanta International
# 671           KL          KLM  Hartsfield-jackson Atlanta International
# 672          ATL         KATL  Hartsfield-jackson Atlanta International
# 673           AM          AMX  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# ...

# %%
########################03.22.2021###################################3400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-22'
    
}

api_0322 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0322.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data34_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data34_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data34_df])
joined_df_merge.head(3400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 769           KL          KLM  Hartsfield-jackson Atlanta International
# 770          ATL         KATL  Hartsfield-jackson Atlanta International
# 771           AM          AMX  Hartsfield-jackson Atlanta International
# 772          ATL         KATL  Hartsfield-jackson Atlanta International
# 773           NK          NKS  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# ...

# %%
########################03.21.2021###################################3500
params = {
   'access_key': api_key, 
   'arr_iata': 'LAX',
    'flight_date': '2021-03-21'
    
}

api_0321 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0321.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data35_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data35_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(3500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 869           VS          VIR                                       NaN
# 870          ATL         KATL                                       NaN
# 871           KL          KLM                                       NaN
# 872          ATL         KATL                                       NaN
# 873           AM          AMX                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.20.2021###################################3600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-20'
    
}

api_0320 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0320.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data36_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data36_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data36_df])
joined_df_merge.head(3600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 969           KL          KLM                                       NaN
# 970          ATL         KATL                                       NaN
# 971           AM          AMX                                       NaN
# 972          ATL         KATL                                       NaN
# 973           NK          NKS                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.19.2021###################################3700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-19'
    
}

api_0319 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0319.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data37_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data37_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data37_df])
joined_df_merge.head(3700)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1069           KL          KLM                                       NaN
# 1070           AM          AMX                                       NaN
# 1071           DL          DAL                                       NaN
# 1072           AF          AFR                                       NaN
# 1073           AM          AMX                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.18.2021###################################3800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-18'
    
}

api_0318 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0318.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data38_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data38_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data38_df])
joined_df_merge.head(3800)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1169           VS          VIR                                       NaN
# 1170           KL          KLM                                       NaN
# 1171           AM          AMX                                       NaN
# 1172           DL          DAL                                       NaN
# 1173           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.17.2021###################################3900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-17'
    
}

api_0317 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0317.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data39_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data39_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data39_df])
joined_df_merge.head(3900)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1269           VS          VIR                                       NaN
# 1270           DL          DAL                                       NaN
# 1271           AM          AMX                                       NaN
# 1272           KE          KAL                                       NaN
# 1273           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.16.2021###################################4000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-16'
    
}

api_0316 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0316.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data40_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data40_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data40_df])
joined_df_merge.head(4000)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1369           AM          AMX                                       NaN
# 1370           KE          KAL                                       NaN
# 1371           KL          KLM                                       NaN
# 1372           VS          VIR                                       NaN
# 1373           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.15.2021###################################4100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-15'
    
}

api_0315 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0315.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data41_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data41_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data41_df])
joined_df_merge.head(4100)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1469           WN          SWA                                       NaN
# 1470           DL          DAL                                       NaN
# 1471           VS          VIR                                       NaN
# 1472           KL          KLM                                       NaN
# 1473           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.14.2021###################################4200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-14'
    
}

api_0314 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0314.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data42_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data42_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data42_df])
joined_df_merge.head(4200)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1569           WN          SWA                                       NaN
# 1570           DL          DAL                                       NaN
# 1571           VS          VIR                                       NaN
# 1572           KL          KLM                                       NaN
# 1573           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.13.2021###################################4300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-13'
    
}

api_0313 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0313.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data43_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data43_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data43_df])
joined_df_merge.head(4300)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 54           KL          KLM  Hartsfield-jackson Atlanta International
# 55           AM          AMX  Hartsfield-jackson Atlanta International
# 56           DL          DAL  Hartsfield-jackson Atlanta International
# 57           AF          AFR  Hartsfield-jackson Atlanta International
# 58           AM          AMX  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# ...

# %%
########################03.12.2021###################################4400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-12'
    
}

api_0312 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0312.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data44_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data44_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data44_df])
joined_df_merge.head(4400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 154           VS          VIR  Hartsfield-jackson Atlanta International
# 155           KL          KLM  Hartsfield-jackson Atlanta International
# 156           AM          AMX  Hartsfield-jackson Atlanta International
# 157           DL          DAL  Hartsfield-jackson Atlanta International
# 158           AF          AFR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.11.2021###################################4500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-11'
    
}

api_0311 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0311.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data45_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data45_df])
joined_df_merge.head(4500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 254           WS          WJA  Hartsfield-jackson Atlanta International
# 255           WS          WJA  Hartsfield-jackson Atlanta International
# 256           VS          VIR  Hartsfield-jackson Atlanta International
# 257           KL          KLM  Hartsfield-jackson Atlanta International
# 258           AM          AMX  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.10.2021###################################4600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-10'
    
}

api_0310 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0310.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data46_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data46_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data46_df])
joined_df_merge.head(4600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 354          ATL         KATL  Hartsfield-jackson Atlanta International
# 355          ATL         KATL  Hartsfield-jackson Atlanta International
# 356          ATL         KATL  Hartsfield-jackson Atlanta International
# 357          ATL         KATL  Hartsfield-jackson Atlanta International
# 358          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.09.2021###################################4700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-09'
    
}

api_0309 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0309.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data47_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data47_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data47_df])
joined_df_merge.head(4700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 454          ATL         KATL  Hartsfield-jackson Atlanta International
# 455          ATL         KATL  Hartsfield-jackson Atlanta International
# 456          ATL         KATL  Hartsfield-jackson Atlanta International
# 457          ATL         KATL  Hartsfield-jackson Atlanta International
# 458          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.08.2021###################################4800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-08'
    
}

api_0308 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0308.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data48_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data48_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data48_df])
joined_df_merge.head(4800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 554           KL          KLM  Hartsfield-jackson Atlanta International
# 555           AF          AFR  Hartsfield-jackson Atlanta International
# 556           DL          DAL  Hartsfield-jackson Atlanta International
# 557           DL          DAL  Hartsfield-jackson Atlanta International
# 558           WS          WJA  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.07.2021###################################4900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-07'
    
}

api_0307 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0307.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data49_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data49_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data49_df])
joined_df_merge.head(4900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 654          ATL         KATL  Hartsfield-jackson Atlanta International
# 655           AF          AFR  Hartsfield-jackson Atlanta International
# 656          ATL         KATL  Hartsfield-jackson Atlanta International
# 657           KL          KLM  Hartsfield-jackson Atlanta International
# 658          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                           dep_airport  \
# ...

# %%
########################03.06.2021###################################5000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-06'
    
}

api_0306 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0306.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data50_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data50_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data50_df])
joined_df_merge.head(5000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 754          ATL         KATL  Hartsfield-jackson Atlanta International
# 755           KL          KLM  Hartsfield-jackson Atlanta International
# 756          ATL         KATL  Hartsfield-jackson Atlanta International
# 757           KE          KAL  Hartsfield-jackson Atlanta International
# 758          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                           dep_airport  \
# ...

# %%
########################03.05.2021###################################5100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-05'
    
}

api_0305 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0305.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data51_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data51_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data51_df])
joined_df_merge.head(5100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 854          ATL         KATL                                       NaN
# 855           AF          AFR                                       NaN
# 856          ATL         KATL                                       NaN
# 857           KL          KLM                                       NaN
# 858          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.04.2021###################################5200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-04'
    
}

api_0304 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0304.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data52_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data52_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data52_df])
joined_df_merge.head(5200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 954          ATL         KATL                                       NaN
# 955           KL          KLM                                       NaN
# 956          ATL         KATL                                       NaN
# 957           KE          KAL                                       NaN
# 958          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.03.2021###################################5300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-03'
    
}

api_0303 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0303.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data53_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data53_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data53_df])
joined_df_merge.head(5300)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1054           KL          KLM                                       NaN
# 1055           AF          AFR                                       NaN
# 1056           DL          DAL                                       NaN
# 1057           KL          KLM                                       NaN
# 1058           AF          AFR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.02.2021###################################5400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-02'
    
}

api_0302 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0302.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data54_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data54_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data54_df])
joined_df_merge.head(5400)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1154           DL          DAL                                       NaN
# 1155           KL          KLM                                       NaN
# 1156           AF          AFR                                       NaN
# 1157           DL          DAL                                       NaN
# 1158           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################03.01.2021###################################5500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-03-01'
    
}

api_0301 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0301.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data55_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data55_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data55_df])
joined_df_merge.head(5500)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1254           WN          SWA                                       NaN
# 1255           KE          KAL                                       NaN
# 1256           DL          DAL                                       NaN
# 1257           AM          AMX                                       NaN
# 1258           KE          KAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.28.2021###################################5600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-28'
    
}

api_0228 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data56_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data26_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data55_df])
joined_df_merge.head(5600)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1354           AM          AMX                                       NaN
# 1355           KE          KAL                                       NaN
# 1356           DL          DAL                                       NaN
# 1357           WN          SWA                                       NaN
# 1358           KE          KAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.27.2021###################################5700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-27'
    
}

api_0227 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0227.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data57_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data57_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data57_df])
joined_df_merge.head(5700)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1454           AF          AFR                                       NaN
# 1455           AF          AFR                                       NaN
# 1456           AM          AMX                                       NaN
# 1457           KL          KLM                                       NaN
# 1458           VS          VIR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.26.2021###################################5800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-26'
    
}

api_0226 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0226.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data58_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data58_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data58_df])
joined_df_merge.head(5800)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1554           AF          AFR                                       NaN
# 1555           AF          AFR                                       NaN
# 1556           AM          AMX                                       NaN
# 1557           KL          KLM                                       NaN
# 1558           VS          VIR                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.25.2021###################################5900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-25'
    
}

api_0225 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0225.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data59_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data59_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data59_df])
joined_df_merge.head(5900)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 39           KL          KLM  Hartsfield-jackson Atlanta International
# 40           AF          AFR  Hartsfield-jackson Atlanta International
# 41           DL          DAL  Hartsfield-jackson Atlanta International
# 42           KL          KLM  Hartsfield-jackson Atlanta International
# 43           AF          AFR  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# ...

# %%
########################02.24.2021###################################6000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-24'
    
}

api_0224 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0224.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data60_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data60_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data60_df])
joined_df_merge.head(6000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 139           DL          DAL  Hartsfield-jackson Atlanta International
# 140           KL          KLM  Hartsfield-jackson Atlanta International
# 141           AF          AFR  Hartsfield-jackson Atlanta International
# 142           DL          DAL  Hartsfield-jackson Atlanta International
# 143           KL          KLM  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.23.2021###################################6100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-23'
    
}

api_0223 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0223.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data61_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data61_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data61_df])
joined_df_merge.head(6100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 239           DL          DAL  Hartsfield-jackson Atlanta International
# 240           AF          AFR  Hartsfield-jackson Atlanta International
# 241           DL          DAL  Hartsfield-jackson Atlanta International
# 242           KL          KLM  Hartsfield-jackson Atlanta International
# 243           AF          AFR  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.22.2021###################################6200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-22'
    
}

api_0222 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0222.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data62_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data62_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data62_df])
joined_df_merge.head(6200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 339          ATL         KATL  Hartsfield-jackson Atlanta International
# 340          ATL         KATL  Hartsfield-jackson Atlanta International
# 341          ATL         KATL  Hartsfield-jackson Atlanta International
# 342          ATL         KATL  Hartsfield-jackson Atlanta International
# 343          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.21.2021###################################6300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-21'
    
}

api_0221 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0221.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data63_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data63_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data63_df])
joined_df_merge.head(6300)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 439          ATL         KATL  Hartsfield-jackson Atlanta International
# 440          ATL         KATL  Hartsfield-jackson Atlanta International
# 441          ATL         KATL  Hartsfield-jackson Atlanta International
# 442          ATL         KATL  Hartsfield-jackson Atlanta International
# 443          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# ...

# %%
########################02.20.2021###################################6400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-20'
    
}

api_0220 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0220.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data64_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data64_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data64_df])
joined_df_merge.head(6400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 539           QR          QTR  Hartsfield-jackson Atlanta International
# 540           AF          AFR  Hartsfield-jackson Atlanta International
# 541           DL          DAL  Hartsfield-jackson Atlanta International
# 542           VS          VIR  Hartsfield-jackson Atlanta International
# 543           DL          DAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate  \
# 0          35            I     None
# ...

# %%
########################02.19.2021###################################6500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-19'
    
}

api_0219 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0219.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data65_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data65_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data65_df])
joined_df_merge.head(6500)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 639           AF          AFR  Hartsfield-jackson Atlanta International
# 640          ATL         KATL  Hartsfield-jackson Atlanta International
# 641           DL          DAL  Hartsfield-jackson Atlanta International
# 642          ATL         KATL  Hartsfield-jackson Atlanta International
# 643           WN          SWA  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# ...

# %%
########################02.18.2021###################################6600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-18'
    
}

api_0218 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0218.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data66_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data66_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data66_df])
joined_df_merge.head(6600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 739           WS          WJA  Hartsfield-jackson Atlanta International
# 740          ATL         KATL  Hartsfield-jackson Atlanta International
# 741           WS          WJA  Hartsfield-jackson Atlanta International
# 742          ATL         KATL  Hartsfield-jackson Atlanta International
# 743           DL          DAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                     dep_airport  \
# ...

# %%
########################02.17.2021###################################6700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-17'
    
}

api_0217 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0217.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data67_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data67_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data67_df])
joined_df_merge.head(6700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 839           AF          AFR                                       NaN
# 840          ATL         KATL                                       NaN
# 841           DL          DAL                                       NaN
# 842          ATL         KATL                                       NaN
# 843           WN          SWA                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.16.2021###################################6800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-16'
    
}

api_0216 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0216.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data68_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data68_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data68_df])
joined_df_merge.head(6800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 939           WS          WJA                                       NaN
# 940          ATL         KATL                                       NaN
# 941           WS          WJA                                       NaN
# 942          ATL         KATL                                       NaN
# 943           DL          DAL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.15.2021###################################7000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-15'
    
}

api_0215 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0215.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data70_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data70_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data70_df])
joined_df_merge.head(7000)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1139           DL          DAL                                       NaN
# 1140           DL          DAL                                       NaN
# 1141           WS          WJA                                       NaN
# 1142           VS          VIR                                       NaN
# 1143           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.14.2021###################################7100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-14'
    
}

api_0214 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0214.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data71_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data71_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data71_df])
joined_df_merge.head(7100)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1239           VS          VIR                                       NaN
# 1240           KL          KLM                                       NaN
# 1241           DL          DAL                                       NaN
# 1242           WN          SWA                                       NaN
# 1243           AM          AMX                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.13.2021###################################7200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-13'
    
}

api_0213 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0213.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data72_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data72_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data72_df])
joined_df_merge.head(7200)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1339           DL          DAL                                       NaN
# 1340           AM          AMX                                       NaN
# 1341           KE          KAL                                       NaN
# 1342           VS          VIR                                       NaN
# 1343           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.12.2021###################################7300
params = {
  'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data73_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data73_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data73_df])
joined_df_merge.head(7300)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1439           WS          WJA                                       NaN
# 1440           KL          KLM                                       NaN
# 1441           DL          DAL                                       NaN
# 1442           AM          AMX                                       NaN
# 1443           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.11.2021###################################7400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data74_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data74_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data74_df])
joined_df_merge.head(7400)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1539           WS          WJA                                       NaN
# 1540           KL          KLM                                       NaN
# 1541           DL          DAL                                       NaN
# 1542           AM          AMX                                       NaN
# 1543           KL          KLM                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.12.2021###################################7500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data75_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data75_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data75_df])
joined_df_merge.head(7500)
# Out:
#    airline_iata airline_icao                               arr_airport  \
# 0            KL          KLM  Hartsfield-jackson Atlanta International
# 1            KL          KLM  Hartsfield-jackson Atlanta International
# 2            WS          WJA  Hartsfield-jackson Atlanta International
# 3            VS          VIR  Hartsfield-jackson Atlanta International
# 4            KL          KLM  Hartsfield-jackson Atlanta International
# ..          ...          ...                                       ...
# 24           VS          VIR  Hartsfield-jackson Atlanta International
# 25           DL          DAL  Hartsfield-jackson Atlanta International
# 26           DL          DAL  Hartsfield-jackson Atlanta International
# 27           DL          DAL  Hartsfield-jackson Atlanta International
# 28           WS          WJA  Hartsfield-jackson Atlanta International
#
#    flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# ...

# %%
########################02.11.2021###################################7600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0211.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data76_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data76_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data76_df])
joined_df_merge.head(7600)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 124           KL          KLM  Hartsfield-jackson Atlanta International
# 125           VS          VIR  Hartsfield-jackson Atlanta International
# 126           DL          DAL  Hartsfield-jackson Atlanta International
# 127           DL          DAL  Hartsfield-jackson Atlanta International
# 128           DL          DAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.10.2021###################################7700
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-10'
    
}

api_0210 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0210.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data77_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data77_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data77_df])
joined_df_merge.head(7700)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 224           KE          KAL  Hartsfield-jackson Atlanta International
# 225           AF          AFR  Hartsfield-jackson Atlanta International
# 226           KL          KLM  Hartsfield-jackson Atlanta International
# 227           VS          VIR  Hartsfield-jackson Atlanta International
# 228           DL          DAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.09.2021###################################7800
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-09'
    
}

api_0209 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0209.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data78_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data78_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data78_df])
joined_df_merge.head(7800)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 324          ATL         KATL  Hartsfield-jackson Atlanta International
# 325          ATL         KATL  Hartsfield-jackson Atlanta International
# 326          ATL         KATL  Hartsfield-jackson Atlanta International
# 327          ATL         KATL  Hartsfield-jackson Atlanta International
# 328          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.08.2021###################################7900
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-08'
    
}

api_0208 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0208.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data79_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data79_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data79_df])
joined_df_merge.head(7900)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 424          ATL         KATL  Hartsfield-jackson Atlanta International
# 425          ATL         KATL  Hartsfield-jackson Atlanta International
# 426          ATL         KATL  Hartsfield-jackson Atlanta International
# 427          ATL         KATL  Hartsfield-jackson Atlanta International
# 428          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.07.2021###################################8000
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-07'
    
}

api_0207 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0207.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data80_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data80_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data80_df])
joined_df_merge.head(8000)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 524           DL          DAL  Hartsfield-jackson Atlanta International
# 525           AM          AMX  Hartsfield-jackson Atlanta International
# 526           KL          KLM  Hartsfield-jackson Atlanta International
# 527           AM          AMX  Hartsfield-jackson Atlanta International
# 528           KE          KAL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.06.2021###################################8100
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-06'
    
}

api_0206 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0206.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data81_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data81_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data81_df])
joined_df_merge.head(8100)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 624          ATL         KATL  Hartsfield-jackson Atlanta International
# 625           NZ          ANZ  Hartsfield-jackson Atlanta International
# 626          ATL         KATL  Hartsfield-jackson Atlanta International
# 627           VS          VIR  Hartsfield-jackson Atlanta International
# 628          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.05.2021###################################8200
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-05'
    
}

api_0205 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0205.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data82_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data82_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data82_df])
joined_df_merge.head(8200)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 724          ATL         KATL  Hartsfield-jackson Atlanta International
# 725           KL          KLM  Hartsfield-jackson Atlanta International
# 726          ATL         KATL  Hartsfield-jackson Atlanta International
# 727           AM          AMX  Hartsfield-jackson Atlanta International
# 728          ATL         KATL  Hartsfield-jackson Atlanta International
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.04.2021###################################8300
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-04'
    
}

api_0204 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0204.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data83_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data83_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data83df])
joined_df_merge.head(8300)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-458-8d9768327eb6> in <module>
# ----> 1 joined_df_merge = pd.concat([joined_df_merge, flights_data83df])
#       2 joined_df_merge.head(8300)
#
# NameError: name 'flights_data83df' is not defined

# %%
########################02.03.2021###################################8400
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-03'
    
}

api_0203 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0203.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data84_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data84_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data84_df])
joined_df_merge.head(8400)
# Out:
#     airline_iata airline_icao                               arr_airport  \
# 0             KL          KLM  Hartsfield-jackson Atlanta International
# 1             KL          KLM  Hartsfield-jackson Atlanta International
# 2             WS          WJA  Hartsfield-jackson Atlanta International
# 3             VS          VIR  Hartsfield-jackson Atlanta International
# 4             KL          KLM  Hartsfield-jackson Atlanta International
# ..           ...          ...                                       ...
# 924          ATL         KATL                                       NaN
# 925           KL          KLM                                       NaN
# 926          ATL         KATL                                       NaN
# 927           AM          AMX                                       NaN
# 928          ATL         KATL                                       NaN
#
#     flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.02.2021###################################8500
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-02'
    
}

api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data85_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data85_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data85_df])
joined_df_merge.head(8500)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1024           WS          WJA                                       NaN
# 1025           DL          DAL                                       NaN
# 1026           AF          AFR                                       NaN
# 1027           DL          DAL                                       NaN
# 1028           WN          SWA                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...

# %%
########################02.01.2021###################################8600
params = {
   'access_key': api_key,
   'arr_iata': 'LAX',
    'flight_date': '2021-02-01'
    
}


api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data86_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data86_df.head()
# Out:
#   airline_iata airline_icao                               arr_airport  \
# 0           KL          KLM  Hartsfield-jackson Atlanta International
# 1           KL          KLM  Hartsfield-jackson Atlanta International
# 2           WS          WJA  Hartsfield-jackson Atlanta International
# 3           VS          VIR  Hartsfield-jackson Atlanta International
# 4           KL          KLM  Hartsfield-jackson Atlanta International
#
#   flight_no arr_terminal arr_gate                   dep_airport dep_terminal  \
# 0        35            I     None               Seoul (Incheon)            2
# 1      7851            I     None               Seoul (Incheon)            2
# 2      5090            I     None               Seoul (Incheon)            2
# 3      6786            S      B21  George Bush Intercontinental            A
# 4      5130            S      A12  George Bush Intercontinental            A
#
#   dep_gate
# 0      231
# 1      231
# 2      231
# 3       14
# 4       15

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data86_df])
joined_df_merge.head(8600)
# Out:
#      airline_iata airline_icao                               arr_airport  \
# 0              KL          KLM  Hartsfield-jackson Atlanta International
# 1              KL          KLM  Hartsfield-jackson Atlanta International
# 2              WS          WJA  Hartsfield-jackson Atlanta International
# 3              VS          VIR  Hartsfield-jackson Atlanta International
# 4              KL          KLM  Hartsfield-jackson Atlanta International
# ...           ...          ...                                       ...
# 1124           DL          DAL                                       NaN
# 1125           WS          WJA                                       NaN
# 1126           DL          DAL                                       NaN
# 1127           AF          AFR                                       NaN
# 1128           DL          DAL                                       NaN
#
#      flight_no arr_terminal arr_gate                   dep_airport  \
# ...
