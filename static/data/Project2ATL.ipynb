# %%
import requests
import json
import pandas as pd
from config import api_key
from pprint import pprint

# %%
########################4.24.2021###################################100
params = {
  'access_key': api_key,
   'arr_iata': 'ATL'
}

api_0424 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0424.json()

pprint(api_response)
# Out:
# {'data': [{'aircraft': None,
#            'airline': {'iata': 'KE', 'icao': 'KAL', 'name': 'Korean Air'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-27T10:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-27T10:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 53,
#                          'estimated': '2021-04-27T09:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '256',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-27T09:20:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': None,
#                       'iata': 'KE35',
#                       'icao': 'KAL35',
#                       'number': '35'},
#            'flight_date': '2021-04-27',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-27T10:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-27T10:10:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Seoul (Incheon)',
#                          'delay': 53,
#                          'estimated': '2021-04-27T09:20:00+00:00',
#                          'estimated_runway': None,
#                          'gate': '256',
#                          'iata': 'ICN',
#                          'icao': 'RKSI',
#                          'scheduled': '2021-04-27T09:20:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Asia/Seoul'},
#            'flight': {'codeshared': {'airline_iata': 'ke',
#                                      'airline_icao': 'kal',
#                                      'airline_name': 'korean air',
#                                      'flight_iata': 'ke35',
#                                      'flight_icao': 'kal35',
#                                      'flight_number': '35'},
#                       'iata': 'DL7851',
#                       'icao': 'DAL7851',
#                       'number': '7851'},
#            'flight_date': '2021-04-27',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T20:11:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A7',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T20:11:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T17:53:00+00:00',
#                          'actual_runway': '2021-04-26T17:53:00+00:00',
#                          'airport': 'Newark Liberty International',
#                          'delay': 6,
#                          'estimated': '2021-04-26T17:48:00+00:00',
#                          'estimated_runway': '2021-04-26T17:53:00+00:00',
#                          'gate': '45',
#                          'iata': 'EWR',
#                          'icao': 'KEWR',
#                          'scheduled': '2021-04-26T17:48:00+00:00',
#                          'terminal': 'B',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL2066',
#                       'icao': 'DAL2066',
#                       'number': '2066'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T20:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T20:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 12,
#                          'estimated': '2021-04-26T18:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D4',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-26T18:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1387',
#                       'icao': 'DAL1387',
#                       'number': '1387'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T20:10:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A17',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T20:10:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': 'Fort Lauderdale–Hollywood International',
#                          'delay': 12,
#                          'estimated': '2021-04-26T18:15:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'D4',
#                          'iata': 'FLL',
#                          'icao': 'KFLL',
#                          'scheduled': '2021-04-26T18:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1387',
#                                      'flight_icao': 'dal1387',
#                                      'flight_number': '1387'},
#                       'iata': 'AF2651',
#                       'icao': 'AFR2651',
#                       'number': '2651'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-26T16:53:00+00:00',
#                        'actual_runway': '2021-04-26T16:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': 'F3',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:07:00+00:00',
#                        'estimated_runway': '2021-04-26T16:53:00+00:00',
#                        'gate': 'F05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:07:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:58:00+00:00',
#                          'actual_runway': '2021-04-26T13:58:00+00:00',
#                          'airport': 'Schiphol',
#                          'delay': 43,
#                          'estimated': '2021-04-26T13:15:00+00:00',
#                          'estimated_runway': '2021-04-26T13:58:00+00:00',
#                          'gate': 'D10',
#                          'iata': 'AMS',
#                          'icao': 'EHAM',
#                          'scheduled': '2021-04-26T13:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Europe/Amsterdam'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl75',
#                                      'flight_icao': 'dal75',
#                                      'flight_number': '75'},
#                       'iata': 'VS3960',
#                       'icao': 'VIR3960',
#                       'number': '3960'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-26T16:53:00+00:00',
#                        'actual_runway': '2021-04-26T16:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': 'F3',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:07:00+00:00',
#                        'estimated_runway': '2021-04-26T16:53:00+00:00',
#                        'gate': 'F05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:07:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:58:00+00:00',
#                          'actual_runway': '2021-04-26T13:58:00+00:00',
#                          'airport': 'Schiphol',
#                          'delay': 43,
#                          'estimated': '2021-04-26T13:15:00+00:00',
#                          'estimated_runway': '2021-04-26T13:58:00+00:00',
#                          'gate': 'D10',
#                          'iata': 'AMS',
#                          'icao': 'EHAM',
#                          'scheduled': '2021-04-26T13:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Europe/Amsterdam'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl75',
#                                      'flight_icao': 'dal75',
#                                      'flight_number': '75'},
#                       'iata': 'KL6013',
#                       'icao': 'KLM6013',
#                       'number': '6013'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-26T16:53:00+00:00',
#                        'actual_runway': '2021-04-26T16:53:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': 'F3',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:07:00+00:00',
#                        'estimated_runway': '2021-04-26T16:53:00+00:00',
#                        'gate': 'F05',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:07:00+00:00',
#                        'terminal': 'I',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:58:00+00:00',
#                          'actual_runway': '2021-04-26T13:58:00+00:00',
#                          'airport': 'Schiphol',
#                          'delay': 43,
#                          'estimated': '2021-04-26T13:15:00+00:00',
#                          'estimated_runway': '2021-04-26T13:58:00+00:00',
#                          'gate': 'D10',
#                          'iata': 'AMS',
#                          'icao': 'EHAM',
#                          'scheduled': '2021-04-26T13:15:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'Europe/Amsterdam'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl75',
#                                      'flight_icao': 'dal75',
#                                      'flight_number': '75'},
#                       'iata': 'AF3667',
#                       'icao': 'AFR3667',
#                       'number': '3667'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-26T11:25:00+00:00',
#                        'actual_runway': '2021-04-26T11:25:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-26T11:55:00+00:00',
#                        'estimated_runway': '2021-04-26T11:25:00+00:00',
#                        'gate': 'A31',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T11:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T09:16:00+00:00',
#                          'actual_runway': '2021-04-26T09:16:00+00:00',
#                          'airport': 'Logan International',
#                          'delay': 16,
#                          'estimated': '2021-04-26T09:00:00+00:00',
#                          'estimated_runway': '2021-04-26T09:16:00+00:00',
#                          'gate': 'A7',
#                          'iata': 'BOS',
#                          'icao': 'KBOS',
#                          'scheduled': '2021-04-26T09:00:00+00:00',
#                          'terminal': 'A',
#                          'timezone': 'America/New_York'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1527',
#                                      'flight_icao': 'dal1527',
#                                      'flight_number': '1527'},
#                       'iata': 'AM4948',
#                       'icao': 'AMX4948',
#                       'number': '4948'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AS', 'icao': 'ASA', 'name': 'Alaska Airlines'},
#            'arrival': {'actual': '2021-04-26T16:08:00+00:00',
#                        'actual_runway': '2021-04-26T16:08:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T16:49:00+00:00',
#                        'estimated_runway': '2021-04-26T16:08:00+00:00',
#                        'gate': 'T10',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T16:49:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T10:10:00+00:00',
#                          'actual_runway': '2021-04-26T10:10:00+00:00',
#                          'airport': 'Sky Harbor International',
#                          'delay': 14,
#                          'estimated': '2021-04-26T09:56:00+00:00',
#                          'estimated_runway': '2021-04-26T10:10:00+00:00',
#                          'gate': 'B27',
#                          'iata': 'PHX',
#                          'icao': 'KPHX',
#                          'scheduled': '2021-04-26T09:56:00+00:00',
#                          'terminal': '4',
#                          'timezone': 'America/Phoenix'},
#            'flight': {'codeshared': {'airline_iata': 'aa',
#                                      'airline_icao': 'aal',
#                                      'airline_name': 'american airlines',
#                                      'flight_iata': 'aa462',
#                                      'flight_icao': 'aal462',
#                                      'flight_number': '462'},
#                       'iata': 'AS6208',
#                       'icao': 'ASA6208',
#                       'number': '6208'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T17:04:00+00:00',
#                          'actual_runway': '2021-04-26T17:04:00+00:00',
#                          'airport': 'Detroit Metropolitan Wayne County',
#                          'delay': 10,
#                          'estimated': '2021-04-26T16:55:00+00:00',
#                          'estimated_runway': '2021-04-26T17:04:00+00:00',
#                          'gate': 'A56',
#                          'iata': 'DTW',
#                          'icao': 'KDTW',
#                          'scheduled': '2021-04-26T16:55:00+00:00',
#                          'terminal': 'EM',
#                          'timezone': 'America/Detroit'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL1148',
#                       'icao': 'DAL1148',
#                       'number': '1148'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T17:04:00+00:00',
#                          'actual_runway': '2021-04-26T17:04:00+00:00',
#                          'airport': 'Detroit Metropolitan Wayne County',
#                          'delay': 10,
#                          'estimated': '2021-04-26T16:55:00+00:00',
#                          'estimated_runway': '2021-04-26T17:04:00+00:00',
#                          'gate': 'A56',
#                          'iata': 'DTW',
#                          'icao': 'KDTW',
#                          'scheduled': '2021-04-26T16:55:00+00:00',
#                          'terminal': 'EM',
#                          'timezone': 'America/Detroit'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1148',
#                                      'flight_icao': 'dal1148',
#                                      'flight_number': '1148'},
#                       'iata': 'KL6969',
#                       'icao': 'KLM6969',
#                       'number': '6969'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T17:04:00+00:00',
#                          'actual_runway': '2021-04-26T17:04:00+00:00',
#                          'airport': 'Detroit Metropolitan Wayne County',
#                          'delay': 10,
#                          'estimated': '2021-04-26T16:55:00+00:00',
#                          'estimated_runway': '2021-04-26T17:04:00+00:00',
#                          'gate': 'A56',
#                          'iata': 'DTW',
#                          'icao': 'KDTW',
#                          'scheduled': '2021-04-26T16:55:00+00:00',
#                          'terminal': 'EM',
#                          'timezone': 'America/Detroit'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1148',
#                                      'flight_icao': 'dal1148',
#                                      'flight_number': '1148'},
#                       'iata': 'AF2327',
#                       'icao': 'AFR2327',
#                       'number': '2327'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': {'iata': 'B744',
#                         'icao': 'B744',
#                         'icao24': '71BE16',
#                         'registration': 'HL7616'},
#            'airline': {'iata': 'OZ', 'icao': 'AAR', 'name': 'Asiana Airlines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': None,
#                        'estimated': '2021-04-26T04:25:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T04:25:00+00:00',
#                        'terminal': 'C',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': None,
#                          'estimated': '2021-04-26T01:25:00+00:00',
#                          'estimated_runway': None,
#                          'gate': None,
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T01:25:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'OZ248',
#                       'icao': 'AAR248',
#                       'number': '248'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': {'altitude': 335.28,
#                     'direction': 90,
#                     'is_ground': False,
#                     'latitude': 33.63,
#                     'longitude': -84.75,
#                     'speed_horizontal': 268.524,
#                     'speed_vertical': -15.228,
#                     'updated': '2021-04-26T16:55:56+00:00'}},
#           {'aircraft': None,
#            'airline': {'iata': 'CV', 'icao': 'CLX', 'name': 'Cargolux'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': None,
#                        'delay': 158,
#                        'estimated': '2021-04-26T06:30:00+00:00',
#                        'estimated_runway': None,
#                        'gate': None,
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T06:30:00+00:00',
#                        'terminal': 'N',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T03:32:00+00:00',
#                          'actual_runway': '2021-04-26T03:32:00+00:00',
#                          'airport': 'Luis Munoz Marin International',
#                          'delay': 112,
#                          'estimated': '2021-04-26T01:30:00+00:00',
#                          'estimated_runway': '2021-04-26T03:32:00+00:00',
#                          'gate': None,
#                          'iata': 'SJU',
#                          'icao': 'TJSJ',
#                          'scheduled': '2021-04-26T01:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Puerto_Rico'},
#            'flight': {'codeshared': None,
#                       'iata': 'CV8391',
#                       'icao': 'CLX8391',
#                       'number': '8391'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL5248',
#                       'icao': 'DAL5248',
#                       'number': '5248'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5248',
#                                      'flight_icao': 'dal5248',
#                                      'flight_number': '5248'},
#                       'iata': 'WS6937',
#                       'icao': 'WJA6937',
#                       'number': '6937'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5248',
#                                      'flight_icao': 'dal5248',
#                                      'flight_number': '5248'},
#                       'iata': 'VS2927',
#                       'icao': 'VIR2927',
#                       'number': '2927'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5248',
#                                      'flight_icao': 'dal5248',
#                                      'flight_number': '5248'},
#                       'iata': 'KL6317',
#                       'icao': 'KLM6317',
#                       'number': '6317'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5248',
#                                      'flight_icao': 'dal5248',
#                                      'flight_number': '5248'},
#                       'iata': 'AM3518',
#                       'icao': 'AMX3518',
#                       'number': '3518'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': '2021-04-26T14:50:00+00:00',
#                        'actual_runway': '2021-04-26T14:50:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '9',
#                        'delay': None,
#                        'estimated': '2021-04-26T15:32:00+00:00',
#                        'estimated_runway': '2021-04-26T14:50:00+00:00',
#                        'gate': 'D5',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T15:32:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T12:32:00+00:00',
#                          'actual_runway': '2021-04-26T12:32:00+00:00',
#                          'airport': 'Quad-City',
#                          'delay': 3,
#                          'estimated': '2021-04-26T12:30:00+00:00',
#                          'estimated_runway': '2021-04-26T12:32:00+00:00',
#                          'gate': 'B9',
#                          'iata': 'MLI',
#                          'icao': 'KMLI',
#                          'scheduled': '2021-04-26T12:30:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl5248',
#                                      'flight_icao': 'dal5248',
#                                      'flight_number': '5248'},
#                       'iata': 'AF2773',
#                       'icao': 'AFR2773',
#                       'number': '2773'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'DL', 'icao': 'DAL', 'name': 'Delta Air Lines'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:55:00+00:00',
#                          'actual_runway': '2021-04-26T13:55:00+00:00',
#                          'airport': 'Albuquerque International',
#                          'delay': 8,
#                          'estimated': '2021-04-26T13:55:00+00:00',
#                          'estimated_runway': '2021-04-26T13:55:00+00:00',
#                          'gate': 'B10',
#                          'iata': 'ABQ',
#                          'icao': 'KABQ',
#                          'scheduled': '2021-04-26T13:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Denver'},
#            'flight': {'codeshared': None,
#                       'iata': 'DL519',
#                       'icao': 'DAL519',
#                       'number': '519'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'scheduled',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'VS', 'icao': 'VIR', 'name': 'Virgin Atlantic'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:55:00+00:00',
#                          'actual_runway': '2021-04-26T13:55:00+00:00',
#                          'airport': 'Albuquerque International',
#                          'delay': 10,
#                          'estimated': '2021-04-26T13:55:00+00:00',
#                          'estimated_runway': '2021-04-26T13:55:00+00:00',
#                          'gate': 'B10',
#                          'iata': 'ABQ',
#                          'icao': 'KABQ',
#                          'scheduled': '2021-04-26T13:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Denver'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl519',
#                                      'flight_icao': 'dal519',
#                                      'flight_number': '519'},
#                       'iata': 'VS2110',
#                       'icao': 'VIR2110',
#                       'number': '2110'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:55:00+00:00',
#                          'actual_runway': '2021-04-26T13:55:00+00:00',
#                          'airport': 'Albuquerque International',
#                          'delay': 10,
#                          'estimated': '2021-04-26T13:55:00+00:00',
#                          'estimated_runway': '2021-04-26T13:55:00+00:00',
#                          'gate': 'B10',
#                          'iata': 'ABQ',
#                          'icao': 'KABQ',
#                          'scheduled': '2021-04-26T13:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Denver'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl519',
#                                      'flight_icao': 'dal519',
#                                      'flight_number': '519'},
#                       'iata': 'KL5723',
#                       'icao': 'KLM5723',
#                       'number': '5723'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '5',
#                        'delay': None,
#                        'estimated': '2021-04-26T18:55:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'A3',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T18:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T13:55:00+00:00',
#                          'actual_runway': '2021-04-26T13:55:00+00:00',
#                          'airport': 'Albuquerque International',
#                          'delay': 10,
#                          'estimated': '2021-04-26T13:55:00+00:00',
#                          'estimated_runway': '2021-04-26T13:55:00+00:00',
#                          'gate': 'B10',
#                          'iata': 'ABQ',
#                          'icao': 'KABQ',
#                          'scheduled': '2021-04-26T13:55:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Denver'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl519',
#                                      'flight_icao': 'dal519',
#                                      'flight_number': '519'},
# ...
#            'arrival': {'actual': '2021-04-26T08:32:00+00:00',
#                        'actual_runway': '2021-04-26T08:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-26T08:55:00+00:00',
#                        'estimated_runway': '2021-04-26T08:32:00+00:00',
#                        'gate': 'A33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T08:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T06:02:00+00:00',
#                          'actual_runway': '2021-04-26T06:02:00+00:00',
#                          'airport': 'General Mitchell International',
#                          'delay': 3,
#                          'estimated': '2021-04-26T06:00:00+00:00',
#                          'estimated_runway': '2021-04-26T06:02:00+00:00',
#                          'gate': 'D48',
#                          'iata': 'MKE',
#                          'icao': 'KMKE',
#                          'scheduled': '2021-04-26T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl814',
#                                      'flight_icao': 'dal814',
#                                      'flight_number': '814'},
#                       'iata': 'KE3689',
#                       'icao': 'KAL3689',
#                       'number': '3689'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': '2021-04-26T08:32:00+00:00',
#                        'actual_runway': '2021-04-26T08:32:00+00:00',
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '4',
#                        'delay': None,
#                        'estimated': '2021-04-26T08:55:00+00:00',
#                        'estimated_runway': '2021-04-26T08:32:00+00:00',
#                        'gate': 'A33',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T08:55:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T06:02:00+00:00',
#                          'actual_runway': '2021-04-26T06:02:00+00:00',
#                          'airport': 'General Mitchell International',
#                          'delay': 3,
#                          'estimated': '2021-04-26T06:00:00+00:00',
#                          'estimated_runway': '2021-04-26T06:02:00+00:00',
#                          'gate': 'D48',
#                          'iata': 'MKE',
#                          'icao': 'KMKE',
#                          'scheduled': '2021-04-26T06:00:00+00:00',
#                          'terminal': None,
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl814',
#                                      'flight_icao': 'dal814',
#                                      'flight_number': '814'},
#                       'iata': 'AM3511',
#                       'icao': 'AMX3511',
#                       'number': '3511'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'landed',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:34:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T14:51:00+00:00',
#                          'actual_runway': '2021-04-26T14:51:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 11,
#                          'estimated': '2021-04-26T14:40:00+00:00',
#                          'estimated_runway': '2021-04-26T14:51:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T14:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1792',
#                                      'flight_icao': 'dal1792',
#                                      'flight_number': '1792'},
#                       'iata': 'AF2367',
#                       'icao': 'AFR2367',
#                       'number': '2367'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:34:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T14:51:00+00:00',
#                          'actual_runway': '2021-04-26T14:51:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 11,
#                          'estimated': '2021-04-26T14:40:00+00:00',
#                          'estimated_runway': '2021-04-26T14:51:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T14:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1792',
#                                      'flight_icao': 'dal1792',
#                                      'flight_number': '1792'},
#                       'iata': 'KL6465',
#                       'icao': 'KLM6465',
#                       'number': '6465'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'WS', 'icao': 'WJA', 'name': 'WestJet'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '6',
#                        'delay': None,
#                        'estimated': '2021-04-26T17:34:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B36',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T17:34:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': '2021-04-26T14:51:00+00:00',
#                          'actual_runway': '2021-04-26T14:51:00+00:00',
#                          'airport': "Chicago O'hare International",
#                          'delay': 11,
#                          'estimated': '2021-04-26T14:40:00+00:00',
#                          'estimated_runway': '2021-04-26T14:51:00+00:00',
#                          'gate': 'E11',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T14:40:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1792',
#                                      'flight_icao': 'dal1792',
#                                      'flight_number': '1792'},
#                       'iata': 'WS7040',
#                       'icao': 'WJA7040',
#                       'number': '7040'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AF', 'icao': 'AFR', 'name': 'Air France'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-26T19:52:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T19:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 2,
#                          'estimated': '2021-04-26T16:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T16:59:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1360',
#                                      'flight_icao': 'dal1360',
#                                      'flight_number': '1360'},
#                       'iata': 'AF2361',
#                       'icao': 'AFR2361',
#                       'number': '2361'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'AM', 'icao': 'AMX', 'name': 'Aeromexico'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-26T19:52:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T19:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 2,
#                          'estimated': '2021-04-26T16:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T16:59:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1360',
#                                      'flight_icao': 'dal1360',
#                                      'flight_number': '1360'},
#                       'iata': 'AM3763',
#                       'icao': 'AMX3763',
#                       'number': '3763'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None},
#           {'aircraft': None,
#            'airline': {'iata': 'KL', 'icao': 'KLM', 'name': 'KLM'},
#            'arrival': {'actual': None,
#                        'actual_runway': None,
#                        'airport': 'Hartsfield-jackson Atlanta International',
#                        'baggage': '7',
#                        'delay': None,
#                        'estimated': '2021-04-26T19:52:00+00:00',
#                        'estimated_runway': None,
#                        'gate': 'B16',
#                        'iata': 'ATL',
#                        'icao': 'KATL',
#                        'scheduled': '2021-04-26T19:52:00+00:00',
#                        'terminal': 'S',
#                        'timezone': 'America/New_York'},
#            'departure': {'actual': None,
#                          'actual_runway': None,
#                          'airport': "Chicago O'hare International",
#                          'delay': 2,
#                          'estimated': '2021-04-26T16:59:00+00:00',
#                          'estimated_runway': None,
#                          'gate': 'E15',
#                          'iata': 'ORD',
#                          'icao': 'KORD',
#                          'scheduled': '2021-04-26T16:59:00+00:00',
#                          'terminal': '2',
#                          'timezone': 'America/Chicago'},
#            'flight': {'codeshared': {'airline_iata': 'dl',
#                                      'airline_icao': 'dal',
#                                      'airline_name': 'delta air lines',
#                                      'flight_iata': 'dl1360',
#                                      'flight_icao': 'dal1360',
#                                      'flight_number': '1360'},
#                       'iata': 'KL5940',
#                       'icao': 'KLM5940',
#                       'number': '5940'},
#            'flight_date': '2021-04-26',
#            'flight_status': 'active',
#            'live': None}],
#  'pagination': {'count': 100, 'limit': 100, 'offset': 0, 'total': 256099}}

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    flight_date.append(row['data'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-88d4c3e024b0> in <module>
#       3
#       4 for row in api_response['data']:
# ----> 5     iata.append(row['airline']['iata'])
#       6     icao.append(row['airline']['icao'])
#       7     arr_airport.append(row['arrival']['airport'])
#
# NameError: name 'iata' is not defined

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    "flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data_df.head()

# %%
########################4.23.2021###################################200
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-23',    
}

api_0423 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0423.json()

pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data2_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data2_df.head()

# %%
joined_df_merge = pd.concat([flights_data_df, flights_data2_df])
joined_df_merge.head()

# %%
########################4.22.2021###################################300
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-22'
    
}

api_0422 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0422.json()

pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data3_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data3_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data3_df])
joined_df_merge.head(300)

# %%
########################4.21.2021###################################400
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-21'
    
}

api_0421 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0421.json()

pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data4_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data4_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data4_df])
joined_df_merge.head(400)

# %%
########################4.20.2021###################################500
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-20'
    
}

api_0420 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0420.json()

pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data5_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data5_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data5_df])
joined_df_merge.head(500)

# %%
########################4.19.2021###################################600
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-19'
    
}

api_0419 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0419.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data6_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data6_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data6_df])
joined_df_merge.head(600)

# %%
########################4.18.2021###################################700
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-18'
    
}

api_0418 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0418.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data7_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data7_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data7_df])
joined_df_merge.head(700)

# %%
########################4.17.2021###################################800
params = {
    'access_key': api_key,
    'arr_iata': 'ATL',
    'flight_date': '2021-04-17'
    
}

api_0417 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0417.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data8_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data8_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data8_df])
joined_df_merge.head(800)

# %%
########################4.16.2021###################################900
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-16'
    
}

api_0416 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0416.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data9_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data9_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data9_df])
joined_df_merge.head(900)

# %%
########################4.15.2021###################################1000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
'flight_date': '2021-04-15'
    
}

api_0415 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0415.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data10_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data10_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data10_df])
joined_df_merge.head(1000)

# %%
########################4.14.2021###################################1100
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-14'
    
}

api_0414 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0414.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data11_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data11_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data11_df])
joined_df_merge.head(1100)

# %%
########################4.13.2021###################################1200
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-13'
    
}

api_0413 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0413.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data12_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data12_df])
joined_df_merge.head(1200)

# %%
########################4.12.2021###################################1300
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-12'
    
}

api_0412 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0412.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data13_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data13_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data13_df])
joined_df_merge.head(1300)

# %%
########################4.11.2021###################################1400
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-11'
    
}

api_0411 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0411.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data14_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data14_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data14_df])
joined_df_merge.head(1400)

# %%
########################4.10.2021###################################1500
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-10'
    
}

api_0410 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0410.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data15_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data15_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data15_df])
joined_df_merge.head(1500)

# %%
########################4.09.2021###################################1600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-09'
    
}

api_0409 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0409.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data16_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data16_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data16_df])
joined_df_merge.head(1600)

# %%
########################4.08.2021###################################1700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-08'
    
}

api_0408 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0408.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data17_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data17_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data17_df])
joined_df_merge.head(1700)

# %%
########################4.07.2021###################################1800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-07'
    
}

api_0407 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0407.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data18_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data18_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data18_df])
joined_df_merge.head(1800)

# %%
########################4.06.2021###################################1900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-06'
    
}

api_0406 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0406.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data19_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data19_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data19_df])
joined_df_merge.head(1900)

# %%
########################4.05.2021###################################2000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-05'
    
}

api_0405 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0405.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data20_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data20_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data20_df])
joined_df_merge.head(2000)

# %%
########################4.04.2021###################################2100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-04'
    
}

api_0404 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0404.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data21_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data21_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data21_df])
joined_df_merge.head(2100)

# %%
########################4.03.2021###################################2200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-03'
    
}

api_0403 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0403.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data22_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data22_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data22_df])
joined_df_merge.head(2200)

# %%
########################4.02.2021###################################2300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-02'
    
}

api_0402 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0402.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data23_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data23_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data23_df])
joined_df_merge.head(2300)

# %%
########################4.01.2021###################################2400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-04-01'
    
}

api_0401 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0401.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data24_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data24_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(2400)

# %%
########################03.31.2021###################################2500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-31'
    
}

api_0331 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0331.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data25_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data25_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data25_df])
joined_df_merge.head(2500)

# %%
########################03.30.2021###################################2600
params = {
   'access_key': api_key,  
   'arr_iata': 'ATL',
    'flight_date': '2021-03-30'
    
}

api_0330 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0330.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data26_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data26_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data26_df])
joined_df_merge.head(2600)

# %%
########################03.29.2021###################################2700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-29'
    
}

api_0329 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0329.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data27_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data27_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data27_df])
joined_df_merge.head(2700)

# %%
########################03.28.2021###################################2800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-28'
    
}

api_0328 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0328.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data28_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data28_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data28_df])
joined_df_merge.head(2800)

# %%
########################03.27.2021###################################2900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-27'
    
}

api_0327 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0327.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data29_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data29_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data29_df])
joined_df_merge.head(2900)

# %%
########################03.26.2021###################################3000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-26'
    
}

api_0326 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0326.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data30_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data30_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data30_df])
joined_df_merge.head(3000)

# %%
########################03.25.2021###################################3100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-25'
    
}

api_0325 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0325.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data31_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data31_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data31_df])
joined_df_merge.head(3100)

# %%
########################03.24.2021###################################3200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-24'
    
}

api_0324 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0324.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data32_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data32_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data32_df])
joined_df_merge.head(3200)

# %%
########################03.23.2021###################################3300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-23'
    
}

api_0323 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0323.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data33_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data33_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data33_df])
joined_df_merge.head(3300)

# %%
########################03.22.2021###################################3400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-22'
    
}

api_0322 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0322.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data34_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data34_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data34_df])
joined_df_merge.head(3400)

# %%
########################03.21.2021###################################3500
params = {
   'access_key': api_key, 
   'arr_iata': 'ATL',
    'flight_date': '2021-03-21'
    
}

api_0321 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0321.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data35_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data35_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data24_df])
joined_df_merge.head(3500)

# %%
########################03.20.2021###################################3600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-20'
    
}

api_0320 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0320.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data36_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data36_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data36_df])
joined_df_merge.head(3600)

# %%
########################03.19.2021###################################3700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-19'
    
}

api_0319 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0319.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data37_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data37_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data37_df])
joined_df_merge.head(3700)

# %%
########################03.18.2021###################################3800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-18'
    
}

api_0318 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0318.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data38_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data38_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data38_df])
joined_df_merge.head(3800)

# %%
########################03.17.2021###################################3900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-17'
    
}

api_0317 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0317.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data39_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data39_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data39_df])
joined_df_merge.head(3900)

# %%
########################03.16.2021###################################4000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-16'
    
}

api_0316 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0316.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data40_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data40_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data40_df])
joined_df_merge.head(4000)

# %%
########################03.15.2021###################################4100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-15'
    
}

api_0315 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0315.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data41_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data41_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data41_df])
joined_df_merge.head(4100)

# %%
########################03.14.2021###################################4200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-14'
    
}

api_0314 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0314.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data42_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data42_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data42_df])
joined_df_merge.head(4200)

# %%
########################03.13.2021###################################4300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-13'
    
}

api_0313 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0313.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data43_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data43_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data43_df])
joined_df_merge.head(4300)

# %%
########################03.12.2021###################################4400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-12'
    
}

api_0312 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0312.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data44_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data44_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data44_df])
joined_df_merge.head(4400)

# %%
########################03.11.2021###################################4500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-11'
    
}

api_0311 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0311.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data45_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data12_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data45_df])
joined_df_merge.head(4500)

# %%
########################03.10.2021###################################4600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-10'
    
}

api_0310 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0310.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data46_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data46_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data46_df])
joined_df_merge.head(4600)

# %%
########################03.09.2021###################################4700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-09'
    
}

api_0309 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0309.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data47_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data47_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data47_df])
joined_df_merge.head(4700)

# %%
########################03.08.2021###################################4800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-08'
    
}

api_0308 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0308.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data48_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data48_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data48_df])
joined_df_merge.head(4800)

# %%
########################03.07.2021###################################4900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-07'
    
}

api_0307 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0307.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data49_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data49_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data49_df])
joined_df_merge.head(4900)

# %%
########################03.06.2021###################################5000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-06'
    
}

api_0306 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0306.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data50_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data50_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data50_df])
joined_df_merge.head(5000)

# %%
########################03.05.2021###################################5100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-05'
    
}

api_0305 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0305.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data51_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data51_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data51_df])
joined_df_merge.head(5100)

# %%
########################03.04.2021###################################5200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-04'
    
}

api_0304 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0304.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data52_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data52_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data52_df])
joined_df_merge.head(5200)

# %%
########################03.03.2021###################################5300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-03'
    
}

api_0303 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0303.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data53_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data53_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data53_df])
joined_df_merge.head(5300)

# %%
########################03.02.2021###################################5400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-02'
    
}

api_0302 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0302.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data54_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data54_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data54_df])
joined_df_merge.head(5400)

# %%
########################03.01.2021###################################5500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-03-01'
    
}

api_0301 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0301.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data55_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data55_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data55_df])
joined_df_merge.head(5500)

# %%
########################02.28.2021###################################5600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-28'
    
}

api_0228 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data56_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data26_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data55_df])
joined_df_merge.head(5600)

# %%
########################02.27.2021###################################5700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-27'
    
}

api_0227 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0227.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data57_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data57_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data57_df])
joined_df_merge.head(5700)

# %%
########################02.26.2021###################################5800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-26'
    
}

api_0226 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0226.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data58_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data58_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data58_df])
joined_df_merge.head(5800)

# %%
########################02.25.2021###################################5900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-25'
    
}

api_0225 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0225.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data59_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data59_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data59_df])
joined_df_merge.head(5900)

# %%
########################02.24.2021###################################6000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-24'
    
}

api_0224 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0224.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data60_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data60_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data60_df])
joined_df_merge.head(6000)

# %%
########################02.23.2021###################################6100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-23'
    
}

api_0223 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0223.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data61_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data61_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data61_df])
joined_df_merge.head(6100)

# %%
########################02.22.2021###################################6200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-22'
    
}

api_0222 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0222.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data62_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data62_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data62_df])
joined_df_merge.head(6200)

# %%
########################02.21.2021###################################6300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-21'
    
}

api_0221 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0221.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data63_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data63_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data63_df])
joined_df_merge.head(6300)

# %%
########################02.20.2021###################################6400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-20'
    
}

api_0220 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0220.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data64_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data64_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data64_df])
joined_df_merge.head(6400)

# %%
########################02.19.2021###################################6500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-19'
    
}

api_0219 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0219.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data65_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data65_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data65_df])
joined_df_merge.head(6500)

# %%
########################02.18.2021###################################6600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-18'
    
}

api_0218 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0218.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data66_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data66_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data66_df])
joined_df_merge.head(6600)

# %%
########################02.17.2021###################################6700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-17'
    
}

api_0217 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0217.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data67_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data67_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data67_df])
joined_df_merge.head(6700)

# %%
########################02.16.2021###################################6800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-16'
    
}

api_0216 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0216.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data68_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data68_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data68_df])
joined_df_merge.head(6800)

# %%
########################02.15.2021###################################7000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-15'
    
}

api_0215 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0215.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data70_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data70_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data70_df])
joined_df_merge.head(7000)

# %%
########################02.14.2021###################################7100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-14'
    
}

api_0214 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0214.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data71_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data71_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data71_df])
joined_df_merge.head(7100)

# %%
########################02.13.2021###################################7200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-13'
    
}

api_0213 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0213.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data72_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data72_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data72_df])
joined_df_merge.head(7200)

# %%
########################02.12.2021###################################7300
params = {
  'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data73_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data73_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data73_df])
joined_df_merge.head(7300)

# %%
########################02.11.2021###################################7400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0228.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data74_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data74_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data74_df])
joined_df_merge.head(7400)

# %%
########################02.12.2021###################################7500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-12'
    
}

api_0212 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0212.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data75_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data75_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data75_df])
joined_df_merge.head(7500)

# %%
########################02.11.2021###################################7600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-11'
    
}

api_0211 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0211.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data76_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data76_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data76_df])
joined_df_merge.head(7600)

# %%
########################02.10.2021###################################7700
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-10'
    
}

api_0210 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0210.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data77_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data77_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data77_df])
joined_df_merge.head(7700)

# %%
########################02.09.2021###################################7800
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-09'
    
}

api_0209 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0209.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data78_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data78_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data78_df])
joined_df_merge.head(7800)

# %%
########################02.08.2021###################################7900
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-08'
    
}

api_0208 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0208.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data79_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data79_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data79_df])
joined_df_merge.head(7900)

# %%
########################02.07.2021###################################8000
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-07'
    
}

api_0207 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0207.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data80_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data80_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data80_df])
joined_df_merge.head(8000)

# %%
########################02.06.2021###################################8100
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-06'
    
}

api_0206 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0206.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data81_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data81_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data81_df])
joined_df_merge.head(8100)

# %%
########################02.05.2021###################################8200
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-05'
    
}

api_0205 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0205.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data82_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data82_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data82_df])
joined_df_merge.head(8200)

# %%
########################02.04.2021###################################8300
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-04'
    
}

api_0204 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0204.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data83_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data83_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data83df])
joined_df_merge.head(8300)

# %%
########################02.03.2021###################################8400
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-03'
    
}

api_0203 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0203.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data84_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data84_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data84_df])
joined_df_merge.head(8400)

# %%
########################02.02.2021###################################8500
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-02'
    
}

api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data85_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data85_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data85_df])
joined_df_merge.head(8500)

# %%
########################02.01.2021###################################8600
params = {
   'access_key': api_key,
   'arr_iata': 'ATL',
    'flight_date': '2021-02-01'
    
}


api_0202 = requests.get('https://api.aviationstack.com/v1/flights', params)

api_response = api_0202.json()

#pprint(api_response)

# %%
# Grab needed rows from airline
flights = []

for row in api_response['data']:
    iata.append(row['airline']['iata'])
    icao.append(row['airline']['icao'])
    arr_airport.append(row['arrival']['airport'])
    flight_number.append(row['flight']['number'])
    #flight_date.append(row['data']['flight_date'])
    arr_terminal.append(row['arrival']['terminal'])
    arr_gate.append(row['arrival']['gate'])
    dep_airport.append(row['departure']['airport'])
    dep_terminal.append(row['departure']['terminal'])
    dep_gate.append(row['departure']['gate'])

# %%
data = {
    "airline_iata": iata,
    "airline_icao": icao,
    "arr_airport": arr_airport,
    "flight_no": flight_number,
    #"flight_date": flight_date,
    "arr_terminal": arr_terminal,
    "arr_gate": arr_gate,
    "dep_airport": dep_airport,
    "dep_terminal": dep_terminal,
    "dep_gate": dep_gate
}
flights_data86_df = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in data.items() ]))
flights_data86_df.head()

# %%
joined_df_merge = pd.concat([joined_df_merge, flights_data86_df])
joined_df_merge.head(8600)

# %%
joined_df_merge.to_csv(saved_data.csv?)
